# %% [markdown]
# # mobilenet
# - https://pytorch.org/hub/pytorch_vision_mobilenet_v2/

# %% [markdown]
# ## transfer learning
# - https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html

# %%
from __future__ import print_function, division

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy

plt.ion()   # interactive mode

# %%
# Data augmentation and normalization for training
# Just normalization for validation
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomRotation(90),
#         transforms.ColorJitter(),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.RandomRotation(90),
#         transforms.Resize(256),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'sample': transforms.Compose([
        transforms.ToPILImage(),
        transforms.RandomRotation(90),
#         transforms.ColorJitter(),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),    
}

data_dir = 'img4'
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=32,
                                             shuffle=True, num_workers=4)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
class_names = image_datasets['train'].classes

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


# Get a batch of training data
inputs, classes = next(iter(dataloaders['train']))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs, save_path):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                scheduler.step()
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for idx, (inputs, labels) in enumerate(dataloaders[phase]):
                inputs = inputs.to(device)
                labels = labels.to(device)
                
                # ------------------------
                pos_len = 6
                cls = np.random.randint(0,len(image_datasets['train'].classes))
                all_targets = np.array(list(zip(range(len(image_datasets['train'].targets)), image_datasets['train'].targets)))
                all_targets = all_targets[all_targets[:,1]==cls]
                np.random.shuffle(all_targets)
                sampled_indics = all_targets[:pos_len, 0]
                sampled_targets = torch.tensor(all_targets[:pos_len, 1]).to(device).long()
                sampled_inputs = torch.stack([data_transforms['sample'](image_datasets['train'][i][0])
                                              for i in sampled_indics]).to(device)
                inputs = torch.cat([inputs, sampled_inputs])
                labels = torch.cat([labels, sampled_targets])
                # ------------------------

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # mini batch statistics
                if idx%50==0:
                    print('[batch loss] {} Loss: {:.4f} Acc: {:.4f}'.format(
                        phase, loss, torch.sum(preds == labels.data)/inputs.shape[0]))

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        #save all model every epoch
        PATH = save_path+str(epoch)+'.pt'
        torch.save(model, PATH)
        print('***** Model saved:', PATH, '*****')
        
    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %% [markdown]
# ## 모델 설정

# %%
"""
resnet18 전체 파라미터 재훈련
"""
model_ft = models.resnet18(pretrained=True)
num_ftrs = model_ft.fc.in_features
model_ft.fc = nn.Linear(num_ftrs, len(class_names))

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)

# %%
model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=25)
# Out:
# Epoch 0/24
# ----------
# train Loss: 0.4286 Acc: 0.9635
# val Loss: 0.5565 Acc: 0.9265
#
# Epoch 1/24
# ----------
# train Loss: 0.4342 Acc: 0.9601
# val Loss: 0.5570 Acc: 0.9265
#
# Epoch 2/24
# ----------
# train Loss: 0.4191 Acc: 0.9635
# val Loss: 0.5579 Acc: 0.9265
#
# Epoch 3/24
# ----------
# train Loss: 0.4258 Acc: 0.9734
# val Loss: 0.5589 Acc: 0.9265
#
# Epoch 4/24
# ----------
# train Loss: 0.4333 Acc: 0.9668
# val Loss: 0.5581 Acc: 0.9265
#
# Epoch 5/24
# ----------
# train Loss: 0.4237 Acc: 0.9701
# val Loss: 0.5590 Acc: 0.9265
#
# Epoch 6/24
# ----------
# train Loss: 0.4182 Acc: 0.9635
# val Loss: 0.5587 Acc: 0.9265
#
# Epoch 7/24
# ----------
# train Loss: 0.4251 Acc: 0.9734
# val Loss: 0.5595 Acc: 0.9265
#
# Epoch 8/24
# ----------
# train Loss: 0.4285 Acc: 0.9701
# val Loss: 0.5580 Acc: 0.9265
#
# Epoch 9/24
# ----------
# train Loss: 0.4356 Acc: 0.9568
# val Loss: 0.5580 Acc: 0.9265
#
# Epoch 10/24
# ----------
# train Loss: 0.4387 Acc: 0.9635
# val Loss: 0.5579 Acc: 0.9265
#
# Epoch 11/24
# ----------
# train Loss: 0.4313 Acc: 0.9701
# val Loss: 0.5580 Acc: 0.9265
#
# Epoch 12/24
# ----------
# train Loss: 0.4414 Acc: 0.9635
# val Loss: 0.5573 Acc: 0.9265
#
# Epoch 13/24
# ----------
# train Loss: 0.4318 Acc: 0.9668
# val Loss: 0.5574 Acc: 0.9265
#
# Epoch 14/24
# ----------
# train Loss: 0.4193 Acc: 0.9668
# val Loss: 0.5595 Acc: 0.9265
#
# Epoch 15/24
# ----------
# train Loss: 0.4244 Acc: 0.9734
# val Loss: 0.5582 Acc: 0.9265
#
# Epoch 16/24
# ----------
# train Loss: 0.4353 Acc: 0.9701
# val Loss: 0.5577 Acc: 0.9265
#
# Epoch 17/24
# ----------
# train Loss: 0.4297 Acc: 0.9701
# val Loss: 0.5583 Acc: 0.9265
#
# Epoch 18/24
# ----------
# train Loss: 0.4210 Acc: 0.9734
# val Loss: 0.5587 Acc: 0.9265
#
# Epoch 19/24
# ----------
# train Loss: 0.4421 Acc: 0.9767
# val Loss: 0.5564 Acc: 0.9265
#
# Epoch 20/24
# ----------
# train Loss: 0.4196 Acc: 0.9635
# val Loss: 0.5567 Acc: 0.9412
#
# Epoch 21/24
# ----------
# train Loss: 0.4202 Acc: 0.9668
# val Loss: 0.5573 Acc: 0.9265
#
# Epoch 22/24
# ----------
# train Loss: 0.4183 Acc: 0.9701
# val Loss: 0.5583 Acc: 0.9265
#
# Epoch 23/24
# ----------
# train Loss: 0.4305 Acc: 0.9668
# val Loss: 0.5585 Acc: 0.9265
#
# Epoch 24/24
# ----------
# train Loss: 0.4277 Acc: 0.9767
# val Loss: 0.5590 Acc: 0.9265
#
# Training complete in 1m 39s
# Best val Acc: 0.941176

# %%
"""
resnet18 마지막 피처 파라미터만 재훈련
"""
model_conv = torchvision.models.resnet18(pretrained=True)
for param in model_conv.parameters():
    param.requires_grad = False

# Parameters of newly constructed modules have requires_grad=True by default
num_ftrs = model_conv.fc.in_features
model_conv.fc = nn.Linear(num_ftrs, len(class_names))

model_conv = model_conv.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that only parameters of final layer are being optimized as
# opposed to before.
optimizer_conv = optim.SGD(model_conv.fc.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_conv, step_size=7, gamma=0.1)

# %%
model_conv = train_model(model_conv, criterion, optimizer_conv,
                         exp_lr_scheduler, num_epochs=25)
# Out:
# Epoch 0/24
# ----------
# train Loss: 2.1997 Acc: 0.0997
# val Loss: 2.0810 Acc: 0.1471
#
# Epoch 1/24
# ----------
# train Loss: 1.9919 Acc: 0.3090
# val Loss: 1.7934 Acc: 0.4853
#
# Epoch 2/24
# ----------
# train Loss: 1.7442 Acc: 0.5449
# val Loss: 1.5221 Acc: 0.5735
#
# Epoch 3/24
# ----------
# train Loss: 1.4618 Acc: 0.6512
# val Loss: 1.2652 Acc: 0.7353
#
# Epoch 4/24
# ----------
# train Loss: 1.2193 Acc: 0.8106
# val Loss: 1.0518 Acc: 0.8382
#
# Epoch 5/24
# ----------
# train Loss: 1.0064 Acc: 0.9136
# val Loss: 0.8809 Acc: 0.8971
#
# Epoch 6/24
# ----------
# train Loss: 0.8728 Acc: 0.9103
# val Loss: 0.8688 Acc: 0.8971
#
# Epoch 7/24
# ----------
# train Loss: 0.8740 Acc: 0.9203
# val Loss: 0.8548 Acc: 0.8824
#
# Epoch 8/24
# ----------
# train Loss: 0.8496 Acc: 0.9236
# val Loss: 0.8430 Acc: 0.8971
#
# Epoch 9/24
# ----------
# train Loss: 0.8393 Acc: 0.9136
# val Loss: 0.8302 Acc: 0.8971
#
# Epoch 10/24
# ----------
# train Loss: 0.8222 Acc: 0.9302
# val Loss: 0.8175 Acc: 0.9118
#
# Epoch 11/24
# ----------
# train Loss: 0.8069 Acc: 0.9402
# val Loss: 0.8083 Acc: 0.8971
#
# Epoch 12/24
# ----------
# train Loss: 0.7987 Acc: 0.9302
# val Loss: 0.7969 Acc: 0.8971
#
# Epoch 13/24
# ----------
# train Loss: 0.7879 Acc: 0.9336
# val Loss: 0.7951 Acc: 0.8971
#
# Epoch 14/24
# ----------
# train Loss: 0.7873 Acc: 0.9302
# val Loss: 0.7938 Acc: 0.8971
#
# Epoch 15/24
# ----------
# train Loss: 0.7875 Acc: 0.9302
# val Loss: 0.7938 Acc: 0.9118
#
# Epoch 16/24
# ----------
# train Loss: 0.7809 Acc: 0.9568
# val Loss: 0.7940 Acc: 0.8971
#
# Epoch 17/24
# ----------
# train Loss: 0.7855 Acc: 0.9468
# val Loss: 0.7928 Acc: 0.8971
#
# Epoch 18/24
# ----------
# train Loss: 0.7861 Acc: 0.9402
# val Loss: 0.7921 Acc: 0.8971
#
# Epoch 19/24
# ----------
# train Loss: 0.7994 Acc: 0.9402
# val Loss: 0.7901 Acc: 0.8971
#
# Epoch 20/24
# ----------
# train Loss: 0.7988 Acc: 0.9468
# val Loss: 0.7891 Acc: 0.8971
#
# Epoch 21/24
# ----------
# train Loss: 0.7787 Acc: 0.9402
# val Loss: 0.7908 Acc: 0.9118
#
# Epoch 22/24
# ----------
# train Loss: 0.7875 Acc: 0.9369
# val Loss: 0.7905 Acc: 0.8971
#
# Epoch 23/24
# ----------
# train Loss: 0.7819 Acc: 0.9435
# val Loss: 0.7920 Acc: 0.8971
#
# Epoch 24/24
# ----------
# train Loss: 0.7880 Acc: 0.9369
# val Loss: 0.7889 Acc: 0.8971
#
# Training complete in 1m 28s
# Best val Acc: 0.911765

# %%
"""
mobilenet 전체 파라미터 재훈련
"""
model_mb = torch.hub.load('pytorch/vision', 'mobilenet_v2', pretrained=True)

# for param in model_mb.parameters():
#     param.requires_grad = False

# Parameters of newly constructed modules have requires_grad=True by default
model_mb.classifier[1] = nn.Linear(1280, len(class_names))
model_mb = model_mb.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that only parameters of final layer are being optimized as
# opposed to before.
# optimizer_mb = optim.SGD(model_mb.classifier.parameters(), lr=0.001, momentum=0.9)
optimizer_mb = torch.optim.Adam(model_mb.parameters(), lr=0.0005)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_mb, step_size=7, gamma=0.1)
# Out:
# Using cache found in C:\Users\LSW/.cache\torch\hub\pytorch_vision_master

# %%
"""
mobilenet 마지막 피처 파라미터만 재훈련
"""
model_mb = torch.hub.load('pytorch/vision', 'mobilenet_v2', pretrained=True)

for param in model_mb.parameters():
    param.requires_grad = False

# Parameters of newly constructed modules have requires_grad=True by default
model_mb.classifier[1] = nn.Linear(1280, len(class_names))
model_mb = model_mb.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that only parameters of final layer are being optimized as
# opposed to before.
# optimizer_mb = optim.SGD(model_mb.classifier.parameters(), lr=0.001, momentum=0.9)
optimizer_mb = torch.optim.Adam(model_mb.classifier.parameters(), lr=0.0005)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_mb, step_size=7, gamma=0.1)
# Out:
# Using cache found in C:\Users\LSW/.cache\torch\hub\pytorch_vision_master

# %%
"""
https://pytorch.org/docs/stable/nn.html
mobilenet L2 margin loss, 전체 파라미터 재훈련
"""
class Flatten(torch.nn.Module):
    def __init__(self):
        """Load the pretrained ResNet-152 and replace top fc layer."""
        super(Flatten, self).__init__()    
    def forward(self, x):
        batch_size = x.shape[0]
        return x.view(batch_size, -1)
    
model_mb = torch.hub.load('pytorch/vision', 'mobilenet_v2', pretrained=False)
modules = list(model_mb.children())[:-1]
avg_pool = torch.nn.AvgPool2d(7, stride=1)
flatten = Flatten()
model_mb = torch.nn.Sequential(*modules, avg_pool, flatten) #1280
        
model_mb = model_mb.to(device)

criterion = torch.nn.CosineEmbeddingLoss(margin=0.3, reduction='mean')
# criterion = torch.nn.MultiMarginLoss(p=2, margin=1.0, reduction='mean')

# Observe that only parameters of final layer are being optimized as
# opposed to before.
# optimizer_mb = optim.SGD(model_mb.classifier.parameters(), lr=0.001, momentum=0.9)
optimizer_mb = torch.optim.Adam(model_mb.parameters(), lr=0.0005)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_mb, step_size=7, gamma=0.1)
# Out:
# Using cache found in C:\Users\LSW/.cache\torch\hub\pytorch_vision_master

# %%
model_mb = train_dmn(model_mb, criterion, optimizer_mb, exp_lr_scheduler,
                     num_epochs=50, save_path='torch_models/cos/mobile-b-10-all-cos-')
# Out:
# Epoch 0/49
# ----------
# [batch loss] train Loss: 0.6407
# [batch loss] train Loss: 0.0300
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-8-944dc72a561a> in <module>()
#       1 model_mb = train_dmn(model_mb, criterion, optimizer_mb, exp_lr_scheduler,
# ----> 2                      num_epochs=50, save_path='torch_models/cos/mobile-b-10-all-cos-')
#
# <ipython-input-6-3a210568dcdc> in train_dmn(model, criterion, optimizer, scheduler, num_epochs, save_path)
#      44                     if phase == 'train':
#      45                         loss.backward()
# ---> 46                         optimizer.step()
#      47
#      48                 # mini batch statistics - 10 times per epoch
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\optim\adam.py in step(self, closure)
#      99                     denom = max_exp_avg_sq.sqrt().add_(group['eps'])
#     100                 else:
# --> 101                     denom = exp_avg_sq.sqrt().add_(group['eps'])
#     102
#     103                 bias_correction1 = 1 - beta1 ** state['step']
#
# RuntimeError: cuda runtime error (4) : unspecified launch failure at C:/w/1/s/tmp_conda_3.6_035809/conda/conda-bld/pytorch_1556683229598/work/aten/src\THC/generic/THCTensorMathPointwise.cu:50

# %%
model_mb = train_model(model_mb, criterion, optimizer_mb, exp_lr_scheduler, 
                         num_epochs=50, save_path='torch_models/first/mobile-b-10-all-margin-')
# Out:
# Epoch 0/49
# ----------
# [batch loss] train Loss: 1.1607 Acc: 0.0000
# [batch loss] train Loss: 0.9810 Acc: 0.0000
# [batch loss] train Loss: 0.9923 Acc: 0.0000
# [batch loss] train Loss: 1.0157 Acc: 0.0000
# [batch loss] train Loss: 0.8324 Acc: 0.0000
# [batch loss] train Loss: 0.9168 Acc: 0.0000
# [batch loss] train Loss: 0.8733 Acc: 0.0000
# [batch loss] train Loss: 0.8955 Acc: 0.0000
# [batch loss] train Loss: 0.8873 Acc: 0.0000
# [batch loss] train Loss: 0.7719 Acc: 0.0000
# [batch loss] train Loss: 0.8052 Acc: 0.0000
# [batch loss] train Loss: 0.7119 Acc: 0.0000
# [batch loss] train Loss: 0.6857 Acc: 0.0000
# [batch loss] train Loss: 0.7222 Acc: 0.0000
# [batch loss] train Loss: 0.5950 Acc: 0.0000
# [batch loss] train Loss: 0.5939 Acc: 0.0000
# [batch loss] train Loss: 0.6779 Acc: 0.0000

# %% [markdown]
# ---
# # siamese net

# %%
def batch_pair_loader(dataset, n_batch=64, pos_ratio=0.02):
    """
    make random pairs minibatch for siamese network margin loss
    @param dataset: torch dataset
    @param n_batch: number of mini batch
    @param pos_ratio: 
    """
    # [[idx_orig, target], [idx_orig, target]...]
    all_targets = np.array(list(zip(range(len(dataset.targets)), dataset.targets)))
    # 클래스 랜덤 샘플
    cls_batch = np.random.randint(0, len(dataset.classes), size=n_batch) # replace samping
    # positive 랜덤 인덱스 페어 생성
    _neg_firts_idx = int(n_batch*pos_ratio)
    first_list = []
    second_list = []
    # positive sampling
    for cls in cls_batch[:_neg_firts_idx]:
        cls_targets = all_targets[all_targets[:,1]==cls]
        i1, i2 = np.random.choice(cls_targets[:,0], 2, replace=True)
        first_list.append(i1)
        second_list.append(i2)
    # negative sampling
    for cls in cls_batch[_neg_firts_idx:]:
        cls_targets = all_targets[all_targets[:,1]==cls]
        cls_targets_neg = all_targets[all_targets[:,1]!=cls]
        i1 = np.random.choice(cls_targets[:,0], 1, replace=True)
        i2 = np.random.choice(cls_targets_neg[:,0], 1, replace=True)        
        first_list.append(int(i1))
        second_list.append(int(i2))    
    
    label = [1]*_neg_firts_idx + [-1]*(n_batch-_neg_firts_idx)
    label = np.array(label)
    # x1, x2, targets
    # dataloader 거치는 것이 아니므로 data_transforms 직접 해줘야함
    x1s = torch.stack([data_transforms['sample'](dataset[i][0]) for i in first_list])
    x2s = torch.stack([data_transforms['sample'](dataset[i][0]) for i in second_list])
    return x1s, x2s, label, cls_batch

# %%
def train_dmn(model, criterion, optimizer, scheduler, num_epochs, save_path):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_loss = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                scheduler.step()
                model.train()  # Set model to training mode
            else:
                model.eval()  # Set model to evaluate mode

            running_loss = 0.0

            # Iterate over data.
            n_batch = {'train':32, 'val':5}
            n_iter_per_epoch = int(len(image_datasets[phase])/n_batch[phase])
            if phase=='val': n_iter_per_epoch = 5
            for idx in range(n_iter_per_epoch):
                # for idx, (inputs, labels) in enumerate(dataloaders[phase]):
                x1s, x2s, labels, _ = batch_pair_loader(image_datasets[phase], n_batch=n_batch[phase])
                x1s = x1s.to(device)
                x2s = x2s.to(device)
                labels = torch.tensor(labels).float().to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs1 = model(x1s)
                    outputs2 = model(x2s)
                    # _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs1, outputs2, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # mini batch statistics - 10 times per epoch
                if phase=='train' and idx % (n_iter_per_epoch//10) == 0:
                    print('[batch loss] {} Loss: {:.4f}'.format(phase, loss))

                # statistics
                running_loss += loss * n_batch[phase]

            # epoch 의미가 없음 랜덤 샘플링이라
            epoch_loss = running_loss / n_batch[phase] / n_iter_per_epoch
            print('{} Loss: {:.4f}'.format(phase, epoch_loss))

            # deep copy the model
            if phase == 'val' and epoch_loss > best_loss:
                best_loss = epoch_loss
                best_model_wts = copy.deepcopy(model.state_dict())

        #save all model every epoch
        PATH = save_path+str(epoch)+'.pt'
        torch.save(model, PATH)
        print('***** Model saved:', PATH, '*****')

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
"""
import torch
import numpy as np
from torch.autograd import Variable
from torch.utils.data import Dataset, DataLoader


class MyDataset(Dataset):
    """ Diabetes dataset."""

    # Initialize your data, download, etc.
    def __init__(self):
        xy = np.loadtxt('./reference_means2.csv',
                        delimiter=',')#, dtype=np.float32)
        self.len = xy.shape[0]
        self.x_data = torch.from_numpy(xy[:, :-1])
        self.y_data = torch.from_numpy(xy[:, -1])

    def __getitem__(self, index):
        return self.x_data[index], self.y_data[index]

    def __len__(self):
        return self.len


dataset = MyDataset()
train_loader = DataLoader(dataset=dataset,
                          batch_size=8,
                          shuffle=True,
                          num_workers=0)

"""

# %% [markdown]
# ---
# # visualize

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
#                 print(class_names[labels[j]])
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title('[ans]: {}, // [predicted]: {}'.format(class_names[labels[j]], class_names[preds[j]]))
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
visualize_model(model_mb)

# %% [markdown]
# ---
# ## Model save / load
# - https://pytorch.org/tutorials/beginner/saving_loading_models.html

# %%
PATH = 'torch_models/mobile-b-10-all-cos-'+str(epoch)+'.pt'
torch.save(model_mb, PATH)
# Out:
# 'torch_models/mobile-b-10-all-cos1.pt'

# %%
# PATH = 'torch_models/mobile-b-10-all-rot2.pt'
PATH = 'torch_models/mobile-b-10-all-cos.pt'

# torch.save(model_ft.state_dict(), PATH)
torch.save(model_mb, PATH)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\torch\serialization.py:256: UserWarning: Couldn't retrieve source code for container of type Flatten. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "

# %%
modules = list(model2.children())[:-1]
linear = torch.nn.Linear(1280, 1000)
avg_pool = torch.nn.AvgPool2d(7, stride=1)
m3 = torch.nn.Sequential(*modules, avg_pool)

# %%
m3.cuda()
m3.eval()
m3(torch.rand([1,3,224,224]).cuda()).view(-1,1280).shape
# Out:
# torch.Size([1, 1280])

# %%
model2 = torch.load(PATH)
model2.eval()
# Out:
# MobileNetV2(
#   (features): Sequential(
#     (0): ConvBNReLU(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace)
#     )
#     (1): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace)
#         )
#         (1): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace)
#         )
#         (2): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (3): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace)
#         )
#         (2): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (4): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144, bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace)
#         )
#         (2): Conv2d(144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace)
#         )
#         (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace)
#         )
#         (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace)
#         )
#         (2): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (8): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (9): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (10): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (11): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace)
#         )
#         (2): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (12): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace)
#         )
#         (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (13): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace)
#         )
#         (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (14): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace)
#         )
#         (2): Conv2d(576, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (15): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace)
#         )
#         (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (16): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace)
#         )
#         (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (17): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace)
#         )
#         (2): Conv2d(960, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (18): ConvBNReLU(
#       (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace)
#     )
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.2)
#     (1): Linear(in_features=1280, out_features=1090, bias=True)
#   )
# )

# %%
visualize_model(model2)

# %% [markdown]
# ---
# ## data preprocesing

# %%
from glob import glob
from tqdm import tqdm_notebook as tqdm
import os
import subprocess

data_dir = 'LG-orignal-video\\images_full' # /로 나누면 윈도에서 에러남
data_dir_new = 'LG-orignal-video\\view'
# data_dir = 'C:\\Users\\LSW\\Downloads\\hand-new' # /로 나누면 윈도에서 에러남
# data_dir_new = 'C:\\Users\\LSW\\Downloads\\hand-new2'

os.mkdir(os.path.join(data_dir_new, 'train'))
os.mkdir(os.path.join(data_dir_new, 'val'))

for d in os.listdir(data_dir):
    print(d)
    for idx, fn in enumerate(tqdm(os.listdir(os.path.join(data_dir, d)))):
        if idx>0 and idx%7==0:
            if not os.path.isdir(os.path.join(data_dir_new, 'val', d)):
                os.mkdir(os.path.join(data_dir_new, 'val', d))
            command = ['cmd', '\/c', 'copy',  os.path.join(data_dir, d, fn) , os.path.join(data_dir_new, 'val', d, d+'_'+str(idx)+'.jpg')]
        else:
            if not os.path.isdir(os.path.join(data_dir_new, 'train', d)):
                os.mkdir(os.path.join(data_dir_new, 'train', d))            
            command = ['cmd', '\/c', 'copy',  os.path.join(data_dir, d, fn) , os.path.join(data_dir_new, 'train', d, d+'_'+str(idx)+'.jpg')]
            
        subprocess.check_output(command)
# Out:
# 1MILLION-PERFUME
# A Jupyter Widget
# 4GF-SUPER PURE CLEAR GEL
# A Jupyter Widget
# 6GF+-PROTEOGLYCAN SKIN CARE CREAM
# A Jupyter Widget
# 6XCREAM-TREATROMM 6 CREAM
# A Jupyter Widget
# 9WISHES-HYDRA AMPULE SERUM
# A Jupyter Widget
# A DERMA-PHYS AC PURIFYING FOAMING GEL
# A Jupyter Widget
# A2H-CURL UP ESSENCE
# A Jupyter Widget
# ABLE C_C-미샤M 비비 부머
# A Jupyter Widget
# ACAI BERRY-MICELLAR CLEANSING FACE SCRUB GEL
# A Jupyter Widget
# ACNES-CLEAR_WHITE FOAMING WASH
# A Jupyter Widget
# ACNES-DERMA RELIEF ESSENCE LOTION
# A Jupyter Widget
# ACURE-THE ESSENTIALS MOROCCAN ARGAN OIL
# A Jupyter Widget
# ACWELL-AQUA CLINITY CREAM
# A Jupyter Widget
# AESTURA-ATOBARRIER365
# A Jupyter Widget
# AGE20_S-AURORA ESSENTIAL CREAM
# A Jupyter Widget
# AGE20_S-CELL BOUNCE CONCENTRATED SERUM
# A Jupyter Widget
# AGE20_S-ESSENCE COVER FACT TX
# A Jupyter Widget
# AGE20_S-ESSENCE COVER FACT VX
# A Jupyter Widget
# AGE20_S-essence cover tx
# A Jupyter Widget
# AGE20_S-HYDRA SYNERGY CREAM
# A Jupyter Widget
# AGE20_S-INTENSE MOISTURE CREAM
# A Jupyter Widget
# AGE20_S-REAL CALENDULA EYE_FACE CREAM
# A Jupyter Widget
# AGE20_S-ULTRA MOISTURE ESSENCE
# A Jupyter Widget
# AGE20_S-에센스 쿠션
# A Jupyter Widget
# AHC-AGELESS REAL EYE CREAM FOR FACE
# A Jupyter Widget
# AHC-AGELESS REAL EYE CREAM FOR FACE_2
# A Jupyter Widget
# AHC-Ageless Real Eye ream for Face
# A Jupyter Widget
# AHC-Aura Secret Toneup Cream
# A Jupyter Widget
# AHC-Capture Hyaluronic
# A Jupyter Widget
# AHC-Natural Vita Sun Stick
# A Jupyter Widget
# AHC-NATURE PLUS SUNSTIC
# A Jupyter Widget
# AHC-ONLY FOR MAN LOTION
# A Jupyter Widget
# AHC-PERFECT DUAL COVER CUSHION 23
# A Jupyter Widget
# AHC-REAL ACTIVE BLENDING CREAM
# A Jupyter Widget
# AHC-REAL ACTIVE PERFECTION CREAM
# A Jupyter Widget
# AHC-REAL GOLD SERUM
# A Jupyter Widget
# AHC-REAL RADIANCE SERUM
# A Jupyter Widget
# AHC-REAL SYNERGY OIL
# A Jupyter Widget
# AHC-THE REAL EYE CREAM FOR FACE
# A Jupyter Widget
# AHC-ULTIMATE REAL EYE CREAM FOR FACE
# A Jupyter Widget
# AHC-VITAL BLACK SEED TONER
# A Jupyter Widget
# ALGOLOGIE-RICHESSE DES VAGUES
# A Jupyter Widget
# ALOE VERA-ALOE MOISTURIZING BRIGHT CARE
# A Jupyter Widget
# ALPECIN-COFFEIN SHAMPOO
# A Jupyter Widget
# AMOREPACIFIC-CONTOURE LIFT SKIN DEFINING CREME
# A Jupyter Widget
# AMOS-AGE CONTROL SAMPOO
# A Jupyter Widget
# AMOS-ANTI AGING CARE AGE CONTROL
# A Jupyter Widget
# AMOS-REPAIR FORCE THERAPY ESSENTIAL OIL
# A Jupyter Widget
# ANDALOUS NATURALS-AGE DEFYING NIGHT REPAIR CREAM
# A Jupyter Widget
# ANESSA-AQUA BOOSTER
# A Jupyter Widget
# ANNASUI-PERFUME
# A Jupyter Widget
# APIEU-POWER BLOCK SUN BASE
# A Jupyter Widget
# APIEU-PURE BLOCK
# A Jupyter Widget
# AQUAVELVA-Sensitive 5 in 1 after shave balm
# A Jupyter Widget
# AQUAXL-MAKE UP FOR EVER
# A Jupyter Widget
# ARITAUM-MONO EYES
# A Jupyter Widget
# ARITAUM-MONO EYES MISS MONO
# A Jupyter Widget
# ARITAUM-MONO EYES PURPLE EYES
# A Jupyter Widget
# ARITAUM-MONO EYES SOCIAL LITE
# A Jupyter Widget
# ARITAUM-SUGARBALL VELVET CHEEK COLOR
# A Jupyter Widget
# AROMATICA-ALOW MINERAL SUNSCREEN
# A Jupyter Widget
# AROMATICA-natural tinted sun cream
# A Jupyter Widget
# ASIS TOBE-Hyaluronic Essential Toner
# A Jupyter Widget
# ATOMY-EVENING CARE PEELING GEL
# A Jupyter Widget
# ATOMY-SKIN CARE SYSTEM THE FAME LOTION
# A Jupyter Widget
# ATOMY-Sunscreen SPF 50+ PA+++
# A Jupyter Widget
# ATOPALM-MOISTURE BALANCING CREAM
# A Jupyter Widget
# ATOPALM-SOOTHING GEL LOTION
# A Jupyter Widget
# ATOPALM-TOP TO TOE WASH
# A Jupyter Widget
# AVEDA-BOTANICAL KINETICS HYDRORATING LOTION
# A Jupyter Widget
# AVEDA-DAMAGE REMEDY
# A Jupyter Widget
# AVEENO-DAILY MOISTURIZING
# A Jupyter Widget
# AVENE-EAU THERMAL MIST
# A Jupyter Widget
# A_PIEU-MINERAL MONO SHADOW
# A Jupyter Widget
# A_PIEU-POWER BLOCK SUN BASE
# A Jupyter Widget
# BAMBOO-COOL WATER SOOTHING GEL
# A Jupyter Widget
# BANANABOAT-ALOE VERA GEL
# A Jupyter Widget
# BANILACO-프라임 프라이머 클래식
# A Jupyter Widget
# BATH_BODY WORKS-HELLO BEAUTIFUL ULTRA SHEA BODY CREAM
# A Jupyter Widget
# BATH_BODY WORKS-PRETTY AS A PEACH BODY LOTION
# A Jupyter Widget
# BATH_BODY WORKS-SUPER SOFT BODY BUTTER SHEA BUTTER COCONUT OIL
# A Jupyter Widget
# BEAUTYMORY-CRYSTAL EXPERT BB CREAM
# A Jupyter Widget
# BELIF-BELIEVE IN TRUTH CREAM
# A Jupyter Widget
# BELIF-BERGAMOT HERBAL EXTRACT TONER
# A Jupyter Widget
# BELIF-CREAMY MOISTURIZER DEEP MOIST
# A Jupyter Widget
# BELIF-MANOLOGY MOISTURIZER AQUA BOMB
# A Jupyter Widget
# BELIF-STRESS SHOOTER CICA BOMB CREAM
# A Jupyter Widget
# BELIF-THE TRUE CREAM AQUA BOMB
# A Jupyter Widget
# BELIF-THE TRUE CREAM MOISTURIZING BOMB
# A Jupyter Widget
# BELIF-UV PROTECTOR DAILY SUNSCREEN GEL
# A Jupyter Widget
# BENEFIC-CHA CHA TINT
# A Jupyter Widget
# BENEFIC-DANDELION BLUSHER
# A Jupyter Widget
# BENEFIC-HIGH BEAM
# A Jupyter Widget
# BENEFIC-SUGARBOMB
# A Jupyter Widget
# BENEFIC-THE PORE FESSIONAL
# A Jupyter Widget
# BENEFIT-DANDELION
# A Jupyter Widget
# BENEFIT-DANDELION BLUSH
# A Jupyter Widget
# BENEFIT-DANDELION BLUSHER
# A Jupyter Widget
# BENEFIT-the porefessional pearl primer
# A Jupyter Widget
# BENIZOIE-MILK BODY LOTION
# A Jupyter Widget
# BENIZOIE-PERFECT SUN PROTECTOR
# A Jupyter Widget
# BEVELY HILLS-POLO CLUB JOY
# A Jupyter Widget
# BEYOND-ANGEL AQUA
# A Jupyter Widget
# BEYOND-ANGEL AQUA DAILY BIG TONER
# A Jupyter Widget
# BEYOND-ANGEL AQUA DAILY BIG TONER SUPER SIZE
# A Jupyter Widget
# BEYOND-ANGEL AQUA DAILY CICA CREAM
# A Jupyter Widget
# BEYOND-ANGEL AQUA MOIST CREAM
# A Jupyter Widget
# BEYOND-ANGEL AQUA MOIST CREAM SUPER SIZE
# A Jupyter Widget
# BEYOND-ANGEL KIDS BODY LOTION
# A Jupyter Widget
# BEYOND-ARGAN THERAPY CURLING ESSENCE
# A Jupyter Widget
# BEYOND-CLASSIC HAND CREAM INTENSIVE TOTAL RECOVERY
# A Jupyter Widget
# BEYOND-DISNEY ECO CREAM
# A Jupyter Widget
# BEYOND-ECO DAILY DEFENCE AQUA SUN GEL
# A Jupyter Widget
# BEYOND-ECO DAILY DEFENSE SKIN TONE
# A Jupyter Widget
# BEYOND-HOMME ALL IN ONE FORMULA
# A Jupyter Widget
# BEYOND-LIFTING MOISTURE THE NUTCRACKER
# A Jupyter Widget
# BEYOND-OH MY SUN CREAM
# A Jupyter Widget
# BEYOND-PHYTO AQUA CREAM
# A Jupyter Widget
# BEYOND-PHYTO AQUA MOITURE CREAM
# A Jupyter Widget
# BEYOND-PHYTO AQUA WATER SUN BASE WITH SAP COMPLEX
# A Jupyter Widget
# BIO OIL-PURECELLIN OIL
# A Jupyter Widget
# BIODERMA-ATODERM
# A Jupyter Widget
# BIODERMA-ATODRM PP BAUME ULTRA NOURISHING BALM
# A Jupyter Widget
# BIODERMA-HYDRABIO CREAM
# A Jupyter Widget
# BIODERMA-HYDRABIO H2O SOLUTION MICELLAIRE
# A Jupyter Widget
# BIODERMA-SENSIBIO H2O MAKEUP REMOVER_1
# A Jupyter Widget
# BIODERMA-SENSIBIO H2O MAKEUP REMOVER_2
# A Jupyter Widget
# BIODERMA-SENSIBIO H2O MAKE_UP REMOVER
# A Jupyter Widget
# BIOSILK-SILK THERAPY ENRICHED ACTION HAIR TREATMENT
# A Jupyter Widget
# BIOSILK-SILK THERAPY FAROUK HAIR TREATMENT
# A Jupyter Widget
# BIOSILK-SILK THERAPY HAIR TREATMENT
# A Jupyter Widget
# BIOTHERM-Body Refirm Stretch Oil
# A Jupyter Widget
# BIOTHERM-EAU VITAMINEE PERFUMED BODY MILK
# A Jupyter Widget
# BIOTHERM-HOMME AQUAPOWER FRESH LOTION IN GEL
# A Jupyter Widget
# BIOTHERM-HOMME AQUAPOWER_1
# A Jupyter Widget
# BIOTHERM-HOMME AQUAPOWER_2
# A Jupyter Widget
# BIOTHERM-HOMME FORCE SUPREME INSTANT
# A Jupyter Widget
# BIOTHERM-HOMME FORCE SUPREME SERUM
# A Jupyter Widget
# BLACK BEAN-DASHU BLACK BEAN SUPER HARD SPRAY
# A Jupyter Widget
# BLACK-LIP STICK
# A Jupyter Widget
# BLACKMORES-NATURAL VITAMINE E CREAM
# A Jupyter Widget
# BLGARI-POUR HOMME PERFUME
# A Jupyter Widget
# BOBBI BROWN-CALYPSO CORAL
# A Jupyter Widget
# BOBBI BROWN-EYE SHADOW
# A Jupyter Widget
# BOBBI BROWN-FRESH MELON24
# A Jupyter Widget
# BOBBI BROWN-Long Water Cream Shadow Stick
# A Jupyter Widget
# BOBBI BROWN-LONG WEAR EVEN FOUNDATION
# A Jupyter Widget
# BOBBI BROWN-POT ROUGE FOR LIPS AND CHEEKS
# A Jupyter Widget
# BOBBI BROWN-PRIMER PLUS PROTECTION
# A Jupyter Widget
# BONABELLA-ROSE WATER TONE UP CREAM
# A Jupyter Widget
# BONABELLA-UV PROTECTION TONE UP DAILY SUN BLOCK
# A Jupyter Widget
# BONABELLA-UV WATER SHIELD SUN BLOCK
# A Jupyter Widget
# BONAMEDUSA-ALPI SNOW CREAM
# A Jupyter Widget
# BONAMEDUSA-FACE WAVE DELETE
# A Jupyter Widget
# BONAMEDUSA-FIXER_AMPOULE X MIST
# A Jupyter Widget
# BONAMEDUSA-ORANGE SKIN DELETE
# A Jupyter Widget
# BOOTS-cucumber moisturising lotion for a smooth day
# A Jupyter Widget
# BORMTREE-GOAT MILK TONE UP CREAM
# A Jupyter Widget
# BOTANITY-FLAVON SERUM
# A Jupyter Widget
# BRING GREEN-ARTEMISIA CALMING CREAM
# A Jupyter Widget
# BUBERRY-PERFUME CLASSIC WOMEN
# A Jupyter Widget
# BURBERRY-WEEKEND FOR MEN MINIATURE PERFUME
# A Jupyter Widget
# BURBERY-BRIT SHEER PERFUME
# A Jupyter Widget
# BURT_S BEES-COCONUT FOOT CREAME
# A Jupyter Widget
# BVLGARI-AQVA ATLANTIQVE
# A Jupyter Widget
# BVLGARI-BLV POUR HOMME
# A Jupyter Widget
# BVLGARI-OMNIA CORAL FOR WOMEN
# A Jupyter Widget
# BVLGARI-OMNIA EAU DE PARFUM
# A Jupyter Widget
# BYREDO-ROSE OF NO MANS_S LAND EAU DE PARFUM
# A Jupyter Widget
# CALVIN KLEIN-CK ONE SKIN MOISTURIZER
# A Jupyter Widget
# CALVIN KLEIN-CK2 PERFUME
# A Jupyter Widget
# CANMAKE-PERFECT BROWN EYES
# A Jupyter Widget
# CAPTURE-REVITE SOLUTION AMPOULE
# A Jupyter Widget
# CAREZONE-A CURE 13 TROUBLE CALMING CREAM
# A Jupyter Widget
# CAREZONE-A CURE CLARIFYING EMULSION EX
# A Jupyter Widget
# CAREZONE-A CURE SKIN SURFACE CLEARING TONE_TEXTURE SERUM
# A Jupyter Widget
# CAREZONE-DOCTOR SOLUTION A CURE CLARIFYING EMULSION
# A Jupyter Widget
# CAREZONE-DOCTOR SOLUTION A CURE CLARIFYTING TONER EX
# A Jupyter Widget
# CAREZONE-NORDENAU WATER ESSENCE
# A Jupyter Widget
# CAREZONE-NORDENAU WATER TONER
# A Jupyter Widget
# CAROLINA HERRERA-L_EAU EAU FRAICHE 100ML SPRAY
# A Jupyter Widget
# CAUDALIE-EAU DE BEAUTE BEAUTY ELIXIR
# A Jupyter Widget
# CAUDALIE-HUILE DIVINE DIVINE OIL
# A Jupyter Widget
# CAUDALIE-VINOPERFECT RADIANCE SERUM
# A Jupyter Widget
# CELIMA-DERMA NATURE FRESh BLACKHEAD JOJOBA CLEANSING OIL
# A Jupyter Widget
# CELL FUSION C-CURE SUNCREEN 100
# A Jupyter Widget
# CELL FUSION C-LASER SUN SCREEN 100
# A Jupyter Widget
# CELL FUSION C-LASER SUNSCREEN 100
# A Jupyter Widget
# CELLSKIN-RENEWAL DUAL EFFECT SERUM
# A Jupyter Widget
# CENTELLIAN24-Centellian Madeca Skin Emulsion
# A Jupyter Widget
# CENTELLIAN24-Madeca Cream
# A Jupyter Widget
# CENTELLIAN24-MADECA CREAM POWER BOOSTING FORMULA
# A Jupyter Widget
# CENTELLIAN24-MADECA MICRO SERUM
# A Jupyter Widget
# CENTELLIAN24-MADECA SOLUTION ESSENCE
# A Jupyter Widget
# CENTELLIAN24-MADECA TONING ESSENCE TREATMENT
# A Jupyter Widget
# CENTELLIAN24-MADECA UV DEFENCE SUN CUSHION
# A Jupyter Widget
# CENTELLIAN24-MADECA UV PROTECTION SUN STICK
# A Jupyter Widget
# CERACARE-RICH LOTION
# A Jupyter Widget
# CETAPHIL-MOISTURISING LOTION
# A Jupyter Widget
# CETAPHIL-MOISTURIZING LOTION
# A Jupyter Widget
# CEZANNE-MIX COLOR CHEEK
# A Jupyter Widget
# CFEAD05F-224D_4DE0_AB61_041FDEF2D19C_junghyuk lee
# A Jupyter Widget
# CHAMPS ELYSEES-EAU DE TOILETTE GUERLAIN FOR WOMEN
# A Jupyter Widget
# CHANEL-ALLURE
# A Jupyter Widget
# CHANEL-COCO MADEMISELLE PERFUME
# A Jupyter Widget
# CHANEL-COMPLETE CORRECTION CREAM
# A Jupyter Widget
# CHANEL-DEMAQUILLANT YEUX INTENSE
# A Jupyter Widget
# CHANEL-INIMITABLE EXTREME MASCARA
# A Jupyter Widget
# CHANEL-JOUES CONTRASTE
# A Jupyter Widget
# CHANEL-LE BLANC Light Creator Brightening Makeup Base
# A Jupyter Widget
# CHANEL-N5 PERFUME
# A Jupyter Widget
# CHANEL-NO.5 EAU DE TOILETTE SPRAY
# A Jupyter Widget
# CHANEL-NO5
# A Jupyter Widget
# CHANEL-POWDER BLUSH 86 DISCREATION
# A Jupyter Widget
# CHANEL-ROUGE ALLURE GLOSS 16 EXTASE
# A Jupyter Widget
# CHANEL-ROUGE ALLURE LIP STICK
# A Jupyter Widget
# CHANEL-STYLO EYE LINER
# A Jupyter Widget
# CHARMZONE-ALBA TROSS DAILY SUN
# A Jupyter Widget
# CHARMZONE-ANTI_WRINKLE PINK OIL IN SERUM
# A Jupyter Widget
# CHARMZONE-Control Cream 225g
# A Jupyter Widget
# CHARMZONE-DeAge CRD_Softening Emulsion
# A Jupyter Widget
# CHARMZONE-DeAge Red Addition Nutrient Cream
# A Jupyter Widget
# CHARMZONE-DeAge Red Addition Skin Toner
# A Jupyter Widget
# CHARMZONE-DeAge Red Edition Eye cream
# A Jupyter Widget
# CHARMZONE-ROSY VOLUME HEARTZONE CREAM
# A Jupyter Widget
# CHARMZONE-Top Class Royal Eye Cream
# A Jupyter Widget
# CHICA Y CHICO-ONE SHOT EYE PALETTE
# A Jupyter Widget
# CHLOE-EAU DE PERFUME
# A Jupyter Widget
# CHOSUNGAH-C_T Blend Easy Firming
# A Jupyter Widget
# CHOSUNGAH-슈퍼 핏 커버 파운데이션 2X 1호
# A Jupyter Widget
# CLAIRE_S KOREA-GUERISSON 9 COMPLEX
# A Jupyter Widget
# CLAIRE_S KOREA-GUERISSON MEN_S ONE
# A Jupyter Widget
# CLAIRE_S KOREA-GUERISSON SIGNATURE OIL SERUM
# A Jupyter Widget
# CLARINS-EXTRA FIRMING NECK
# A Jupyter Widget
# CLARINS-SOIN COMPLET
# A Jupyter Widget
# CLEAN AND CLEAR-페이셜 포밍 클렌저
# A Jupyter Widget
# CLEAN-WARM COTTON EAU DE PERFUME
# A Jupyter Widget
# CLEDBEL-24K GOLD SERUM
# A Jupyter Widget
# CLEDBEL-FACE LIFT PROGRAM HYDRA POWER LIFTING SERUM
# A Jupyter Widget
# CLEDBEL-GLUTA POWER WHITENING BOOSTER SERUM
# A Jupyter Widget
# CLINIQUE-BLENDED FACE POWER
# A Jupyter Widget
# CLINIQUE-CHUBBY STICK MOISTURIZING LIP COLOUR BALM
# A Jupyter Widget
# CLINIQUE-CLARIFYING MOISTURE LOTION
# A Jupyter Widget
# CLINIQUE-LIP_EYE MAKEUP PALETTE 5X COLOUR SURGE LIPSTICK
# A Jupyter Widget
# CLINIQUE-MOISTURE SURGE 72HOUR AUTO REPLENISHING
# A Jupyter Widget
# CLINIQUE-MOISTURE SURGE INTENSE SKIN FORTIFYING HYDRATOR GEL CREME
# A Jupyter Widget
# CLIO-ART SHADOW 17 NIGHT BLUE
# A Jupyter Widget
# CLIO-KILL BROW AUTO HARD BROW PENCIL 5 GRAY BROWN
# A Jupyter Widget
# CLIO-ROUSE HEEL NOODIE BROWN
# A Jupyter Widget
# CLIO-SHARP SO SIMPLE WARTERPROOF PENCIL LINER
# A Jupyter Widget
# CLIO-VEIGIN KISS SILKUID LIP
# A Jupyter Widget
# CNP LABORATORY-GREEN PROPOLIES PERFECT WRINKLE CORRECTOR
# A Jupyter Widget
# CNP LABORATORY-GREEN PROPOLIS ANTI_OXIDANT AMPULE
# A Jupyter Widget
# CNP LABORATORY-Green Propolis Engery Recharging Emulsion
# A Jupyter Widget
# CNP LABORATORY-Green Propolis Intense Firming Creem
# A Jupyter Widget
# CNP LABORATORY-Green Propolis Skin Hydrating Enhancer
# A Jupyter Widget
# CNP LABORATORY-HOME ACTIVE SUN BB CREAM
# A Jupyter Widget
# CNP LABORATORY-Tune_sun care up proection sun
# A Jupyter Widget
# CONAD-CREMA SOLARE VISO
# A Jupyter Widget
# CONDENSE-BRIGHT AND SOFT LOTION
# A Jupyter Widget
# COSMEDICS-ULOS
# A Jupyter Widget
# CREMA IDRALIA-OFFICLNA PROFUMO FARMACEUTLCA
# A Jupyter Widget
# DAISO-GREENTEA NAIL REMOVER
# A Jupyter Widget
# DARPHIN-HYDRASKIN RICH CREAM
# A Jupyter Widget
# DARPHIN-INTREAL TONER
# A Jupyter Widget
# DERMA B-EVERY DAY SUN BLOCK
# A Jupyter Widget
# DERMA PLATZ-ACTIVE LAYERED CREAM
# A Jupyter Widget
# DERMALIFT-CENTELLA REPAIR AMPOULE
# A Jupyter Widget
# DERMATORY-AZULENE HYPOALLERGENIC CICA CREAM
# A Jupyter Widget
# DEWY TREE-ULTRA VITALIZING SNAIL CREAM_1
# A Jupyter Widget
# DEWY TREE-ULTRA VITALIZING SNAIL CREAM_2
# A Jupyter Widget
# DEWYTREE-CLEAN LAB HEALTHY FOAM
# A Jupyter Widget
# DIOR-ADDICT LIP CLOW
# A Jupyter Widget
# DIOR-DIORSKIN FOREVER EXTREME CONTROL
# A Jupyter Widget
# DIOR-Jabore pearl eau de parfum
# A Jupyter Widget
# DIOR-JADORE WOMEN EAU DE PERFUME
# A Jupyter Widget
# DIOR-LIP GLOW COLOR REVIVER BALM_1
# A Jupyter Widget
# DIOR-LIP GLOW-COLOR REVIVER BALM_2
# A Jupyter Widget
# DIOR-LIP MAXIMIZER
# A Jupyter Widget
# DIOR-ROSE EN
# A Jupyter Widget
# DIPTYQUE-DO SON
# A Jupyter Widget
# DIPTYQUE-DOSON COLLECTION 34 BOULEVARD SAINT FERMAIN
# A Jupyter Widget
# DIPTYQUE-EAU DES SENS HAIR MIST
# A Jupyter Widget
# DMCK-CLEAN AC CREAM SOOTHING COMBINATION
# A Jupyter Widget
# DOCTORCOS-SNOW WHITE WATER GLOW MASK
# A Jupyter Widget
# DOLCE_GABBANA-LIGHT BLUE_1
# A Jupyter Widget
# DOLCE_GABBANA-LIGHT BLUE_2
# A Jupyter Widget
# DOLCE_GABBANA-THE ONE GENTLEMAN
# A Jupyter Widget
# DOUBLE RICH-ART DE PEAU HAIR GEL
# A Jupyter Widget
# DPC-PINK AURA CUSHION SA
# A Jupyter Widget
# DR.AG PLUS-CICAREPAIR PEELING PAD
# A Jupyter Widget
# DR.AG PLUS-INTERSIVE DERMA CICA SALVE CREAM
# A Jupyter Widget
# DR.G-A CLEAR BALANCING MOISTURIZER
# A Jupyter Widget
# DR.G-AIRY SKIN UP SUN
# A Jupyter Widget
# DR.G-BLACK SNAIL CREAM
# A Jupyter Widget
# DR.G-BLACK SNAIL CREAM_1
# A Jupyter Widget
# DR.G-BLACK SNAIL CREAM_2
# A Jupyter Widget
# DR.G-BLACK SNAIL CREAM_3
# A Jupyter Widget
# DR.G-BLACK SNAIL CREAM_4
# A Jupyter Widget
# DR.G-BRIGHTENING PEELING GEL
# A Jupyter Widget
# DR.G-BRIGHTENING UP SUN
# A Jupyter Widget
# DR.G-FILAGRIN BARRIER CREAM
# A Jupyter Widget
# DR.G-GREEN MILD UP SUN
# A Jupyter Widget
# DR.G-RED BLEMISH CLEAR CREAM
# A Jupyter Widget
# DR.JART+-BB BEAUTY BALM
# A Jupyter Widget
# DR.JART+-HOLY SKIN SOOTHING BALM
# A Jupyter Widget
# DR.JART-FOUNDATION
# A Jupyter Widget
# DR.PEPTI+-CENTELLA TONER
# A Jupyter Widget
# DR.YOUNG-ANTI PORE ERASER BALM
# A Jupyter Widget
# DRG-BLACK SNAIL CREAM
# A Jupyter Widget
# D_ALBA-WHITE TROUBLE FIRST SPREY SERUM
# A Jupyter Widget
# E45-DERMATOLOGICAL CREAM
# A Jupyter Widget
# ECLADO-OIL FREE SUN CREAM
# A Jupyter Widget
# ECLADO-Real White eRaser Cream
# A Jupyter Widget
# ECLADO-regene Blemish Balm
# A Jupyter Widget
# EDP-DOMINIQUE ROPION GERANIUM TOUR MONSIEUR
# A Jupyter Widget
# ELASTINE-Silk repair recovery oil essence
# A Jupyter Widget
# ELENSILIA CPP-PLACENTA 80 MILLESIS CREAM
# A Jupyter Widget
# ELENSILIA-ESCARGOT ORIGINAL REPAIR BEE VENOM MIST
# A Jupyter Widget
# ELIZABETH ARDEN-EIGHT HOUR CREAM
# A Jupyter Widget
# ENJOY-Perfect Daily Sun Cream
# A Jupyter Widget
# ENPRANI-ONE TOUCH SUN POWDER
# A Jupyter Widget
# ESCADA-HOMME ESSENCE EMULSION
# A Jupyter Widget
# ESPOIR-PRO TAILOR FOUNDATION
# A Jupyter Widget
# ESPOIR-PRO TAILOR FOUNDATION MEDIUM2
# A Jupyter Widget
# ESPOIR-PRO TAILOR LIQUID FOUNDATION EX
# A Jupyter Widget
# ESTEE LAUDER-ADVANCED NIGHT REPAIR
# A Jupyter Widget
# ESTEE LAUDER-Advanced Night Repair Synchronized Complex II
# A Jupyter Widget
# ESTEE LAUDER-ADVANCED NIGHT REPAIR_2
# A Jupyter Widget
# ESTEE LAUDER-DOUBLE WEAR
# A Jupyter Widget
# ESTEE LAUDER-DOUBLE WEAR STAY IN PLACE MAKEUP_1
# A Jupyter Widget
# ESTEE LAUDER-DOUBLE WEAR STAY IN PLACE MAKEUP_2
# A Jupyter Widget
# ESTEE LAUDER-Double Wear Stay_in_Place Makeyp
# A Jupyter Widget
# ESTEE LAUDER-DOUBLE WEAR ZERO MASCARA
# A Jupyter Widget
# ESTEE LAUDER-PURE COLOR CRYSTAM LIPSTIC 01 CRYSTAL BABY CREME
# A Jupyter Widget
# ESTEE LAUDER-PURE COLOR LOVE LIPSTICK_1
# A Jupyter Widget
# ESTEE LAUDER-PURE COLOR LOVE LIPSTICK_2
# A Jupyter Widget
# ESTEE LAUDER-SUMPTUOUS KNOCKOUT MASCARA
# A Jupyter Widget
# ESTETICA-HYDRA MULTI THERAPY
# A Jupyter Widget
# ESTHEMORE-컬링 에센스 2X
# A Jupyter Widget
# ETUDE HOUSE-DOUBLE LASTING FOUNDATION
# A Jupyter Widget
# ETUDE HOUSE-GLOW ON BASE
# A Jupyter Widget
# ETUDE HOUSE-PLAY COLOR EYES
# A Jupyter Widget
# ETUDE HOUSE-SOON JUNG MOIST RELIEF ALL IN ONE GEL
# A Jupyter Widget
# ETUDE HOUSE-UV DOUBLE CUT SUN GEL
# A Jupyter Widget
# EUBOS-HAUT RUHE CREAM
# A Jupyter Widget
# EUCERIN-DERMATOCLEAN CLARIFYING TONER
# A Jupyter Widget
# EUCERIN-HYALURON FILLER VOLUME LIFT
# A Jupyter Widget
# EVAS-LEMONADE MOISTURE HAND CREAM
# A Jupyter Widget
# EVOLUDERM-EAU MICELLAIRE CLEANSING WATER
# A Jupyter Widget
# EXCELMAKE-FIVE LAYERS SHADOW
# A Jupyter Widget
# FACE IT-RADIANCE MAKEUP BASE
# A Jupyter Widget
# FAIRY TALES-ROSEMARY HAIR SPRAY
# A Jupyter Widget
# FAISIES-MAYBELINE VOLUME EXPRESS
# A Jupyter Widget
# FERRARI-SCUDERIA BLACK EAU DE TOILETTE SPRAY
# A Jupyter Widget
# FERRARI-UOMO PERFUME
# A Jupyter Widget
# FIRST AID BEAUTY-ULTRA REPAIR CREAM
# A Jupyter Widget
# FIRSTLAB-PROBIOTIC REVERSE CREAM
# A Jupyter Widget
# FIXX-ALL DAY GLOW MAKEUP SETTING
# A Jupyter Widget
# FO ARUM-NATURAL BB CREAM
# A Jupyter Widget
# FRESH-SUGAR FACE POLISH
# A Jupyter Widget
# FROM NATURE-ALOEVERA PERFECT SUN BLOCK
# A Jupyter Widget
# FROM NATURE-COLLAGEN HYDRO HONEY ESSENCE
# A Jupyter Widget
# FRUIT OF THE EARTH-ALOE VERA 100_ GEL
# A Jupyter Widget
# FUERAIN-METEORITES TRAVEL TOUCH FACE POWDER
# A Jupyter Widget
# F_CO-BANILA CO PRIME PRIMER BB CREAM
# A Jupyter Widget
# GD3.4-HAIR ENHANCER AMPOULE
# A Jupyter Widget
# GINGER-LAURA MERCIER
# A Jupyter Widget
# GIORGIO ARMANI-ACQUA DI GIO POUR HOMME
# A Jupyter Widget
# GIORGIO ARMANI-LASTING SILK UV FOUNDATION
# A Jupyter Widget
# GIORGIO ARMANI-LIP MAGNET
# A Jupyter Widget
# GOODAL-DOUBLE BRIGHT DDAY AMPOULE
# A Jupyter Widget
# GOODAL-DOUBLE BRIGHT WHITENING C AMPOULE
# A Jupyter Widget
# GOODAL-GREEN TANGERINE VITA C DART SPOT SERUM
# A Jupyter Widget
# GOODAL-GREEN TAUGERINE VITA C CREAM
# A Jupyter Widget
# GOODAL-PREMIUM SNAIL TONE UP CREAM
# A Jupyter Widget
# GOONGBE-FRESS SUN LOTION
# A Jupyter Widget
# GREEN FINGER-AFTER SUN CLEANSING
# A Jupyter Widget
# GREEN FINGER-INTENSIVE SUN BALM
# A Jupyter Widget
# GREEN FINGER-KIDS FACIAL LOTION
# A Jupyter Widget
# GREEN FINGER-MY KIDS KIDS LOTION
# A Jupyter Widget
# GREEN FINGER-야외놀이 선로션 SPF PA 45
# A Jupyter Widget
# GREEN FINGER-야외놀이 선크림
# A Jupyter Widget
# GREENFINGER-ULTRA LOTION
# A Jupyter Widget
# HADALABO-GOKU JYUN PERFECT GEL
# A Jupyter Widget
# HADALABO-ROHTO HADALABO GOKUJUN HYALURONIC LOTION MIST
# A Jupyter Widget
# HADALABO-SHIRO JYUN CREAM
# A Jupyter Widget
# HADALABO-SHIRO JYUN Lotion
# A Jupyter Widget
# HADALABO-SHIRO JYUN MILK
# A Jupyter Widget
# HADALABO-기와미츠 유무워터 하또무기_비타
# A Jupyter Widget
# HAIR PLUS-OH FRESH DEEP HERBAL SCALP CLEANSING SHAMPOO
# A Jupyter Widget
# HAIR PLUS-VELVET PROTEIN BOND NUTRI INJECTION AMPOULE
# A Jupyter Widget
# HANGYEOL-SUN PROTECTOR WITH BLISS
# A Jupyter Widget
# HANSKIN-Caviar Gold BB Cream
# A Jupyter Widget
# HANYUL-PURE ARTEMISIA WATERY CALMING CREAM
# A Jupyter Widget
# HAPPY BATH-AQUA MOISTURE SUN LOTION
# A Jupyter Widget
# HAPPY BATH-Deep Cleansing Form
# A Jupyter Widget
# HAPPY BATH-FACIAL YOGURT FOAM
# A Jupyter Widget
# HAPPY BATH-PERFECT SUN CREAM
# A Jupyter Widget
# HAZZYS MEN-RULE420 WHITENING SUN ALL IN ONE
# A Jupyter Widget
# HEALTH REVOLUTION_S-HERBAL FACE FOOD
# A Jupyter Widget
# HENVX-INSTANT HARI PLUS POWDER
# A Jupyter Widget
# HERA-AGE AWAY VITALIZING NIGHT MASK
# A Jupyter Widget
# HERA-AGE REVERSE CUSHION C13
# A Jupyter Widget
# HERA-BLACK CUSHION 21
# A Jupyter Widget
# HERA-BLACK CUSHION_1
# A Jupyter Widget
# HERA-BLACK CUSHION_2
# A Jupyter Widget
# HERA-BLACK CUSHION_3
# A Jupyter Widget
# HERA-BLACK FOUNDATION WEIGHTLESS COVER FIT FOUNDATION
# A Jupyter Widget
# HERA-BLINDNESS BLACK CUSHION
# A Jupyter Widget
# HERA-HD PERFECT FOUNDATION
# A Jupyter Widget
# HERA-MAGIC STARTER
# A Jupyter Widget
# HERA-MAKE UP FIXER
# A Jupyter Widget
# HERA-MAKE UP FIXER ALL DAY FITTING
# A Jupyter Widget
# HERA-SHADOW HOLIC 4D
# A Jupyter Widget
# HERA-SIGNIA CREAM
# A Jupyter Widget
# HERA-SUN MATE EXCELLENCE
# A Jupyter Widget
# HERA-SUN MATE PROTECTOR
# A Jupyter Widget
# HERA-UV MIST CUSHION COVER
# A Jupyter Widget
# HEROINE MAKE-SMOOTH LIQUID EYELINER
# A Jupyter Widget
# HIMALAYA HERBALS-REVITALIZING NIGHT CREAM
# A Jupyter Widget
# HIMALAYA-LIP BALM
# A Jupyter Widget
# HIMALAYA-NOURISHING SKIN CREAM
# A Jupyter Widget
# HOLIKA HOLIKA-GOOD CERA SUPER CERAMIDE MIST
# A Jupyter Widget
# HOLIKA HOLIKA-PEACE MATCHING SHADOW
# A Jupyter Widget
# HUGO-Element eau de toilette
# A Jupyter Widget
# IDIUOMO-SKIN TYPE TESTATO
# A Jupyter Widget
# ILDONG-Probiotic Cream
# A Jupyter Widget
# ILLI-TOTAL AGING CARE BODY LOTION
# A Jupyter Widget
# ILLIYOON-CERAMIDE ATO CONCENTRATE CREAM
# A Jupyter Widget
# ILLIYOON-PROBIOTICS SKIN BARRIER ESSENCE DROP
# A Jupyter Widget
# IMFROM-MUGWORT ESSENCE
# A Jupyter Widget
# INNESFREE-MY EYE SHADOW
# A Jupyter Widget
# INNISFREE-ALOE REVITAL SOOTHING GEL
# A Jupyter Widget
# INNISFREE-APPLE SEED LIB _ EYE MAKE UP REMOVER
# A Jupyter Widget
# INNISFREE-APPLE SEED LIP AND EYE MAKEUP REMOVER
# A Jupyter Widget
# INNISFREE-BIJA TROUBLE LOTION
# A Jupyter Widget
# INNISFREE-BLUEBERRY REBALANCING SKIN
# A Jupyter Widget
# INNISFREE-DERMA FORMULA PEELING CREAM
# A Jupyter Widget
# INNISFREE-eco nail remover
# A Jupyter Widget
# INNISFREE-EXTREME UV PROTECTION CREAM
# A Jupyter Widget
# INNISFREE-FOREST FOR MEN FRESH CLEANSING FOAM
# A Jupyter Widget
# INNISFREE-forest for men fresh skin Jeju phytoncide complex
# A Jupyter Widget
# INNISFREE-FOREST FOR MEN PORE CARE ALL IN ONE ESSENCE
# A Jupyter Widget
# INNISFREE-green barley Peeting Toner
# A Jupyter Widget
# INNISFREE-green tea lotion for men
# A Jupyter Widget
# INNISFREE-GREEN TEA SEED ESSENC IN LOTION
# A Jupyter Widget
# INNISFREE-green tea seed serum
# A Jupyter Widget
# INNISFREE-Green tea Skin for Men
# A Jupyter Widget
# INNISFREE-INTENSIVE LONG LASTIN SUNSCREEN
# A Jupyter Widget
# INNISFREE-JEJU CHERRY BLOSSOM SKIN
# A Jupyter Widget
# INNISFREE-JEJU ORCHID SKIN
# A Jupyter Widget
# INNISFREE-JEJU SPARKLING MOISTURE
# A Jupyter Widget
# INNISFREE-MOISTURIZING OIL SERUM
# A Jupyter Widget
# INNISFREE-MY DROP WATER MOISTURE
# A Jupyter Widget
# INNISFREE-NAIL REMOVER
# A Jupyter Widget
# INNISFREE-OLIVE REAL CLEANSING FOAM
# A Jupyter Widget
# INNISFREE-olive real essential oil Ex
# A Jupyter Widget
# INNISFREE-PERFECT 9 REPAIR CREAM EX
# A Jupyter Widget
# INNISFREE-PERFECT 9 REPAIR EYE CREAM
# A Jupyter Widget
# INNISFREE-perfect uv protection cream
# A Jupyter Widget
# INNISFREE-PERFECT UV PROTECTION CREAM(1)
# A Jupyter Widget
# INNISFREE-PERFECT9 REPAIR LOTION
# A Jupyter Widget
# INNISFREE-SOYBEAN ENERGY NECK CREAM
# A Jupyter Widget
# INNISFREE-SOYBEAN ENERGY OIL
# A Jupyter Widget
# INNISFREE-TRUECARE NON_NANO SUNSCREEN
# A Jupyter Widget
# INNISFREE-마이 블러셔 햇살 가득 장미
# A Jupyter Widget
# INNISFREE-비비드 후르츠 틴트 물 먹은 체리
# A Jupyter Widget
# INNODERM-INNODERM CREAM
# A Jupyter Widget
# IOPE-AIR CUSHION MOISTURE RESTING
# A Jupyter Widget
# IOPE-BIO ESSENCE INTENSIVE CONDITIONING
# A Jupyter Widget
# IOPE-BIO NIGHT MASK INTENSIVE RECHARGING
# A Jupyter Widget
# IOPE-CC
# A Jupyter Widget
# IOPE-DERMA REPAIR CICA CREAM
# A Jupyter Widget
# IOPE-DERMA REPAIR CLEAN SUN STICK
# A Jupyter Widget
# IOPE-EYEBROW AUTO PENCIL EX
# A Jupyter Widget
# IOPE-LIP STICK
# A Jupyter Widget
# IOPE-LIVE LIFT EMULSION
# A Jupyter Widget
# IOPE-LIVE LIFT SOFTENER
# A Jupyter Widget
# IOPE-MOIST CLEANSING OIL
# A Jupyter Widget
# IOPE-PERFECT SKIN BASE
# A Jupyter Widget
# IOPE-UV SHIELD
# A Jupyter Widget
# IPKN MAN-TOWER ACTIVE(LITE) ALL IN ONE PRO
# A Jupyter Widget
# ISA KNOX-365 SUN CREAM
# A Jupyter Widget
# ISA KNOX-Heating Drop Cream
# A Jupyter Widget
# ISA KNOX-HOMME SKIN CARE AFTERSHAVE
# A Jupyter Widget
# ISA KNOX-HYDRO LIFTING TREATMENT REPAIR SERUM
# A Jupyter Widget
# ISA KNOX-IDEAL RINGER MEDIHYALON DROP
# A Jupyter Widget
# ISA KNOX-MX_II PLATINUM ULTRA MOISTURE EMULSION
# A Jupyter Widget
# ISA KNOX-NOX LAB EYE CREAM RETINOL _ MOISTURE LIPOSOME
# A Jupyter Widget
# ISA KNOX-Powdery Cotton Sun Stick
# A Jupyter Widget
# ISA KNOX-Tervina LX Homme Regenerating Torner
# A Jupyter Widget
# ISA KNOX-THE PRESTIGE RE ACTIVE CONCENTRATING CREAM
# A Jupyter Widget
# ISA KNOX-THE PRESTIGE RE ACTIVE CONCENTRATING SERUM
# A Jupyter Widget
# ISA KNOX-THE PRESTIGE RE ACTIVE HYDRATING EMULSION
# A Jupyter Widget
# ISA KNOX-UV SUN PRO BEAUTY SUN
# A Jupyter Widget
# ISA KNOX-X2D2 PORE CORRECTOR SERUM
# A Jupyter Widget
# ISA NOX-POWDERY COTTON SUN STICK
# A Jupyter Widget
# ISOI-BR MOISTURIZIP
# A Jupyter Widget
# ISOI-PORE TIGHTENING FRESH GEL CREAM
# A Jupyter Widget
# IT_S SKIN-COLLAGEN NUTRITION EMULSION
# A Jupyter Widget
# IT_S SKIN-IT_S TOP BY ITALY SATIN LIP PENCIL
# A Jupyter Widget
# IT_S SKIN-POWER 10 FORMULA WR FACE _ BODY OIL MIST
# A Jupyter Widget
# I_M MEME-I_M SHADING PALETTE
# A Jupyter Widget
# J.ESTINA-PEARL FECTION FLOW FIXER
# A Jupyter Widget
# JAMINKYUNG-CARACOL ALL IN ONE CREAM
# A Jupyter Widget
# JIMMY CHOO-BODY LOTION
# A Jupyter Widget
# JIMMY CHOO-EAU DE TOILETTE
# A Jupyter Widget
# JIMMY CHOO-오드트휠렛
# A Jupyter Widget
# JJHO DERMA-D MOISTURE CREAM
# A Jupyter Widget
# JO MALONE-BLACKBERRY AND BAY COLOGNE
# A Jupyter Widget
# JO MALONE-BLOSSOM AND HONEY COLOGNE
# A Jupyter Widget
# JO MALONE-ENGLISH PEAR _ FREESIA
# A Jupyter Widget
# JO MALONE-LACKBERRY_BAY COLOGNE
# A Jupyter Widget
# JO MALONE-OSMANTHUS BLOSSOM COLOGNE
# A Jupyter Widget
# JO MALONE-WOOP SAGE _ SEA SALT COLOGNE
# A Jupyter Widget
# JOHN VARVATOS-ARTISAN
# A Jupyter Widget
# JOHN VARVATOS-ARTISAN_1
# A Jupyter Widget
# JUNGSAEMMOOL-ARTIST CONCEALER PALETTE
# A Jupyter Widget
# J_COCEU-PEPTIDE VOLUME ESSENCE
# A Jupyter Widget
# KAMILL-HAND _ NAGELCREME
# A Jupyter Widget
# Kamill-Hand _ Nail Cream
# A Jupyter Widget
# KAMILL-HAND_NAGELCREME CLASSIC
# A Jupyter Widget
# KAMILL-HAND_NAIL CREAM_1
# A Jupyter Widget
# KAMILL-HAND_NAIL CREAM_2
# A Jupyter Widget
# KAMILLE-HANDCREME
# A Jupyter Widget
# KARADIUM-DEEP PORE CLEAN CLEANSING WATER
# A Jupyter Widget
# KATE-BROWN SHADE EYES_1
# A Jupyter Widget
# KATE-BROWN SHADE EYES_2
# A Jupyter Widget
# KATE-DESIGNING EYE BROW
# A Jupyter Widget
# KATE-POWDERIESS LIQUID FOR COVER
# A Jupyter Widget
# KENNETH COLE-BLACK
# A Jupyter Widget
# KENZO-LEAU KENZO POUR HOMME
# A Jupyter Widget
# Kerastate-Nutritive Nectar Thermique
# A Jupyter Widget
# KIEHL_S-CALENDUAL HERBAL EXTRACT ALCOHOL FREE TONER
# A Jupyter Widget
# KIEHL_S-CALENDULA DEEP CLEANSING FOAMING FACE WASH
# A Jupyter Widget
# KIEHL_S-CLEARLY CORRECTIVE DARK SPOT SOLUTION
# A Jupyter Widget
# KIEHL_S-FACIAL FUEL ENERGIZING TONIC FOR MAN
# A Jupyter Widget
# KIEHL_S-FACIAL FUEL ENERGIZING TONIC FOR MEN
# A Jupyter Widget
# KIEHL_S-LIP BALM CRANBERRY
# A Jupyter Widget
# KIEHL_S-MID NIGHT RECOVERY CONCENTRATE
# A Jupyter Widget
# KIEHL_S-POWERFUL STRENGTH LINE REDUCING CONCENTRATE
# A Jupyter Widget
# KIEHL_S-PRECISION LIFTING _ PORE TIGHTENING CONCENTRATE
# A Jupyter Widget
# KIEHL_S-TURMERID _ CRANBERRY SEED ENERGIZING RADIANCE MASQUE
# A Jupyter Widget
# KIEHL_S-ULTRA FACIAL CREAM
# A Jupyter Widget
# KIEHL_S-ULTRA FACIAL CREAM_1
# A Jupyter Widget
# KIEHL_S-ULTRA FACIAL CREAM_2
# A Jupyter Widget
# KIEHL_S-ULTRA FACIAL CREAM_3
# A Jupyter Widget
# KIEHL_S-ULTRA FACIAL TONER
# A Jupyter Widget
# KIEHL_S-ULTRA LIGHT DAILY UV DEFENSE
# A Jupyter Widget
# KISS ME-EYELINER BLACK
# A Jupyter Widget
# KISS ME-HEAVY ROTATION COLORING EYEBROW
# A Jupyter Widget
# KISS ME-HEROINE MAKE MASCARA
# A Jupyter Widget
# KISS ME-HEROINE MAKE SMOOTH LIQUID EYELINER
# A Jupyter Widget
# KISSME-HEAVY ROTATION COLORING EYRBROW
# A Jupyter Widget
# KISSME-HEROINE MAKE SMOOTH LIQUID EYE LINER
# A Jupyter Widget
# KISSME-HEROINE MAKE SMOOTH LIQUID EYELINER
# A Jupyter Widget
# KISSME-HEROINE MAKEUP SMOOTHING EYELINER
# A Jupyter Widget
# LA RECHE POSAY-LIPIKAR LOTION
# A Jupyter Widget
# LA ROCHE POSAY-EFFACLAR DUO
# A Jupyter Widget
# LA ROCHE POSAY-EFFACLAR K
# A Jupyter Widget
# LA ROCHE POSAY-EFFACLAR LOTION ASTRINGENTE
# A Jupyter Widget
# LA ROCHE POSAY-EFFACLAR MAT
# A Jupyter Widget
# LA ROCHE POSAY-LIPIAR LAIT LOTION
# A Jupyter Widget
# LA ROCHE POSAY-TOLERIANE CRME MOUSSANCTE PURIFLANTE
# A Jupyter Widget
# LA ROCHE POSAY-TOLERIANE DERMO CLEANSER
# A Jupyter Widget
# LAB SERIES FOR MEN-Rescue Water Lotion
# A Jupyter Widget
# LAB SERIES-AGE RESCUE FACE LOTION
# A Jupyter Widget
# LAB SERIES-RESCUE WATER LOTION
# A Jupyter Widget
# LAB SERIES-SOLID WATER ESSENCE
# A Jupyter Widget
# LABEL YOUNG-EFFECT RECIPRE SPOT TONING VER PREMIUM
# A Jupyter Widget
# LABEL YOUNG-SHOCKING FOOT PEELING CREAM
# A Jupyter Widget
# LABEL YOUNG-SHOCKING SCALP PACK
# A Jupyter Widget
# LABIOTTE-Collagen water soothing gel
# A Jupyter Widget
# LACVERT-CATHY CAT COLOR TALK EYES
# A Jupyter Widget
# LACVERT-HELLO HYALURON TONER
# A Jupyter Widget
# LACVERT-HOMEE RECHARGE MILD SET EMULSION 35ML
# A Jupyter Widget
# LACVERT-HOMME RE CHARGE MILD SET AFTERSHAVE
# A Jupyter Widget
# LACVERT-HOMME RECHARGE MILD SET AFTERSHAVE 160ML
# A Jupyter Widget
# LACVERT-HOMME RECHARGE MILD SET AFTERSHAVE 35ML
# A Jupyter Widget
# LACVERT-MINT TONE UP SUN CREAM
# A Jupyter Widget
# LACVERT-PURE DEEP CLEANSING OIL
# A Jupyter Widget
# LAFEMME-PLACENTA CREAM MOISTURISER WITH COENZME
# A Jupyter Widget
# LAHEIN-SALON LONG LASTING
# A Jupyter Widget
# LANCOME-BALLERINE NEW SPRINT 2014 NAIL
# A Jupyter Widget
# LANCOME-GRANDIOSE MASCARA
# A Jupyter Widget
# LANCOME-MIRACLE PERFUME
# A Jupyter Widget
# LANCOME-UV EXPERT MILKEY BRIGHT
# A Jupyter Widget
# LANCOME-UV EXPERT YOUTH SHIELD BB COMPLETE
# A Jupyter Widget
# LANEIGE-BB CUSHION PORE CONTROL
# A Jupyter Widget
# LANEIGE-CREAM SKIN
# A Jupyter Widget
# LANEIGE-CREAM SKIN REFINER
# A Jupyter Widget
# LANEIGE-HOMME ACTIVE WATER BANACING EMULSION
# A Jupyter Widget
# LANEIGE-HOMME ACTIVE WATER CLEANSER
# A Jupyter Widget
# LANEIGE-HOMME ACTIVE WATER TONER
# A Jupyter Widget
# LARINS-MANUKA FACIAL MUD MASK
# A Jupyter Widget
# LAROCHE POSAY-CICA PLAST BAUME B5 SOOTHING REPAIRING BALM
# A Jupyter Widget
# LAROCHE POSAY-DERMO SOOTHING HYDRATING LOTION
# A Jupyter Widget
# LAROCHE POSAY-TOLERIANE FLUIDE
# A Jupyter Widget
# LAROCHE POSAY-TOLERIANE ULTRA CONTOUR YEUX
# A Jupyter Widget
# LAROCHE POSAY-TOLERIANE ULTRA LIGHT INTENSE SOOTHING FLUID FACE AND EYES
# A Jupyter Widget
# LAURA MERCIER-INVISIBLE LOOSE SETTING POWDER
# A Jupyter Widget
# LAURA MERCIER-MATTE EYE COLOUR
# A Jupyter Widget
# LAURA MERCIER-MATTE EYE COLOUR_2
# A Jupyter Widget
# LAVIDA-COLLAGEN SOLUTION SERUM
# A Jupyter Widget
# LE BLANC REAL-DROP H ESSENCE
# A Jupyter Widget
# LEADERS-TRIPLE CURE SUN STICK
# A Jupyter Widget
# LEZE-TREATMENT MOISTURING SERUM
# A Jupyter Widget
# LG LIFE_HEALTH-ART DE PEAU HAIR GEL
# A Jupyter Widget
# LG-praL
# A Jupyter Widget
# LG-praL2
# A Jupyter Widget
# LILYBYRED-MOOD LIAR VELVET TINT
# A Jupyter Widget
# LIP MAGNET-MATTE LIP GLOSS
# A Jupyter Widget
# LIRIKOS-KAKAO FOUDER
# A Jupyter Widget
# LOCCITANE-BRUME PERFECTRICE PERFECTING MIST
# A Jupyter Widget
# LOCCITANE-CEAME MAINS HAND CREAM
# A Jupyter Widget
# LOCCITANE-LAVANDE LAIT CORPS BODY LOTION
# A Jupyter Widget
# LOCCITANE-MINI PURE SHEA BUTTER
# A Jupyter Widget
# LOREAL-COLLAGEN MOISTURE FILLER
# A Jupyter Widget
# LOREAL-HYDRAFRESH ULTRA HYDRATING GEL CREAM
# A Jupyter Widget
# LOREAL-LIP STICK
# A Jupyter Widget
# LOTREE-ROSA DAVURICA POWDER PACT
# A Jupyter Widget
# LOVEYDOVEY-FRAGRANCE BODY MIST
# A Jupyter Widget
# LOWELL-DONO CURE CREMA HAIR STYLING TREATMENT
# A Jupyter Widget
# LUK-THE HAIR CUSHION
# A Jupyter Widget
# LUNA-LONG LASTING TIP CONCEALER
# A Jupyter Widget
# LUNA-SOFT FACE FOUDER
# A Jupyter Widget
# LUNASOL-EYE SHADOW
# A Jupyter Widget
# LUNASOL-Sking Modeling Eyes 01
# A Jupyter Widget
# LUSH-CATASTOPHE COSMETIC FRESH FACE MASK
# A Jupyter Widget
# M.T.E-MINERAL TONING ESSENCE
# A Jupyter Widget
# MAC-LIGHT SCAPADE MINERALIZE SKIN FINISH
# A Jupyter Widget
# MAC-LIP STICK
# A Jupyter Widget
# MAC-LIP STICK2
# A Jupyter Widget
# MAC-LUSTRE LIP STICK
# A Jupyter Widget
# MAC-MAKE UP POWDER MEDIUM DARK
# A Jupyter Widget
# MAC-POUDER KISS LIP STICK
# A Jupyter Widget
# MAC-PRE+PRIME FIX+
# A Jupyter Widget
# MAC-PRO LONGWEAR MOURISHING WATER PRO FOUNDATION
# A Jupyter Widget
# MAC-STUDIO CAREBLEND PRESSED
# A Jupyter Widget
# MAC-STUDIO FIX FLUID SPF BROAD SPECTRUM
# A Jupyter Widget
# MAC-Vegas Volt
# A Jupyter Widget
# MAC-VEGAS VOLT AMPLIFIED LIP STICK_1
# A Jupyter Widget
# MAC-VEGAS VOLT AMPLIFIED LIP STICK_2
# A Jupyter Widget
# MAC-VERSICOLOUR STAIN
# A Jupyter Widget
# MACQUEEN-TONE ON TONE SHADOW PALETTE
# A Jupyter Widget
# MAD HIPPIE-VITAMIN C SERUM
# A Jupyter Widget
# MADECA21-TECASOL TONER
# A Jupyter Widget
# MAIIM-RAHEL NATURAL LOTION
# A Jupyter Widget
# MAKE UP FOR EVER-Aqua XL Ink Eye Liner
# A Jupyter Widget
# MAKEUP HELPER-ORIGINAL PRO FINISH
# A Jupyter Widget
# MAKOLICA-SHADOW BE286
# A Jupyter Widget
# MAMONDE MEN-MOISTURE CONTROL LOTION
# A Jupyter Widget
# MAMONDE MEN-Recharging Lotion
# A Jupyter Widget
# MAMONDE-CHAMOMILE PURE TONER
# A Jupyter Widget
# MAMONDE-CREAMY TINT COLOR BALM LIGHT NO
# A Jupyter Widget
# MAMONDE-EVERYDAY SUN CREAM
# A Jupyter Widget
# MAMONDE-MOISTURE CERAMIDE
# A Jupyter Widget
# MAMONDE-MOISTURE CREAM EMULSION
# A Jupyter Widget
# MAMONDE-PANG PANG HAIR SHADOW 01 BABYFACE HAIRLINE
# A Jupyter Widget
# MAMONDE-ROSE WATER TONER
# A Jupyter Widget
# MAMONDE-ROSE WATER TONER_2
# A Jupyter Widget
# MANOLOGY-AQUA BOUNCING WATER LOTION
# A Jupyter Widget
# MANOLOGY-MOISTURIZER AQUA BOMB
# A Jupyter Widget
# MANYO FACTORY-GALAC FOR MEN DAILY SUN MOISTURIZING LOTION
# A Jupyter Widget
# Marc Jacobs-Daisy Dream
# A Jupyter Widget
# MARC JACOBS-RAIN PERFUME
# A Jupyter Widget
# MARY KAY-satin hands cream
# A Jupyter Widget
# MATSU KRYO-ACNE CLEANSING FOAM
# A Jupyter Widget
# MATT-TOUCH LIPSTIC BATONE A LEVRES
# A Jupyter Widget
# MAVIS VIVAUDOU-DUAL LOOSE CUBE
# A Jupyter Widget
# MAXCLINIC-TONE UP BB CUSHION
# A Jupyter Widget
# MAY NEWYORK-SUPER CLEAR SUN STICK
# A Jupyter Widget
# MAY NEWYORK-SUPER SUN STICK
# A Jupyter Widget
# MAYBELLIN-THE FALSIES
# A Jupyter Widget
# MAYBELLINE-FASHION BROW
# A Jupyter Widget
# MAYBELLINE-PORELESS AND MATTE FIT ME CONCEALER
# A Jupyter Widget
# MAYBELLINE-ROCKET VOLUME EXPRESS
# A Jupyter Widget
# MDOC-SEBUM STRIKE SERUM 100ml
# A Jupyter Widget
# MDOC-SEBUM STRIKE TONER
# A Jupyter Widget
# MDOC-SKIN PORE PRIMER
# A Jupyter Widget
# MDOC-WHITENING TONE UP CREAM
# A Jupyter Widget
# MEDICUBE-ZERO PORE PAD
# A Jupyter Widget
# MEDITIME-BOTALINUM CONCENTRATE CARE CREAM
# A Jupyter Widget
# MEDI_PEEL-Bor_Tox
# A Jupyter Widget
# MEGA-FIRST C SERUM PURE VITAMIN C
# A Jupyter Widget
# MENTHLATUM-DEEP MOIST LIP BAM
# A Jupyter Widget
# MIBA-ION CALCIUM MINERAL BB CREAM
# A Jupyter Widget
# MIGUHARA-ANTI WRINKLE PERFECT AMPLE
# A Jupyter Widget
# MIGUHARA-Ultra Whitening  Ample
# A Jupyter Widget
# MIRACLE30-YOUTH AMPOULE
# A Jupyter Widget
# MISEENSCENE-ALL AT ONCE ESSENCE
# A Jupyter Widget
# MISEENSCENE-CURLING ESSENCE 2X
# A Jupyter Widget
# MISEENSCENE-LIMITED PERFECT SERUM ROSE PETAL EDITION
# A Jupyter Widget
# MISEENSCENE-PERFECT SERUM
# A Jupyter Widget
# MISEENSCENE-PERFECT SERUM STYLING
# A Jupyter Widget
# MISEENSCENE-PERFECT SERUM_1
# A Jupyter Widget
# MISEENSCENE-PERFECT SERUM_2
# A Jupyter Widget
# MISS DIOR-BLOOMING BOUQUET
# A Jupyter Widget
# MISSHA-ALL AROUND SAFE BLOCK SEBUM ZERO SUN
# A Jupyter Widget
# MISSHA-LAYER BLURRING PRIMER SHIMMER
# A Jupyter Widget
# MISSHA-M PERFECT COVER BB CREAM
# A Jupyter Widget
# MISSHA-PERFECT COVER BB CREAM
# A Jupyter Widget
# MISSHA-Perfumed Show Cologne Heaven Blue
# A Jupyter Widget
# MISSHA-SAFE BLOCK ESSENCE SUN 45
# A Jupyter Widget
# MISSHA-SIGNATURE DEWY ROUGE
# A Jupyter Widget
# MISSHA-SIGNATURE FLAWLESS COVER STICK CONCEALER
# A Jupyter Widget
# MISSHA-STROBEAM
# A Jupyter Widget
# MISSHA-TIME REVOLUTION NIGHT REPAIR BORABIT AMPOULE
# A Jupyter Widget
# MISSHA-TIME REVOLUTION THE FIRST INTENSIVE MOISUTE
# A Jupyter Widget
# MISSHA-TIME REVOLUTION THE FIRST TREATMENT ESSENCE
# A Jupyter Widget
# MISSHA-TRIPLE SHADOW
# A Jupyter Widget
# MISSHA-VITAMIN B12 DOUBLE HYDROP AMPOULER
# A Jupyter Widget
# MOLTON BROWN-COCO_SANDALWOOD NOURISHING BODY LOTION
# A Jupyter Widget
# MOREMO-HIGH PROTEIN AMPOULE CREAM
# A Jupyter Widget
# MOROCCANOIL-MOROCCANOIL TREATMENT
# A Jupyter Widget
# MOROCCANOIL-Treatment
# A Jupyter Widget
# N7-PROTECT_PERFECT INTENSE EYE CREAM
# A Jupyter Widget
# NARS-AQUA GLOW CUSION
# A Jupyter Widget
# NARS-FOUNDATION
# A Jupyter Widget
# NARS-GINA BLUSH
# A Jupyter Widget
# NARS-LIP STICK
# A Jupyter Widget
# NARS-LIQUID BLUSH SEXAPEAL
# A Jupyter Widget
# NARS-NAMSAN AQYA GLOW CUSHION FOUNDATION
# A Jupyter Widget
# NARS-RADIANT CREAMY CONCEALER
# A Jupyter Widget
# NARS-SEX APPEAL
# A Jupyter Widget
# NARS-SEX APPEAL MAKE UP
# A Jupyter Widget
# NARS-SHAKE WELL BIEN AGITER FOUNDATION
# A Jupyter Widget
# NARS-VELVET LIP GLID PLAY PEN
# A Jupyter Widget
# NARS-VELVET MATTE LIP PENCIL
# A Jupyter Widget
# NARURE REPUBLIC-SUPER AQUA MAX
# A Jupyter Widget
# NATURE REPUBLIC-BUY FLOWER BLUSHER
# A Jupyter Widget
# NATURE REPUBLIC-COLLAGEN BB CREAM
# A Jupyter Widget
# NATURE REPUBLIC-PROVANECE AIR SKIN FIT
# A Jupyter Widget
# NATURE REPUBLIC-SHEA BUTTER ULTRA STREAM CREAM
# A Jupyter Widget
# NATURE REPUBLIC-바이플라워 트리플 무스 틴트 레드 무스
# A Jupyter Widget
# NEUTROGENA-BEACH DEFENSE SUNSCREEN LOTION
# A Jupyter Widget
# NEUTROGENA-FOOT CREAM
# A Jupyter Widget
# NEUTROGENA-HAND CREAM
# A Jupyter Widget
# NO BRAND-BABT COMFORT LOTION
# A Jupyter Widget
# NO BRAND-BE ACTIVE PURE SUNSTICK
# A Jupyter Widget
# NOODLE_BOO-BOUNCING BABY BUBBLES
# A Jupyter Widget
# NOW SOLUTION-SHEA BUTTER MOISTURE
# A Jupyter Widget
# NU SKIN-NACPA MOISTURE MIST
# A Jupyter Widget
# NUSKIN-pure cleansing gel
# A Jupyter Widget
# NUSKIN-SUNRIGHT for Face _ Body
# A Jupyter Widget
# NUXE-HUILE PRODIGIEUSE
# A Jupyter Widget
# NUXE-REVE DE MIEL HAND AND NAIL CREAM
# A Jupyter Widget
# O HUI-DAY SHIELD
# A Jupyter Widget
# O HUI-MIRACLE MOISTURE CLEANSING FOAM
# A Jupyter Widget
# O HUI-MIRACLE MOISTURE CREAM
# A Jupyter Widget
# O HUI-MIRACLE MOISTURE EMULSION
# A Jupyter Widget
# O HUI-MIRACLE MOISTURE SKIN SOFTNER
# A Jupyter Widget
# OBSIDIEN-CURLING START 2 SWING
# A Jupyter Widget
# ODYSSEY-ROMANTIC EMULSION
# A Jupyter Widget
# ODYSSEY-SKIN REFINER
# A Jupyter Widget
# OGANACELL-PEPTIDE RECOVERY CREAM
# A Jupyter Widget
# OHUI-AGE RECOVERY EYE CREAM FOR ALL
# A Jupyter Widget
# OHUI-AGE RECOVERY SKIN SOFTERNER
# A Jupyter Widget
# OHUI-ANTI WRINKLE AGE RECOVERY CREAM
# A Jupyter Widget
# OHUI-ANTI WRINKLE AGE RECOVERY EMULSION
# A Jupyter Widget
# OHUI-MIRACLE MOISTURE CLEANSING FOAM
# A Jupyter Widget
# OHUI-PERFECT SUN POWDER
# A Jupyter Widget
# OHUI-PERFECT SUN WATER CLEANSER
# A Jupyter Widget
# OHUI-PHYTO VITAMIN PRIME ADVANCER EMULSION
# A Jupyter Widget
# OHUI-PRIME ADVANCER SKIN SOFTNER
# A Jupyter Widget
# OHUI-SECOND SKIN FOUNDATION
# A Jupyter Widget
# OLAY-ACTIVE HYDRATING HYDRATATION ORIGINAL CREAM
# A Jupyter Widget
# ON THE BODY-FACE_BODY PERFECT SUN LOTION
# A Jupyter Widget
# ON THE BODY-ONE SHOT SUN KILL
# A Jupyter Widget
# ON THE BODY-THE NATURAL COCONUT OIL BODY LOTION
# A Jupyter Widget
# ONTHEBODY-NATURAL NO SEBUM SUN PACT
# A Jupyter Widget
# ONTHEBODY-SPA NATUAL THERAPY GINGERLEMON REVITAL BODY OIL
# A Jupyter Widget
# ORGAPLUS-ULTRA PURE SUN STICK
# A Jupyter Widget
# ORIENTAL-GOLD BB CREAM
# A Jupyter Widget
# PALMER_S-COCONUT OIL BODY LOTION
# A Jupyter Widget
# PAULA_S CHOICE-hydralight moisture_infusing lotion
# A Jupyter Widget
# PAULA_S CHOICE-PORE REDUCING TONER
# A Jupyter Widget
# PAULA_S CHOICE-Pore_Reducing Toner
# A Jupyter Widget
# PAULA_S CHOICE-RESIST SUPER LIGHT DAILY WRINKLE DEFENSE
# A Jupyter Widget
# PAULA_S CHOICE-SKIN BALANCING INVISIBLE FINISH MOISUTRE GEL
# A Jupyter Widget
# PAULA_S CHOICE-SKIN BALANCING PORE REDUCING TONER
# A Jupyter Widget
# PAULA_S CHOICE-Skin Balancing Ultra Sheer Daily Defense
# A Jupyter Widget
# PAULA_S CHOICE-Skin Perfecting 8_ AHA GEL
# A Jupyter Widget
# PAULA_S CHOICE-SKIN PERFECTING AHA GEL EXFOLIANT
# A Jupyter Widget
# PAULA_S CHOICE-SKIN PERFECTING BHA LIQUID
# A Jupyter Widget
# PAULA_S CHOICE-Super light Daily Wrinkle Defense
# A Jupyter Widget
# PAULA_SCHOICE-PORE CLARIFYING CHARCOAL GEL MASK
# A Jupyter Widget
# PEPTIDE-Volume Essence
# A Jupyter Widget
# PEPTIDE-Volume Essence_2
# A Jupyter Widget
# PERIPERA-INK AIRY VEVET 02
# A Jupyter Widget
# PERIPERA-INK BLACK CARE VOLUME CURLING
# A Jupyter Widget
# PERIPERA-VELVET CHEEK
# A Jupyter Widget
# PETERTHOMASROTH-MEGA RICH CODITIONER
# A Jupyter Widget
# PHYSIOGEL-CALMING RELEF SERUM
# A Jupyter Widget
# PHYSIOGEL-CODZIENNE NAWILZANIE
# A Jupyter Widget
# PHYSIOGEL-DAILY MOISTURE THERAPY
# A Jupyter Widget
# PHYSIOGEL-DAILY MOISTURE THERAPY FACIAL CREAM
# A Jupyter Widget
# PHYSIOGEL-Daily Moisture Therapy Facial Lotion
# A Jupyter Widget
# PHYSIOGEL-DAILY MOISTURE THERAPY FAICAL CREAM
# A Jupyter Widget
# PHYSIOGEL-DAILY MOISTURE THERAPY FOR DRY AND SENSITIVE SKIN
# A Jupyter Widget
# PHYSIOGEL-DAILY MOISTURE THERAPY(1)
# A Jupyter Widget
# PHYSIOGEL-FACIAL LOTION
# A Jupyter Widget
# PHYSIOGEL-HYPOALLERGENIC BODY LOTION
# A Jupyter Widget
# PHYSIOGEL-LAGODZENIE I ULGA
# A Jupyter Widget
# PHYTO VITAL-DEEP MOISTURIZING MASK
# A Jupyter Widget
# POLO SPORT-RALPH LAUREN
# A Jupyter Widget
# POLO-BLACK BY RALPH LAUREN FOR MEN
# A Jupyter Widget
# PONDS-BB MAGIC POWDER
# A Jupyter Widget
# POND_s-BB Magic Power
# A Jupyter Widget
# POND_S-CLEAR FACE SPA LIP_EYE REMOVER
# A Jupyter Widget
# POND_S-MAGIC POWDER BB CREAM
# A Jupyter Widget
# POWDER4ROOM-FULL COVER SKIN FIXING CREAM
# A Jupyter Widget
# POWER4ROOM-MAKE UP POWER FIXX
# A Jupyter Widget
# PREM-PROTECT YOUR SKIN FROM THE SUN
# A Jupyter Widget
# PRETTY AS A PEACH-SUPER SMOOTH BODY LOTION
# A Jupyter Widget
# PRIMERA-CURE EYE CREAM ORGANIENCE
# A Jupyter Widget
# PRIMERA-EMULSION ORGANIENCE
# A Jupyter Widget
# PRIMERA-OIL FREE GEL CREAM
# A Jupyter Widget
# PROFESSIONAL STRENGTH-5_ GLYCOLIC ACID CREME
# A Jupyter Widget
# RAUSCH-ANTI DANDRUFF SHAMPOO
# A Jupyter Widget
# REAL BARRIER-AQUA SOOTHING GEL CREAM
# A Jupyter Widget
# REAL BARRIER-EXTREAM CREAM
# A Jupyter Widget
# RENEW-INTENSIVE SKIN THERAPY
# A Jupyter Widget
# RENK-EYE SHADOW
# A Jupyter Widget
# RENK-Real White Gel Cream
# A Jupyter Widget
# RENK-TRIPLE RAGIANCE COLOR CREAM
# A Jupyter Widget
# RICH SKIN-MOIST UP FACE MIST GREEN TEA
# A Jupyter Widget
# RIRE-BUBLE BUBLE LIP MASK
# A Jupyter Widget
# RMK-FOUNDATION_1
# A Jupyter Widget
# RMK-FOUNDATION_2
# A Jupyter Widget
# RMK-INGENLOUS POWDER CHEEKS
# A Jupyter Widget
# RMK-Liquid Foundation
# A Jupyter Widget
# RMK-UV FACE PROTECTOR
# A Jupyter Widget
# ROKKISS-TEA TREE MOISTURINZING CREAM
# A Jupyter Widget
# ROUND LAB-독도 토너
# A Jupyter Widget
# ROUNDLAB-1025 DOCKDO TONER
# A Jupyter Widget
# ROVECTIN-TREATMENT LOTION
# A Jupyter Widget
# RYUSPA-FACIAL CREAM
# A Jupyter Widget
# S2ND-PINK TOUCH ALL IN ONE TONE UP CREAM
# A Jupyter Widget
# SABON-BODY SCRUB PATCHOULI VAVENDER VANILLA
# A Jupyter Widget
# SABON-Lip Balm Vanilla Coconut
# A Jupyter Widget
# SAINT LAURENT-LIP STICK
# A Jupyter Widget
# SAINT LAURENT-LIP TINT
# A Jupyter Widget
# SANTA MARIA NOVELLA-ACQUA DI ROSE WATER
# A Jupyter Widget
# SCINIC-CICANOID AMPOULE
# A Jupyter Widget
# SCINIC-ENJOY ALL ROUND AIRY SUN STICK
# A Jupyter Widget
# SCINIC-FIRST TREATMENT ESSENCE
# A Jupyter Widget
# SCINIC-MASTER PLUS
# A Jupyter Widget
# SCUDERIA FERRARI-BLACK SIGNATURE
# A Jupyter Widget
# SEBAMED-EXTREME DRY SKIN RELEF FACE CREAM
# A Jupyter Widget
# SENKA-HADA LABO GOKU_JYUN PERFECT GEL
# A Jupyter Widget
# SENKA-PERFECT WHIP
# A Jupyter Widget
# SENKA-PERFECT WHIP COLLAGEN IN
# A Jupyter Widget
# SENKA-PERFECT WHIP_2
# A Jupyter Widget
# SERENDIBEAYTY-NATURAL MOURISING FACE OIL
# A Jupyter Widget
# SHU UEMURA-PETAL SKIN FUID FOUNDATION
# A Jupyter Widget
# SHU UEMURA-UNLIMITED BREATHABLE LASTING FOUNDATION
# A Jupyter Widget
# SHU UEMURA-unlimited foundation
# A Jupyter Widget
# SHU UEMURE-POWDER
# A Jupyter Widget
# SIDMOOL-ATMEAL WATERFULL CREAM
# A Jupyter Widget
# SIDMOOL-ATO LOTION WITH NATURAL INGREDIENTS
# A Jupyter Widget
# SIDMOOL-GREEN TEA SKIN
# A Jupyter Widget
# SIDMOOL-ROYAL HONEY PEPTIDE DEEP MOISTURE PACK
# A Jupyter Widget
# SIDMOOL-SUBUN GADEUK SUN SPRAY
# A Jupyter Widget
# SIDMOOL-ULTRA FACIAL MOISTURIZING LOTION
# A Jupyter Widget
# SIDMOOL-다당류 리얼 수분 에센스
# A Jupyter Widget
# SIDMOOL-살구씨 딥 클렌징 오일
# A Jupyter Widget
# SIDMOOL-카카두 아미노 클렌져
# A Jupyter Widget
# SISLEY-FLORAL TUONING LOTION
# A Jupyter Widget
# SK II-MEN FACIAL TREATMENT ESSENCE
# A Jupyter Widget
# SK II-RNA POWER EYE CREAM RADICAL NEW AGE
# A Jupyter Widget
# SK II-RNA POWER RADICAL NEW AGE
# A Jupyter Widget
# SK II-STEMPWER EYE CREAM
# A Jupyter Widget
# SKIN FOOD-ALL OVER MUFFIN CAKE FINISH
# A Jupyter Widget
# SKIN FOOD-GOLD CAVIAR EMULSION
# A Jupyter Widget
# SKIN FOOD-PEACH COTTON MULTI FINISH POWDER
# A Jupyter Widget
# SKIN FOOD-석류 립 시크
# A Jupyter Widget
# SKIN HD-COLAGENIC CHEEK
# A Jupyter Widget
# SKIN ORGANICS-MOISTURE RESTORING NIGHT CREAM
# A Jupyter Widget
# SKINEYE-AC PURE SOOTHER SLEEPING PACK
# A Jupyter Widget
# SKINFOOD-MINERAL SUGAR TRIPLE SHADOW
# A Jupyter Widget
# SKINFOOD-WHITE GRAPE
# A Jupyter Widget
# SKIN_LAB-BARRIERDERM INTENSIVE CREAM
# A Jupyter Widget
# SO NATURAL-ALL DAY TIGHT MAKE UP SETTING FIXER
# A Jupyter Widget
# SOHAIR-MOROCOCO ARGAN OIL
# A Jupyter Widget
# SOMEBYMI-AHABHAPHA 30DAYS MIRACLE TONER
# A Jupyter Widget
# SONATURAL-CENTELLA MAGIC POWER
# A Jupyter Widget
# SONREVE-DAILY SUN PROTECTION
# A Jupyter Widget
# SONREVE-FACE_NECK SLEEPING MASK
# A Jupyter Widget
# SONREVE-TRI BIO TREATMENT ESSENCE
# A Jupyter Widget
# SOORYEHAN-BCHAEK TRUE EYE CREAM
# A Jupyter Widget
# SOORYEHAN-BICHAEK TRYE REJUVENATING EMULSION
# A Jupyter Widget
# SOORYEHAN-BIO GINSENG FIRST ESSENCE
# A Jupyter Widget
# SOORYEHAN-CHEAYUL ESSENCE
# A Jupyter Widget
# SOORYEHAN-REPAIR ESSENCE
# A Jupyter Widget
# SOORYEHAN-진생진액
# A Jupyter Widget
# SOORYEHAN-효 구효진 보울 오일
# A Jupyter Widget
# STAGE PERFORMER GLOW CREATOR-BASE _ TOP GLOW BOOSTING CREAM
# A Jupyter Widget
# STILA-MATTE N METAL EYE SHADOW PALETTE
# A Jupyter Widget
# STRIDEX MAXIMUM-ACNE MEDICATION PADS
# A Jupyter Widget
# STRIDEX-SINGLE STEP CLEANSING
# A Jupyter Widget
# STYLENANDA-3ce red recipe matte lip color
# A Jupyter Widget
# SULHWASOO-SNOWISE WHITENING ESSENCE
# A Jupyter Widget
# SULHWASOO-수올미스트
# A Jupyter Widget
# SULHWASOO-여윤팩
# A Jupyter Widget
# SULWHASOO-CLEAR MASK
# A Jupyter Widget
# SULWHASOO-ESSENTIAL BALANCING EMULSION EX
# A Jupyter Widget
# SULWHASOO-ESSENTIAL BALANCING WATER EX
# A Jupyter Widget
# SULWHASOO-ESSENTIAL FIRMING CREAM EX
# A Jupyter Widget
# SULWHASOO-ESSENTIAL REJUVENATING EYE CREAM 25ML
# A Jupyter Widget
# SULWHASOO-FIRST CARE ACTIVATING SERUM
# A Jupyter Widget
# SULWHASOO-RENODIGM DUAL CARE CREAM
# A Jupyter Widget
# SULWHASOO-SNOWISE BRIGHTENING SERUM
# A Jupyter Widget
# SULWHASOO-립스틱 4호
# A Jupyter Widget
# SULWHASOO-순행클랜징폼
# A Jupyter Widget
# SULWHASOO-옥용팩
# A Jupyter Widget
# SULWHASOO-자음유액
# A Jupyter Widget
# SUM-SECRET EYE CREAM
# A Jupyter Widget
# SUM-TIME ENERGY SKIN RESETTING MOIST FIRMING CREAM
# A Jupyter Widget
# SUM-WHITE AWARD
# A Jupyter Widget
# SUM37-SECRET ESSENCE MIST
# A Jupyter Widget
# SUNSILK-DAMAGE RESTORE
# A Jupyter Widget
# TAF-ESSENTIAL 7 SKIN
# A Jupyter Widget
# TEGEL-HAND AND BODY LOTION
# A Jupyter Widget
# THE BODY SHOP-MORINGA SHOWER GEL
# A Jupyter Widget
# THE BODY SHOP-WHITE MUSK EAU DE TOILETTE
# A Jupyter Widget
# THE FACE SHOP-STYLIST SUPER HARD WAX
# A Jupyter Widget
# THE FACESHOP-ANTI DARKENING CUSHION
# A Jupyter Widget
# THE FACESHOP-HIGHLIGHTER BEAM BASE ILLUMINATRICE
# A Jupyter Widget
# THE FACESHOP-INK LIPQUID RED SING
# A Jupyter Widget
# THE FACESHOP-JEJU ALOE
# A Jupyter Widget
# THE FACESHOP-JEJU ALOE FRESH SOOTHING GEL
# A Jupyter Widget
# THE FACESHOP-LA MARCHE THERAPHY FIST SERUM
# A Jupyter Widget
# THE FACESHOP-NATURAL SUN BODY _ FAMILY MILD SUN MILK
# A Jupyter Widget
# THE FACESHOP-NATURAL SUN INORGANIC SUN SCREEN STICK
# A Jupyter Widget
# THE FACESHOP-OIL CLEAR SMOOTH AND BRIGHT POWDER
# A Jupyter Widget
# THE FACESHOP-POWER LONG LASTING SUN CREAM
# A Jupyter Widget
# THE FACESHOP-POWER PERFECTION BB CREAM
# A Jupyter Widget
# THE FACESHOP-PRISM CUBE BRUSH BY ITALY FRENCH ROSE
# A Jupyter Widget
# THE FACESHOP-SINGLE BLUSH FARD A JOUES MULTI USAGE
# A Jupyter Widget
# THE FACESHOP-The Fresh for men Hydrating Emulsion
# A Jupyter Widget
# THE FACESHOP-THE SIGNARUE SKIN CONDITIONING SERUM
# A Jupyter Widget
# THE FACESHOP-TINT STICK TEINTE EN BATON
# A Jupyter Widget
# THE FACESHOP-Trendy Nails Nail Remover Rose
# A Jupyter Widget
# THE FACESHOP-더시그니처 모공 숨숨 크림
# A Jupyter Widget
# THE SAEM-HEALING TEA GARDEN GREEN TEA CLEANSING WATER
# A Jupyter Widget
# THE THERAPY-HYDRATING FORMULA EMULSION
# A Jupyter Widget
# THEBODYSHOP-MORINGA BOBY YOGURT
# A Jupyter Widget
# THEFACESHOP-INK LASTING FOUNDATION SLIM FIT
# A Jupyter Widget
# THIERRY MUGLER-ANGEL EAU PARFUM NATURAL SPRAY
# A Jupyter Widget
# THINK NATURE-BODY LOTION MOISTURE
# A Jupyter Widget
# TN-AC CONTROL RECIPE TROUBLE SKIN MOITURE LOTION
# A Jupyter Widget
# TONICO ANALCOLICO-ANTICA FARMACIA DEI MONACI CAMALDOLESI
# A Jupyter Widget
# TONY LAB-AC Control Toner
# A Jupyter Widget
# TONYMOLY-DELIGHT TONY TINT
# A Jupyter Widget
# TONYMOLY-EASY TOUCH
# A Jupyter Widget
# TONYMOLY-Floria Nutra Energy 100 Hours Cream
# A Jupyter Widget
# TONYMOLY-LUMINOUS GODDESS AURA BB CREAM
# A Jupyter Widget
# TONYMOLY-LUMINOUS GOODESS AURA BB CREAM
# A Jupyter Widget
# TONYMOLY-MOISTURE MIST
# A Jupyter Widget
# TONYMOLY-My Sunny vital sun Stick
# A Jupyter Widget
# TONYMOLY-The Chok Chok GREEN TEA Foam Cleanser
# A Jupyter Widget
# TONYMORY-THE BLACK TEA LONDON CLASSIC OIL
# A Jupyter Widget
# TONYPOLY-백젤 아이라이너 BLACK
# A Jupyter Widget
# TOO COOL FOR SCHOOL-ART CLASS BY RODIN
# A Jupyter Widget
# TOO COOL FOR SCHOOL-ART CLASS BY RODIN SHADING
# A Jupyter Widget
# TOO COOL FOR SCHOOL-ART CLASS BY RODIN SHADING CONTOUR
# A Jupyter Widget
# TOPPIK-HAIR BUILDING FIBERS
# A Jupyter Widget
# ULOS-COSMEDIC SKIN LOTION FOR FACE AND BODY
# A Jupyter Widget
# ULOS-COSMEDICS SKIN LOTION FOR FACE _ BODY
# A Jupyter Widget
# ULOS-SKIN MILK FOR FACE _ BODY
# A Jupyter Widget
# ULTRA HD-MAKE UP FOR EVER FOUNDATION
# A Jupyter Widget
# ULTRA V-FOCUS ENRICHED CREAM WHITENING NAD WRINKLE CARE
# A Jupyter Widget
# ULTRA V-HYAL 100 ANTI WRINKLE _ WHITENING
# A Jupyter Widget
# ULTRA V-IDEBENONE AGE RETURNING EYE CREAM
# A Jupyter Widget
# ULTRA V-IDEBENONE SUN BLOCK
# A Jupyter Widget
# ULTRA V-NIO BF CREAM SKIN BRIGHTENING ANTI WRINKLE
# A Jupyter Widget
# UNKNOWN-ORGAN EXTRA VIRGIN COCONUT OIL
# A Jupyter Widget
# URBAN BOUTIQUE-ROSY CHEEKS_ONLY ONE
# A Jupyter Widget
# URIAGE-THERMAL MICELLAR WATER
# A Jupyter Widget
# URIAGE-XEMOSE CLEANSING SOOTHING OIL
# A Jupyter Widget
# URIAGE-XEMOSE TONIQUE HYDRATANT
# A Jupyter Widget
# VANITAS Versace-eau de toilette
# A Jupyter Widget
# VANT36.5-AHA 10_ CREAM
# A Jupyter Widget
# VANT36.5-ALL IN ONE ESSENCE
# A Jupyter Widget
# VASELINE-INTENSIVE CARE
# A Jupyter Widget
# VASELINE-PURE PETROLEUM JELLY ORIGINAL
# A Jupyter Widget
# VDIVOV-SILK WEAR MAKEUP BASE
# A Jupyter Widget
# VDL-COLOR CORRECTING PRIMER
# A Jupyter Widget
# VDL-EXPERT COLOR FOR EYES
# A Jupyter Widget
# VDL-EXPERT COLOR PRIMER FOR EYES
# A Jupyter Widget
# VDL-EXPERT RADIANCE FIX MIST
# A Jupyter Widget
# VDL-NAKED STRONG CLEASING OIL
# A Jupyter Widget
# VDL-PERFECTING LAST FOUNDATION
# A Jupyter Widget
# VELY VELY-ARTEMISIA BALANCE ESSENCE
# A Jupyter Widget
# VELY VELY-AURA PEARL BASE
# A Jupyter Widget
# Vely Vely-Water Glow Balm
# A Jupyter Widget
# VER22-BOUNCE UP PACT PRIME
# A Jupyter Widget
# VERITE-ALL IN ONE CREAM
# A Jupyter Widget
# VERITE-AURORA COVER CUSHION
# A Jupyter Widget
# VERITE-CREAMY COLOR LIP BALM
# A Jupyter Widget
# VERITE-LIGHT TOUCH FOUNDATION
# A Jupyter Widget
# VERITE-오로라 커버 쿠션 21호 커버 바닐라
# A Jupyter Widget
# VERITE-울트라 모이스트 스킨
# A Jupyter Widget
# VERITE-크리스탈 커버 쿠션 21호 커버 바닐라 1
# A Jupyter Widget
# VERITE-크리스탈 커버 쿠션 21호 커버 바닐라 2
# A Jupyter Widget
# VERNIS A LEVRES-LIP TINT STICK
# A Jupyter Widget
# VERSACE-BRIGHT CRYSTAL PERFUME
# A Jupyter Widget
# VICHY V-EAU THERMALE MINERALISANTE
# A Jupyter Widget
# Vichy-EAU THERMALE MINERALISANTE
# A Jupyter Widget
# VICTORIA_S SECRET-LOVE ADDICT BODY MIST
# A Jupyter Widget
# VICTORIA_S SECRET-LOVE SPELL
# A Jupyter Widget
# VICTORIA_S SECRET-LOVE SPELL FRAGRANCE LOTION
# A Jupyter Widget
# VITRESS-CUTICLE COAT CLASSIC FOR EXTRA SHINY_SILLY SMOOTH HAIR
# A Jupyter Widget
# VIVIENNE WESTWOOD-NAUGHTY ALICE
# A Jupyter Widget
# VOLTE FACE-Fill Nutrition Serum
# A Jupyter Widget
# VONIN-PURE SUN
# A Jupyter Widget
# VONIN-THE CHARACTER BLACK
# A Jupyter Widget
# VONIN-THE CHARACTER BLACK TONER
# A Jupyter Widget
# VT-CICA REDNESS COVER CUSHION
# A Jupyter Widget
# VT-CICA REPAIR CREAM
# A Jupyter Widget
# VT-Double Cover Cushion 21호
# A Jupyter Widget
# VT-WATER CC CUSION MINI
# A Jupyter Widget
# W-ESSENCE WAX_1
# A Jupyter Widget
# W-ESSENCE WAX_2
# A Jupyter Widget
# WAKE MAKE-LIP COSTER ROSE SWING
# A Jupyter Widget
# WET N WILD-COLORICON ROSE IN THE AIR
# A Jupyter Widget
# WHOO-THE HISTORY OF WHOO LUXURY BB CREAM
# A Jupyter Widget
# WHOO-공진향 미 궁중 블러셔
# A Jupyter Widget
# WHOO-궁중립밤
# A Jupyter Widget
# WHOO-럭셔리 립스틱 부케 핑크
# A Jupyter Widget
# WHYDRO-WHITE REVOLTION CREAM
# A Jupyter Widget
# WONDER-CERAMIDE MOCCHI TONER
# A Jupyter Widget
# YOUR NAIL-BASIC
# A Jupyter Widget
# YSL-Endanger Me Red
# A Jupyter Widget
# YSL-GLOSSY STAIN
# A Jupyter Widget
# YSL-GLOSSY STAIN LIP COLOR_1
# A Jupyter Widget
# YSL-LIP STICK
# A Jupyter Widget
# YSL-LIP STICK_2
# A Jupyter Widget
# YSL-RED LIP STICK
# A Jupyter Widget
# YSL-TATOUAGE COUTURE LIQUID MATTE LIP STAIN_1
# A Jupyter Widget
# YSL-TATOUAGE COUTURE LIQUID MATTE LIP STAIN_2
# A Jupyter Widget
# YSL-VERNIS À LÈVRES VINYL CREAM LIQUID LIPSTICK
# A Jupyter Widget
# YURICA-FACE SHIELD
# A Jupyter Widget
# YURIPIBU-BIFIDA REPAIR AMPOULE
# A Jupyter Widget
# YURIPIBU-SPECIAL SPOT ESSENCE
# A Jupyter Widget
# ZIAJA-KOZIE MLEKO KREM2
# A Jupyter Widget
# ZIALA-goat_s milk Night Cream
# A Jupyter Widget
# 과일나라-PURE ALOE VERA
# A Jupyter Widget
# 과일나라-ULTRA MOISTURE HAND CARE ARGAN HAND CREAM
# A Jupyter Widget
# 식물나라-OXYGEN WATER FITTING SUN CREAM
# A Jupyter Widget
# 식물나라-제주 탄산수 딥 클렌징 워터
# A Jupyter Widget
# 식물나라-프로폴리스 페이스 오일
# A Jupyter Widget
# 웰빙헬스-고운발
# A Jupyter Widget

# %%
"""
폴더내 이미지 복사용
"""
from glob import glob
from tqdm import tqdm_notebook as tqdm
import os
import subprocess

data_dir = '.\\LG-orignal-video\\images_seperated_full\\val' # /로 나누면 윈도에서 에러남
for d in os.listdir(data_dir):
    print(d)
    fileList = os.listdir(os.path.join(data_dir, d))
    for idx, fn in enumerate(tqdm(fileList)):
        command = ['cmd', '\/c', 'copy',  os.path.join(data_dir, d, fn) , os.path.join(data_dir, d, 'web_'+str(idx)+'.jpg')]
        subprocess.check_output(command)
    for idx, fn in enumerate(tqdm(fileList)):
        command = ['cmd', '\/c', 'copy',  os.path.join(data_dir, d, fn) , os.path.join(data_dir, d, 'web__'+str(idx)+'.jpg')]        
        subprocess.check_output(command)
# Out:
# AGE20_S-ESSENCE COVER FACT TX
# A Jupyter Widget
# A Jupyter Widget
# AHC-AGELESS REAL EYE CREAM FOR FACE
# A Jupyter Widget
# A Jupyter Widget
# ARITAUM-MONO EYES
# A Jupyter Widget
# A Jupyter Widget
# BENEFIT-DANDELION
# A Jupyter Widget
# A Jupyter Widget
# BEYOND-ANGEL AQUA DAILY BIG TONER
# A Jupyter Widget
# A Jupyter Widget
# BEYOND-ANGEL AQUA MOIST CREAM
# A Jupyter Widget
# A Jupyter Widget
# BEYOND-ECO DAILY DEFENCE AQUA SUN GEL
# A Jupyter Widget
# A Jupyter Widget
# BEYOND-PHYTO AQUA CREAM
# A Jupyter Widget
# A Jupyter Widget
# BIODERMA-SENSIBIO H2O MAKE
# A Jupyter Widget
# A Jupyter Widget
# BIOSILK-SILK THERAPY HAIR TREATMENT
# A Jupyter Widget
# A Jupyter Widget
# BIOTHERM-HOMME AQUAPOWER_1
# A Jupyter Widget
# A Jupyter Widget
# BONABELLA-UV PROTECTION TONE UP DAILY SUN BLOCK
# A Jupyter Widget
# A Jupyter Widget
# BVLGARI-OMNIA CORAL FOR WOMEN
# A Jupyter Widget
# A Jupyter Widget
# CAREZONE-DOCTOR SOLUTION A CURE CLARIFYING EMULSION
# A Jupyter Widget
# A Jupyter Widget
# CAREZONE-NORDENAU WATER ESSENCE
# A Jupyter Widget
# A Jupyter Widget
# CELL FUSION C-LASER SUNSCREEN 100
# A Jupyter Widget
# A Jupyter Widget
# CENTELLIAN24-Madeca Cream
# A Jupyter Widget
# A Jupyter Widget
# CETAPHIL-MOISTURISING LOTION
# A Jupyter Widget
# A Jupyter Widget
# CHANEL-N5 PERFUME
# A Jupyter Widget
# A Jupyter Widget
# CHANEL-ROUGE ALLURE LIP STICK
# A Jupyter Widget
# A Jupyter Widget
# CLEDBEL-24K GOLD SERUM
# A Jupyter Widget
# A Jupyter Widget
# CLINIQUE-MOISTURE SURGE 72HOUR AUTO REPLENISHING
# A Jupyter Widget
# A Jupyter Widget
# DEWY TREE-ULTRA VITALIZING SNAIL CREAM_1
# A Jupyter Widget
# A Jupyter Widget
# DIOR-JADORE WOMEN EAU DE PERFUME
# A Jupyter Widget
# A Jupyter Widget
# DIOR-LIP GLOW COLOR REVIVER BALM_1
# A Jupyter Widget
# A Jupyter Widget
# DIPTYQUE-DO SON
# A Jupyter Widget
# A Jupyter Widget
# DR.G-BLACK SNAIL CREAM
# A Jupyter Widget
# A Jupyter Widget
# ESPOIR-PRO TAILOR FOUNDATION
# A Jupyter Widget
# A Jupyter Widget
# ESTEE LAUDER-ADVANCED NIGHT REPAIR
# A Jupyter Widget
# A Jupyter Widget
# ESTEE LAUDER-PURE COLOR LOVE LIPSTICK_1
# A Jupyter Widget
# A Jupyter Widget
# GOODAL-DOUBLE BRIGHT DDAY AMPOULE
# A Jupyter Widget
# A Jupyter Widget
# GREEN FINGER-KIDS FACIAL LOTION
# A Jupyter Widget
# A Jupyter Widget
# GREEN FINGER-야외놀이 선크림
# A Jupyter Widget
# A Jupyter Widget
# HADALABO-SHIRO JYUN Lotion
# A Jupyter Widget
# A Jupyter Widget
# HERA-BLACK CUSHION_1
# A Jupyter Widget
# A Jupyter Widget
# HERA-BLACK CUSHION_2
# A Jupyter Widget
# A Jupyter Widget
# HERA-MAKE UP FIXER
# A Jupyter Widget
# A Jupyter Widget
# HERA-SUN MATE EXCELLENCE
# A Jupyter Widget
# A Jupyter Widget
# INNISFREE-APPLE SEED LIP AND EYE MAKEUP REMOVER
# A Jupyter Widget
# A Jupyter Widget
# INNISFREE-green tea lotion for men
# A Jupyter Widget
# A Jupyter Widget
# INNISFREE-PERFECT 9 REPAIR EYE CREAM
# A Jupyter Widget
# A Jupyter Widget
# INNISFREE-perfect uv protection cream
# A Jupyter Widget
# A Jupyter Widget
# ISA KNOX-THE PRESTIGE RE ACTIVE CONCENTRATING SERUM
# A Jupyter Widget
# A Jupyter Widget
# JIMMY CHOO-EAU DE TOILETTE
# A Jupyter Widget
# A Jupyter Widget
# JO MALONE-BLACKBERRY AND BAY COLOGNE
# A Jupyter Widget
# A Jupyter Widget
# JOHN VARVATOS-ARTISAN
# A Jupyter Widget
# A Jupyter Widget
# KAMILL-HAND_NAIL CREAM_1
# A Jupyter Widget
# A Jupyter Widget
# KATE-BROWN SHADE EYES_1
# A Jupyter Widget
# A Jupyter Widget
# KIEHL_S-FACIAL FUEL ENERGIZING TONIC FOR MEN
# A Jupyter Widget
# A Jupyter Widget
# KIEHL_S-POWERFUL STRENGTH LINE REDUCING CONCENTRATE
# A Jupyter Widget
# A Jupyter Widget
# KIEHL_S-ULTRA FACIAL CREAM
# A Jupyter Widget
# A Jupyter Widget
# KISS ME-HEAVY ROTATION COLORING EYEBROW
# A Jupyter Widget
# A Jupyter Widget
# KISSME-HEROINE MAKE SMOOTH LIQUID EYE LINER
# A Jupyter Widget
# A Jupyter Widget
# LA ROCHE POSAY-EFFACLAR DUO
# A Jupyter Widget
# A Jupyter Widget
# LA ROCHE POSAY-LIPIAR LAIT LOTION
# A Jupyter Widget
# A Jupyter Widget
# LAB SERIES-RESCUE WATER LOTION
# A Jupyter Widget
# A Jupyter Widget
# LACVERT-HOMME RE CHARGE MILD SET AFTERSHAVE
# A Jupyter Widget
# A Jupyter Widget
# LANEIGE-CREAM SKIN
# A Jupyter Widget
# A Jupyter Widget
# LAROCHE POSAY-TOLERIANE FLUIDE
# A Jupyter Widget
# A Jupyter Widget
# LAROCHE POSAY-TOLERIANE ULTRA CONTOUR YEUX
# A Jupyter Widget
# A Jupyter Widget
# LAURA MERCIER-MATTE EYE COLOUR
# A Jupyter Widget
# A Jupyter Widget
# LG-praL
# A Jupyter Widget
# A Jupyter Widget
# LUNASOL-EYE SHADOW
# A Jupyter Widget
# A Jupyter Widget
# MAC-LIP STICK
# A Jupyter Widget
# A Jupyter Widget
# MAMONDE-ROSE WATER TONER
# A Jupyter Widget
# A Jupyter Widget
# MANOLOGY-AQUA BOUNCING WATER LOTION
# A Jupyter Widget
# A Jupyter Widget
# MISEENSCENE-PERFECT SERUM
# A Jupyter Widget
# A Jupyter Widget
# MISSHA-PERFECT COVER BB CREAM
# A Jupyter Widget
# A Jupyter Widget
# MISSHA-TIME REVOLUTION THE FIRST TREATMENT ESSENCE
# A Jupyter Widget
# A Jupyter Widget
# MOROCCANOIL-MOROCCANOIL TREATMENT
# A Jupyter Widget
# A Jupyter Widget
# NARS-SEX APPEAL MAKE UP
# A Jupyter Widget
# A Jupyter Widget
# NARS-SHAKE WELL BIEN AGITER FOUNDATION
# A Jupyter Widget
# A Jupyter Widget
# NEUTROGENA-HAND CREAM
# A Jupyter Widget
# A Jupyter Widget
# O HUI-MIRACLE MOISTURE CLEANSING FOAM
# A Jupyter Widget
# A Jupyter Widget
# PAULA_S CHOICE-PORE REDUCING TONER
# A Jupyter Widget
# A Jupyter Widget
# PAULA_S CHOICE-Skin Balancing Ultra Sheer Daily Defense
# A Jupyter Widget
# A Jupyter Widget
# PAULA_S CHOICE-SKIN PERFECTING AHA GEL EXFOLIANT
# A Jupyter Widget
# A Jupyter Widget
# PEPTIDE-Volume Essence
# A Jupyter Widget
# A Jupyter Widget
# PHYSIOGEL-FACIAL LOTION
# A Jupyter Widget
# A Jupyter Widget
# POND_S-MAGIC POWDER BB CREAM
# A Jupyter Widget
# A Jupyter Widget
# RMK-FOUNDATION_1
# A Jupyter Widget
# A Jupyter Widget
# ROUND LAB-독도 토너
# A Jupyter Widget
# A Jupyter Widget
# SENKA-PERFECT WHIP
# A Jupyter Widget
# A Jupyter Widget
# SHU UEMURA-UNLIMITED BREATHABLE LASTING FOUNDATION
# A Jupyter Widget
# A Jupyter Widget
# SK II-RNA POWER RADICAL NEW AGE
# A Jupyter Widget
# A Jupyter Widget
# SULHWASOO-ESSENTIAL BALANCING WATER EX
# A Jupyter Widget
# A Jupyter Widget
# SULHWASOO-옥용팩
# A Jupyter Widget
# A Jupyter Widget
# THE FACESHOP-JEJU ALOE
# A Jupyter Widget
# A Jupyter Widget
# THE FACESHOP-SINGLE BLUSH FARD A JOUES MULTI USAGE
# A Jupyter Widget
# A Jupyter Widget
# TONYMOLY-LUMINOUS GOODESS AURA BB CREAM
# A Jupyter Widget
# A Jupyter Widget
# TOO COOL FOR SCHOOL-ART CLASS BY RODIN
# A Jupyter Widget
# A Jupyter Widget
# ULOS-COSMEDIC SKIN LOTION FOR FACE AND BODY
# A Jupyter Widget
# A Jupyter Widget
# VERITE-쿠션 21호 커버 바닐라 1
# A Jupyter Widget
# A Jupyter Widget
# VICHY V-EAU THERMALE MINERALISANTE
# A Jupyter Widget
# A Jupyter Widget
# VICTORIA_S SECRET-LOVE SPELL
# A Jupyter Widget
# A Jupyter Widget
# VONIN-THE CHARACTER BLACK
# A Jupyter Widget
# A Jupyter Widget
# W-ESSENCE WAX_1
# A Jupyter Widget
# A Jupyter Widget
# YSL-LIP STICK
# A Jupyter Widget
# A Jupyter Widget
# ZIALA-goat_s milk Night Cream
# A Jupyter Widget
# A Jupyter Widget

# %%
data_dir = '.\\LG-orignal-video\\images_seperated_full\\val' # /로 나누면 윈도에서 에러남
data_dir_web = '.\\LG-orignal-video\\images_seperated_full\\web' # /로 나누면 윈도에서 에러남

for d in os.listdir(data_dir):
    new_path = os.path.join(data_dir_web,d)
    os.mkdir(new_path)

# %% [markdown]
# ---
# ## train/test 데이터 나누기

# %%
import pandas as pd
import os

# %%
df = pd.read_csv('cosmetic_class.txt', encoding='utf8')
for col in df:
    if col!='isTest':
        df[col] = df[col].apply(lambda x: x.strip())
df['full'] = df.apply(lambda x: x[0]+'-'+x[1], axis=1)
# df['full'] = df.apply(lambda x: (x[0]+'-'+x[1]).strip(), axis=1)

# %%
orig_list = os.listdir('img')
# orig_list = os.listdir('video/resized')
refined_list = list(df['full'])

orig_list2 = [i for i in orig_list]

# %%
print(len(orig_list), len(refined_list))
for i in orig_list2:
    if i in refined_list:
        idx_r = refined_list.index(i)
        idx_o = orig_list.index(i)
#         print(idx)
        del orig_list[idx_o]
        del refined_list[idx_r]
print(len(orig_list), len(refined_list))
# Out:
# 1054 1054
# 0 0

# %%
orig_list
# Out:
# []

# %%
refined_list
# Out:
# []

# %%
label_test_exist = list((df2['class'][df['isTest']==1]))

newTest = []
for c,t in zip(df['class'], df['isTest']):
    if t==0:
        if c in label_test_exist: newTest.append(0) # 테스트셋에 같은 클래스 있는 트레이닝 셋 - accuracy 검증용
        else: newTest.append(-1) # 테스트셋에 같은 클래스 없는 트레이닝 셋 - 백본 훈련용
    else: newTest.append(1) # test set

df['target'] = newTest

# %%
df.to_csv('my_cosmetic_class.csv', encoding='utf8', index=False)

# %%
from IPython.core.display import HTML
df2 = pd.read_csv('my_cosmetic_class.csv', encoding='utf8')
display(HTML(df2.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>company</th>
#       <th>name</th>
#       <th>class</th>
#       <th>isTest</th>
#       <th>full</th>
#       <th>target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1MILLION</td>
#       <td>PERFUME</td>
#       <td>1MILLION-PERFUME</td>
#       <td>0</td>
#       <td>1MILLION-PERFUME</td>
#       <td>-1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4GF</td>
#       <td>SUPER PURE CLEAR GEL</td>
#       <td>4GF-SUPER PURE CLEAR GEL</td>
#       <td>0</td>
#       <td>4GF-SUPER PURE CLEAR GEL</td>
#       <td>-1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>6GF+</td>
#       <td>PROTEOGLYCAN SKIN CARE CREAM</td>
#       <td>6GF+-PROTEOGLYCAN SKIN CARE CREAM</td>
#       <td>0</td>
#       <td>6GF+-PROTEOGLYCAN SKIN CARE CREAM</td>
#       <td>-1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>6XCREAM</td>
#       <td>TREATROMM 6 CREAM</td>
#       <td>6XCREAM-TREATROMM 6 CREAM</td>
#       <td>0</td>
#       <td>6XCREAM-TREATROMM 6 CREAM</td>
#       <td>-1</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>9WISHES</td>
#       <td>HYDRA AMPULE SERUM</td>
#       <td>9WISHES-HYDRA AMPULE SERUM</td>
#       <td>0</td>
#       <td>9WISHES-HYDRA AMPULE SERUM</td>
#       <td>-1</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>A DERMA</td>
#       <td>PHYS AC PURIFYING FOAMING GEL</td>
#       <td>A DERMA-PHYS AC PURIFYING FOAMING GEL</td>
#       <td>0</td>
#       <td>A DERMA-PHYS AC PURIFYING FOAMING GEL</td>
#       <td>-1</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>A2H</td>
#       <td>CURL UP ESSENCE</td>
#       <td>A2H-CURL UP ESSENCE</td>
#       <td>0</td>
#       <td>A2H-CURL UP ESSENCE</td>
#       <td>-1</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>ABLE C_C</td>
#       <td>미샤M 비비 부머</td>
#       <td>ABLE C_C-미샤M 비비 부머</td>
#       <td>0</td>
#       <td>ABLE C_C-미샤M 비비 부머</td>
#       <td>-1</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>ACAI BERRY</td>
#       <td>MICELLAR CLEANSING FACE SCRUB GEL</td>
#       <td>ACAI BERRY-MICELLAR CLEANSING FACE SCRUB GEL</td>
#       <td>0</td>
#       <td>ACAI BERRY-MICELLAR CLEANSING FACE SCRUB GEL</td>
#       <td>-1</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>ACNES</td>
#       <td>CLEAR_WHITE FOAMING WASH</td>
#       <td>ACNES-CLEAR_WHITE FOAMING WASH</td>
#       <td>0</td>
#       <td>ACNES-CLEAR_WHITE FOAMING WASH</td>
#       <td>-1</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>ACNES</td>
#       <td>DERMA RELIEF ESSENCE LOTION</td>
#       <td>ACNES-DERMA RELIEF ESSENCE LOTION</td>
#       <td>0</td>
#       <td>ACNES-DERMA RELIEF ESSENCE LOTION</td>
#       <td>-1</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>ACURE</td>
#       <td>THE ESSENTIALS MOROCCAN ARGAN OIL</td>
#       <td>ACURE-THE ESSENTIALS MOROCCAN ARGAN OIL</td>
#       <td>0</td>
#       <td>ACURE-THE ESSENTIALS MOROCCAN ARGAN OIL</td>
#       <td>-1</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>ACWELL</td>
#       <td>AQUA CLINITY CREAM</td>
#       <td>ACWELL-AQUA CLINITY CREAM</td>
#       <td>0</td>
#       <td>ACWELL-AQUA CLINITY CREAM</td>
#       <td>-1</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>AESTURA</td>
#       <td>ATOBARRIER365</td>
#       <td>AESTURA-ATOBARRIER365</td>
#       <td>0</td>
#       <td>AESTURA-ATOBARRIER365</td>
#       <td>-1</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>AGE20_S</td>
#       <td>AURORA ESSENTIAL CREAM</td>
#       <td>AGE20_S-AURORA ESSENTIAL CREAM</td>
#       <td>0</td>
#       <td>AGE20_S-AURORA ESSENTIAL CREAM</td>
#       <td>-1</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>AGE20_S</td>
#       <td>CELL BOUNCE CONCENTRATED SERUM</td>
#       <td>AGE20_S-CELL BOUNCE CONCENTRATED SERUM</td>
#       <td>0</td>
#       <td>AGE20_S-CELL BOUNCE CONCENTRATED SERUM</td>
#       <td>-1</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>AGE20_S</td>
#       <td>ESSENCE COVER FACT TX</td>
#       <td>AGE20_S-ESSENCE COVER FACT TX</td>
#       <td>0</td>
#       <td>AGE20_S-ESSENCE COVER FACT TX</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>AGE20_S</td>
#       <td>ESSENCE COVER FACT VX</td>
#       <td>AGE20_S-ESSENCE COVER FACT VX</td>
#       <td>0</td>
#       <td>AGE20_S-ESSENCE COVER FACT VX</td>
#       <td>-1</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>AGE20_S</td>
#       <td>HYDRA SYNERGY CREAM</td>
#       <td>AGE20_S-HYDRA SYNERGY CREAM</td>
#       <td>0</td>
#       <td>AGE20_S-HYDRA SYNERGY CREAM</td>
#       <td>-1</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>AGE20_S</td>
#       <td>INTENSE MOISTURE CREAM</td>
#       <td>AGE20_S-INTENSE MOISTURE CREAM</td>
#       <td>0</td>
#       <td>AGE20_S-INTENSE MOISTURE CREAM</td>
#       <td>-1</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>AGE20_S</td>
#       <td>REAL CALENDULA EYE_FACE CREAM</td>
#       <td>AGE20_S-REAL CALENDULA EYE_FACE CREAM</td>
#       <td>0</td>
#       <td>AGE20_S-REAL CALENDULA EYE_FACE CREAM</td>
#       <td>-1</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>AGE20_S</td>
#       <td>ULTRA MOISTURE ESSENCE</td>
#       <td>AGE20_S-ULTRA MOISTURE ESSENCE</td>
#       <td>0</td>
#       <td>AGE20_S-ULTRA MOISTURE ESSENCE</td>
#       <td>-1</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>AGE20_S</td>
#       <td>essence cover tx</td>
#       <td>AGE20_S-ESSENCE COVER FACT TX</td>
#       <td>1</td>
#       <td>AGE20_S-essence cover tx</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>AGE20_S</td>
#       <td>에센스 쿠션</td>
#       <td>AGE20_S-에센스 쿠션</td>
#       <td>0</td>
#       <td>AGE20_S-에센스 쿠션</td>
#       <td>-1</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>AHC</td>
#       <td>AGELESS REAL EYE CREAM FOR FACE</td>
#       <td>AHC-AGELESS REAL EYE CREAM FOR FACE</td>
#       <td>0</td>
#       <td>AHC-AGELESS REAL EYE CREAM FOR FACE</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>AHC</td>
#       <td>AGELESS REAL EYE CREAM FOR FACE_2</td>
#       <td>AHC-AGELESS REAL EYE CREAM FOR FACE</td>
#       <td>0</td>
#       <td>AHC-AGELESS REAL EYE CREAM FOR FACE_2</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>AHC</td>
#       <td>Ageless Real Eye ream for Face</td>
#       <td>AHC-AGELESS REAL EYE CREAM FOR FACE</td>
#       <td>1</td>
#       <td>AHC-Ageless Real Eye ream for Face</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>AHC</td>
#       <td>Aura Secret Toneup Cream</td>
#       <td>AHC-Aura Secret Toneup Cream</td>
#       <td>0</td>
#       <td>AHC-Aura Secret Toneup Cream</td>
#       <td>-1</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>AHC</td>
#       <td>Capture Hyaluronic</td>
#       <td>AHC-Capture Hyaluronic</td>
#       <td>0</td>
#       <td>AHC-Capture Hyaluronic</td>
#       <td>-1</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>AHC</td>
#       <td>NATURE PLUS SUNSTIC</td>
#       <td>AHC-NATURE PLUS SUNSTIC</td>
#       <td>0</td>
#       <td>AHC-NATURE PLUS SUNSTIC</td>
#       <td>-1</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>AHC</td>
#       <td>Natural Vita Sun Stick</td>
#       <td>AHC-Natural Vita Sun Stick</td>
#       <td>0</td>
#       <td>AHC-Natural Vita Sun Stick</td>
#       <td>-1</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>AHC</td>
#       <td>ONLY FOR MAN LOTION</td>
#       <td>AHC-ONLY FOR MAN LOTION</td>
#       <td>0</td>
#       <td>AHC-ONLY FOR MAN LOTION</td>
#       <td>-1</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>AHC</td>
#       <td>PERFECT DUAL COVER CUSHION 23</td>
#       <td>AHC-PERFECT DUAL COVER CUSHION 23</td>
#       <td>0</td>
#       <td>AHC-PERFECT DUAL COVER CUSHION 23</td>
#       <td>-1</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>AHC</td>
#       <td>REAL ACTIVE BLENDING CREAM</td>
#       <td>AHC-REAL ACTIVE BLENDING CREAM</td>
#       <td>0</td>
#       <td>AHC-REAL ACTIVE BLENDING CREAM</td>
#       <td>-1</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>AHC</td>
#       <td>REAL ACTIVE PERFECTION CREAM</td>
#       <td>AHC-REAL ACTIVE PERFECTION CREAM</td>
#       <td>0</td>
#       <td>AHC-REAL ACTIVE PERFECTION CREAM</td>
#       <td>-1</td>
#     </tr>
#     <tr>
#       <th>35</th

# %%
print('backbone:',(df2['target'] == -1).sum(), 'train:',(df2['target'] == 0).sum(), 'val:',(df2['target'] == 1).sum())
# Out:
# backbone: 796 train: 158 val: 101

# %%
from glob import glob
from tqdm import tqdm_notebook as tqdm
import os
import subprocess

"""
이미지 데이터  df2 target에 따라서 자료 생성
"""
data_dir = '.\\LG-orignal-video\\images_full'
data_dir_new = '.\\LG-orignal-video\\images_seperated_full'

os.mkdir(os.path.join(data_dir_new, 'backbone'))
os.mkdir(os.path.join(data_dir_new, 'train'))
os.mkdir(os.path.join(data_dir_new, 'val'))

for d in os.listdir(data_dir):
    idx = list(df2['full']).index(d)
    class_name = df2['class'][idx]
    if df2['target'][idx]==1: # val set
        if not os.path.isdir(os.path.join(data_dir_new, 'val', class_name)):
            os.mkdir(os.path.join(data_dir_new, 'val', class_name))
        command = ['cmd', '\/c', 'copy',  os.path.join(data_dir, d) , os.path.join(data_dir_new, 'val', class_name)]
    elif df2['target'][idx]==0: # train set
        if not os.path.isdir(os.path.join(data_dir_new, 'train', class_name)):
            os.mkdir(os.path.join(data_dir_new, 'train', class_name))
        command = ['cmd', '\/c', 'copy',  os.path.join(data_dir, d) , os.path.join(data_dir_new, 'train', class_name)]        
    else: # backbone set       
        if not os.path.isdir(os.path.join(data_dir_new, 'backbone', class_name)):
            os.mkdir(os.path.join(data_dir_new, 'backbone', class_name))
        command = ['cmd', '\/c', 'copy',  os.path.join(data_dir, d) , os.path.join(data_dir_new, 'backbone', class_name)]

    subprocess.check_output(command)
    print(df2['target'][idx], d)
# Out:
# -1 1MILLION-PERFUME
# -1 4GF-SUPER PURE CLEAR GEL
# -1 6GF+-PROTEOGLYCAN SKIN CARE CREAM
# -1 6XCREAM-TREATROMM 6 CREAM
# -1 9WISHES-HYDRA AMPULE SERUM
# -1 A DERMA-PHYS AC PURIFYING FOAMING GEL
# -1 A2H-CURL UP ESSENCE
# -1 ABLE C_C-미샤M 비비 부머
# -1 ACAI BERRY-MICELLAR CLEANSING FACE SCRUB GEL
# -1 ACNES-CLEAR_WHITE FOAMING WASH
# -1 ACNES-DERMA RELIEF ESSENCE LOTION
# -1 ACURE-THE ESSENTIALS MOROCCAN ARGAN OIL
# -1 ACWELL-AQUA CLINITY CREAM
# -1 AESTURA-ATOBARRIER365
# -1 AGE20_S-AURORA ESSENTIAL CREAM
# -1 AGE20_S-CELL BOUNCE CONCENTRATED SERUM
# 0 AGE20_S-ESSENCE COVER FACT TX
# -1 AGE20_S-ESSENCE COVER FACT VX
# 1 AGE20_S-essence cover tx
# -1 AGE20_S-HYDRA SYNERGY CREAM
# -1 AGE20_S-INTENSE MOISTURE CREAM
# -1 AGE20_S-REAL CALENDULA EYE_FACE CREAM
# -1 AGE20_S-ULTRA MOISTURE ESSENCE
# -1 AGE20_S-에센스 쿠션
# 0 AHC-AGELESS REAL EYE CREAM FOR FACE
# 0 AHC-AGELESS REAL EYE CREAM FOR FACE_2
# 1 AHC-Ageless Real Eye ream for Face
# -1 AHC-Aura Secret Toneup Cream
# -1 AHC-Capture Hyaluronic
# -1 AHC-Natural Vita Sun Stick
# -1 AHC-NATURE PLUS SUNSTIC
# -1 AHC-ONLY FOR MAN LOTION
# -1 AHC-PERFECT DUAL COVER CUSHION 23
# -1 AHC-REAL ACTIVE BLENDING CREAM
# -1 AHC-REAL ACTIVE PERFECTION CREAM
# -1 AHC-REAL GOLD SERUM
# -1 AHC-REAL RADIANCE SERUM
# -1 AHC-REAL SYNERGY OIL
# -1 AHC-THE REAL EYE CREAM FOR FACE
# -1 AHC-ULTIMATE REAL EYE CREAM FOR FACE
# -1 AHC-VITAL BLACK SEED TONER
# -1 ALGOLOGIE-RICHESSE DES VAGUES
# -1 ALOE VERA-ALOE MOISTURIZING BRIGHT CARE
# -1 ALPECIN-COFFEIN SHAMPOO
# -1 AMOREPACIFIC-CONTOURE LIFT SKIN DEFINING CREME
# -1 AMOS-AGE CONTROL SAMPOO
# -1 AMOS-ANTI AGING CARE AGE CONTROL
# -1 AMOS-REPAIR FORCE THERAPY ESSENTIAL OIL
# -1 ANDALOUS NATURALS-AGE DEFYING NIGHT REPAIR CREAM
# -1 ANESSA-AQUA BOOSTER
# -1 ANNASUI-PERFUME
# -1 APIEU-POWER BLOCK SUN BASE
# -1 APIEU-PURE BLOCK
# -1 AQUAVELVA-Sensitive 5 in 1 after shave balm
# -1 AQUAXL-MAKE UP FOR EVER
# 0 ARITAUM-MONO EYES
# 0 ARITAUM-MONO EYES MISS MONO
# 0 ARITAUM-MONO EYES PURPLE EYES
# 1 ARITAUM-MONO EYES SOCIAL LITE
# -1 ARITAUM-SUGARBALL VELVET CHEEK COLOR
# -1 AROMATICA-ALOW MINERAL SUNSCREEN
# -1 AROMATICA-natural tinted sun cream
# -1 ASIS TOBE-Hyaluronic Essential Toner
# -1 ATOMY-EVENING CARE PEELING GEL
# -1 ATOMY-SKIN CARE SYSTEM THE FAME LOTION
# -1 ATOMY-Sunscreen SPF 50+ PA+++
# -1 ATOPALM-MOISTURE BALANCING CREAM
# -1 ATOPALM-SOOTHING GEL LOTION
# -1 ATOPALM-TOP TO TOE WASH
# -1 AVEDA-BOTANICAL KINETICS HYDRORATING LOTION
# -1 AVEDA-DAMAGE REMEDY
# -1 AVEENO-DAILY MOISTURIZING
# -1 AVENE-EAU THERMAL MIST
# -1 A_PIEU-MINERAL MONO SHADOW
# -1 A_PIEU-POWER BLOCK SUN BASE
# -1 BAMBOO-COOL WATER SOOTHING GEL
# -1 BANANABOAT-ALOE VERA GEL
# -1 BANILACO-프라임 프라이머 클래식
# -1 BATH_BODY WORKS-HELLO BEAUTIFUL ULTRA SHEA BODY CREAM
# -1 BATH_BODY WORKS-PRETTY AS A PEACH BODY LOTION
# -1 BATH_BODY WORKS-SUPER SOFT BODY BUTTER SHEA BUTTER COCONUT OIL
# -1 BEAUTYMORY-CRYSTAL EXPERT BB CREAM
# -1 BELIF-BELIEVE IN TRUTH CREAM
# -1 BELIF-BERGAMOT HERBAL EXTRACT TONER
# -1 BELIF-CREAMY MOISTURIZER DEEP MOIST
# -1 BELIF-MANOLOGY MOISTURIZER AQUA BOMB
# -1 BELIF-STRESS SHOOTER CICA BOMB CREAM
# -1 BELIF-THE TRUE CREAM AQUA BOMB
# -1 BELIF-THE TRUE CREAM MOISTURIZING BOMB
# -1 BELIF-UV PROTECTOR DAILY SUNSCREEN GEL
# -1 BENEFIC-CHA CHA TINT
# -1 BENEFIC-DANDELION BLUSHER
# -1 BENEFIC-HIGH BEAM
# -1 BENEFIC-SUGARBOMB
# -1 BENEFIC-THE PORE FESSIONAL
# 0 BENEFIT-DANDELION
# 0 BENEFIT-DANDELION BLUSH
# 1 BENEFIT-DANDELION BLUSHER
# -1 BENEFIT-the porefessional pearl primer
# -1 BENIZOIE-MILK BODY LOTION
# -1 BENIZOIE-PERFECT SUN PROTECTOR
# -1 BEVELY HILLS-POLO CLUB JOY
# 0 BEYOND-ANGEL AQUA
# 0 BEYOND-ANGEL AQUA DAILY BIG TONER
# 1 BEYOND-ANGEL AQUA DAILY BIG TONER SUPER SIZE
# -1 BEYOND-ANGEL AQUA DAILY CICA CREAM
# 0 BEYOND-ANGEL AQUA MOIST CREAM
# 1 BEYOND-ANGEL AQUA MOIST CREAM SUPER SIZE
# -1 BEYOND-ANGEL KIDS BODY LOTION
# -1 BEYOND-ARGAN THERAPY CURLING ESSENCE
# -1 BEYOND-CLASSIC HAND CREAM INTENSIVE TOTAL RECOVERY
# -1 BEYOND-DISNEY ECO CREAM
# 0 BEYOND-ECO DAILY DEFENCE AQUA SUN GEL
# 1 BEYOND-ECO DAILY DEFENSE SKIN TONE
# -1 BEYOND-HOMME ALL IN ONE FORMULA
# -1 BEYOND-LIFTING MOISTURE THE NUTCRACKER
# -1 BEYOND-OH MY SUN CREAM
# 0 BEYOND-PHYTO AQUA CREAM
# 1 BEYOND-PHYTO AQUA MOITURE CREAM
# -1 BEYOND-PHYTO AQUA WATER SUN BASE WITH SAP COMPLEX
# -1 BIO OIL-PURECELLIN OIL
# -1 BIODERMA-ATODERM
# -1 BIODERMA-ATODRM PP BAUME ULTRA NOURISHING BALM
# -1 BIODERMA-HYDRABIO CREAM
# -1 BIODERMA-HYDRABIO H2O SOLUTION MICELLAIRE
# 0 BIODERMA-SENSIBIO H2O MAKEUP REMOVER_1
# 1 BIODERMA-SENSIBIO H2O MAKEUP REMOVER_2
# 0 BIODERMA-SENSIBIO H2O MAKE_UP REMOVER
# -1 BIOSILK-SILK THERAPY ENRICHED ACTION HAIR TREATMENT
# 1 BIOSILK-SILK THERAPY FAROUK HAIR TREATMENT
# 0 BIOSILK-SILK THERAPY HAIR TREATMENT
# -1 BIOTHERM-Body Refirm Stretch Oil
# -1 BIOTHERM-EAU VITAMINEE PERFUMED BODY MILK
# -1 BIOTHERM-HOMME AQUAPOWER FRESH LOTION IN GEL
# 0 BIOTHERM-HOMME AQUAPOWER_1
# 1 BIOTHERM-HOMME AQUAPOWER_2
# -1 BIOTHERM-HOMME FORCE SUPREME INSTANT
# -1 BIOTHERM-HOMME FORCE SUPREME SERUM
# -1 BLACK BEAN-DASHU BLACK BEAN SUPER HARD SPRAY
# -1 BLACK-LIP STICK
# -1 BLACKMORES-NATURAL VITAMINE E CREAM
# -1 BLGARI-POUR HOMME PERFUME
# -1 BOBBI BROWN-CALYPSO CORAL
# -1 BOBBI BROWN-EYE SHADOW
# -1 BOBBI BROWN-FRESH MELON24
# -1 BOBBI BROWN-Long Water Cream Shadow Stick
# -1 BOBBI BROWN-LONG WEAR EVEN FOUNDATION
# -1 BOBBI BROWN-POT ROUGE FOR LIPS AND CHEEKS
# -1 BOBBI BROWN-PRIMER PLUS PROTECTION
# -1 BONABELLA-ROSE WATER TONE UP CREAM
# 0 BONABELLA-UV PROTECTION TONE UP DAILY SUN BLOCK
# 1 BONABELLA-UV WATER SHIELD SUN BLOCK
# -1 BONAMEDUSA-ALPI SNOW CREAM
# -1 BONAMEDUSA-FACE WAVE DELETE
# -1 BONAMEDUSA-FIXER_AMPOULE X MIST
# -1 BONAMEDUSA-ORANGE SKIN DELETE
# -1 BOOTS-cucumber moisturising lotion for a smooth day
# -1 BORMTREE-GOAT MILK TONE UP CREAM
# -1 BOTANITY-FLAVON SERUM
# -1 BRING GREEN-ARTEMISIA CALMING CREAM
# -1 BUBERRY-PERFUME CLASSIC WOMEN
# -1 BURBERRY-WEEKEND FOR MEN MINIATURE PERFUME
# -1 BURBERY-BRIT SHEER PERFUME
# -1 BURT_S BEES-COCONUT FOOT CREAME
# -1 BVLGARI-AQVA ATLANTIQVE
# -1 BVLGARI-BLV POUR HOMME
# 0 BVLGARI-OMNIA CORAL FOR WOMEN
# 1 BVLGARI-OMNIA EAU DE PARFUM
# -1 BYREDO-ROSE OF NO MANS_S LAND EAU DE PARFUM
# -1 CALVIN KLEIN-CK ONE SKIN MOISTURIZER
# -1 CALVIN KLEIN-CK2 PERFUME
# -1 CANMAKE-PERFECT BROWN EYES
# -1 CAPTURE-REVITE SOLUTION AMPOULE
# -1 CAREZONE-A CURE 13 TROUBLE CALMING CREAM
# 0 CAREZONE-A CURE CLARIFYING EMULSION EX
# -1 CAREZONE-A CURE SKIN SURFACE CLEARING TONE_TEXTURE SERUM
# 0 CAREZONE-DOCTOR SOLUTION A CURE CLARIFYING EMULSION
# 1 CAREZONE-DOCTOR SOLUTION A CURE CLARIFYTING TONER EX
# 0 CAREZONE-NORDENAU WATER ESSENCE
# 1 CAREZONE-NORDENAU WATER TONER
# -1 CAROLINA HERRERA-L_EAU EAU FRAICHE 100ML SPRAY
# -1 CAUDALIE-EAU DE BEAUTE BEAUTY ELIXIR
# -1 CAUDALIE-HUILE DIVINE DIVINE OIL
# -1 CAUDALIE-VINOPERFECT RADIANCE SERUM
# -1 CELIMA-DERMA NATURE FRESh BLACKHEAD JOJOBA CLEANSING OIL
# -1 CELL FUSION C-CURE SUNCREEN 100
# 1 CELL FUSION C-LASER SUN SCREEN 100
# 0 CELL FUSION C-LASER SUNSCREEN 100
# -1 CELLSKIN-RENEWAL DUAL EFFECT SERUM
# -1 CENTELLIAN24-Centellian Madeca Skin Emulsion
# 0 CENTELLIAN24-Madeca Cream
# -1 CENTELLIAN24-MADECA CREAM POWER BOOSTING FORMULA
# 1 CENTELLIAN24-MADECA MICRO SERUM
# -1 CENTELLIAN24-MADECA SOLUTION ESSENCE
# -1 CENTELLIAN24-MADECA TONING ESSENCE TREATMENT
# -1 CENTELLIAN24-MADECA UV DEFENCE SUN CUSHION
# -1 CENTELLIAN24-MADECA UV PROTECTION SUN STICK
# -1 CERACARE-RICH LOTION
# 0 CETAPHIL-MOISTURISING LOTION
# 1 CETAPHIL-MOISTURIZING LOTION
# -1 CEZANNE-MIX COLOR CHEEK
# -1 CFEAD05F-224D_4DE0_AB61_041FDEF2D19C_junghyuk lee
# -1 CHAMPS ELYSEES-EAU DE TOILETTE GUERLAIN FOR WOMEN
# -1 CHANEL-ALLURE
# -1 CHANEL-COCO MADEMISELLE PERFUME
# -1 CHANEL-COMPLETE CORRECTION CREAM
# -1 CHANEL-DEMAQUILLANT YEUX INTENSE
# -1 CHANEL-INIMITABLE EXTREME MASCARA
# -1 CHANEL-JOUES CONTRASTE
# -1 CHANEL-LE BLANC Light Creator Brightening Makeup Base
# 0 CHANEL-N5 PERFUME
# 1 CHANEL-NO.5 EAU DE TOILETTE SPRAY
# -1 CHANEL-NO5
# -1 CHANEL-POWDER BLUSH 86 DISCREATION
# 1 CHANEL-ROUGE ALLURE GLOSS 16 EXTASE
# 0 CHANEL-ROUGE ALLURE LIP STICK
# -1 CHANEL-STYLO EYE LINER
# -1 CHARMZONE-ALBA TROSS DAILY SUN
# -1 CHARMZONE-ANTI_WRINKLE PINK OIL IN SERUM
# -1 CHARMZONE-Control Cream 225g
# -1 CHARMZONE-DeAge CRD_Softening Emulsion
# -1 CHARMZONE-DeAge Red Addition Nutrient Cream
# -1 CHARMZONE-DeAge Red Addition Skin Toner
# -1 CHARMZONE-DeAge Red Edition Eye cream
# -1 CHARMZONE-ROSY VOLUME HEARTZONE CREAM
# -1 CHARMZONE-Top Class Royal Eye Cream
# -1 CHICA Y CHICO-ONE SHOT EYE PALETTE
# -1 CHLOE-EAU DE PERFUME
# -1 CHOSUNGAH-C_T Blend Easy Firming
# -1 CHOSUNGAH-슈퍼 핏 커버 파운데이션 2X 1호
# -1 CLAIRE_S KOREA-GUERISSON 9 COMPLEX
# -1 CLAIRE_S KOREA-GUERISSON MEN_S ONE
# -1 CLAIRE_S KOREA-GUERISSON SIGNATURE OIL SERUM
# -1 CLARINS-EXTRA FIRMING NECK
# -1 CLARINS-SOIN COMPLET
# -1 CLEAN AND CLEAR-페이셜 포밍 클렌저
# -1 CLEAN-WARM COTTON EAU DE PERFUME
# 0 CLEDBEL-24K GOLD SERUM
# 0 CLEDBEL-FACE LIFT PROGRAM HYDRA POWER LIFTING SERUM
# 1 CLEDBEL-GLUTA POWER WHITENING BOOSTER SERUM
# -1 CLINIQUE-BLENDED FACE POWER
# -1 CLINIQUE-CHUBBY STICK MOISTURIZING LIP COLOUR BALM
# -1 CLINIQUE-CLARIFYING MOISTURE LOTION
# -1 CLINIQUE-LIP_EYE MAKEUP PALETTE 5X COLOUR SURGE LIPSTICK
# 0 CLINIQUE-MOISTURE SURGE 72HOUR AUTO REPLENISHING
# 1 CLINIQUE-MOISTURE SURGE INTENSE SKIN FORTIFYING HYDRATOR GEL CREME
# -1 CLIO-ART SHADOW 17 NIGHT BLUE
# -1 CLIO-KILL BROW AUTO HARD BROW PENCIL 5 GRAY BROWN
# -1 CLIO-ROUSE HEEL NOODIE BROWN
# -1 CLIO-SHARP SO SIMPLE WARTERPROOF PENCIL LINER
# -1 CLIO-VEIGIN KISS SILKUID LIP
# -1 CNP LABORATORY-GREEN PROPOLIES PERFECT WRINKLE CORRECTOR
# -1 CNP LABORATORY-GREEN PROPOLIS ANTI_OXIDANT AMPULE
# -1 CNP LABORATORY-Green Propolis Engery Recharging Emulsion
# -1 CNP LABORATORY-Green Propolis Intense Firming Creem
# -1 CNP LABORATORY-Green Propolis Skin Hydrating Enhancer
# -1 CNP LABORATORY-HOME ACTIVE SUN BB CREAM
# -1 CNP LABORATORY-Tune_sun care up proection sun
# -1 CONAD-CREMA SOLARE VISO
# -1 CONDENSE-BRIGHT AND SOFT LOTION
# -1 COSMEDICS-ULOS
# -1 CREMA IDRALIA-OFFICLNA PROFUMO FARMACEUTLCA
# -1 DAISO-GREENTEA NAIL REMOVER
# -1 DARPHIN-HYDRASKIN RICH CREAM
# -1 DARPHIN-INTREAL TONER
# -1 DERMA B-EVERY DAY SUN BLOCK
# -1 DERMA PLATZ-ACTIVE LAYERED CREAM
# -1 DERMALIFT-CENTELLA REPAIR AMPOULE
# -1 DERMATORY-AZULENE HYPOALLERGENIC CICA CREAM
# 0 DEWY TREE-ULTRA VITALIZING SNAIL CREAM_1
# 1 DEWY TREE-ULTRA VITALIZING SNAIL CREAM_2
# -1 DEWYTREE-CLEAN LAB HEALTHY FOAM
# -1 DIOR-ADDICT LIP CLOW
# -1 DIOR-DIORSKIN FOREVER EXTREME CONTROL
# 1 DIOR-Jabore pearl eau de parfum
# 0 DIOR-JADORE WOMEN EAU DE PERFUME
# 0 DIOR-LIP GLOW COLOR REVIVER BALM_1
# 1 DIOR-LIP GLOW-COLOR REVIVER BALM_2
# -1 DIOR-LIP MAXIMIZER
# -1 DIOR-ROSE EN
# 0 DIPTYQUE-DO SON
# 1 DIPTYQUE-DOSON COLLECTION 34 BOULEVARD SAINT FERMAIN
# 0 DIPTYQUE-EAU DES SENS HAIR MIST
# -1 DMCK-CLEAN AC CREAM SOOTHING COMBINATION
# -1 DOCTORCOS-SNOW WHITE WATER GLOW MASK
# -1 DOLCE_GABBANA-LIGHT BLUE_1
# -1 DOLCE_GABBANA-LIGHT BLUE_2
# -1 DOLCE_GABBANA-THE ONE GENTLEMAN
# -1 DOUBLE RICH-ART DE PEAU HAIR GEL
# -1 DPC-PINK AURA CUSHION SA
# -1 DR.AG PLUS-CICAREPAIR PEELING PAD
# -1 DR.AG PLUS-INTERSIVE DERMA CICA SALVE CREAM
# -1 DR.G-A CLEAR BALANCING MOISTURIZER
# -1 DR.G-AIRY SKIN UP SUN
# 0 DR.G-BLACK SNAIL CREAM
# 0 DR.G-BLACK SNAIL CREAM_1
# 0 DR.G-BLACK SNAIL CREAM_2
# 0 DR.G-BLACK SNAIL CREAM_3
# 0 DR.G-BLACK SNAIL CREAM_4
# -1 DR.G-BRIGHTENING PEELING GEL
# -1 DR.G-BRIGHTENING UP SUN
# -1 DR.G-FILAGRIN BARRIER CREAM
# -1 DR.G-GREEN MILD UP SUN
# -1 DR.G-RED BLEMISH CLEAR CREAM
# -1 DR.JART+-BB BEAUTY BALM
# -1 DR.JART+-HOLY SKIN SOOTHING BALM
# -1 DR.JART-FOUNDATION
# -1 DR.PEPTI+-CENTELLA TONER
# -1 DR.YOUNG-ANTI PORE ERASER BALM
# 1 DRG-BLACK SNAIL CREAM
# -1 D_ALBA-WHITE TROUBLE FIRST SPREY SERUM
# -1 E45-DERMATOLOGICAL CREAM
# -1 ECLADO-OIL FREE SUN CREAM
# -1 ECLADO-Real White eRaser Cream
# -1 ECLADO-regene Blemish Balm
# -1 EDP-DOMINIQUE ROPION GERANIUM TOUR MONSIEUR
# -1 ELASTINE-Silk repair recovery oil essence
# -1 ELENSILIA CPP-PLACENTA 80 MILLESIS CREAM
# -1 ELENSILIA-ESCARGOT ORIGINAL REPAIR BEE VENOM MIST
# -1 ELIZABETH ARDEN-EIGHT HOUR CREAM
# -1 ENJOY-Perfect Daily Sun Cream
# -1 ENPRANI-ONE TOUCH SUN POWDER
# -1 ESCADA-HOMME ESSENCE EMULSION
# 0 ESPOIR-PRO TAILOR FOUNDATION
# 0 ESPOIR-PRO TAILOR FOUNDATION MEDIUM2
# 1 ESPOIR-PRO TAILOR LIQUID FOUNDATION EX
# 0 ESTEE LAUDER-ADVANCED NIGHT REPAIR
# 1 ESTEE LAUDER-Advanced Night Repair Synchronized Complex II
# 0 ESTEE LAUDER-ADVANCED NIGHT REPAIR_2
# -1 ESTEE LAUDER-DOUBLE WEAR
# -1 ESTEE LAUDER-DOUBLE WEAR STAY IN PLACE MAKEUP_1
# -1 ESTEE LAUDER-DOUBLE WEAR STAY IN PLACE MAKEUP_2
# -1 ESTEE LAUDER-Double Wear Stay_in_Place Makeyp
# -1 ESTEE LAUDER-DOUBLE WEAR ZERO MASCARA
# 0 ESTEE LAUDER-PURE COLOR CRYSTAM LIPSTIC 01 CRYSTAL BABY CREME
# 0 ESTEE LAUDER-PURE COLOR LOVE LIPSTICK_1
# 1 ESTEE LAUDER-PURE COLOR LOVE LIPSTICK_2
# -1 ESTEE LAUDER-SUMPTUOUS KNOCKOUT MASCARA
# -1 ESTETICA-HYDRA MULTI THERAPY
# -1 ESTHEMORE-컬링 에센스 2X
# -1 ETUDE HOUSE-DOUBLE LASTING FOUNDATION
# -1 ETUDE HOUSE-GLOW ON BASE
# -1 ETUDE HOUSE-PLAY COLOR EYES
# -1 ETUDE HOUSE-SOON JUNG MOIST RELIEF ALL IN ONE GEL
# -1 ETUDE HOUSE-UV DOUBLE CUT SUN GEL
# -1 EUBOS-HAUT RUHE CREAM
# -1 EUCERIN-DERMATOCLEAN CLARIFYING TONER
# -1 EUCERIN-HYALURON FILLER VOLUME LIFT
# -1 EVAS-LEMONADE MOISTURE HAND CREAM
# -1 EVOLUDERM-EAU MICELLAIRE CLEANSING WATER
# -1 EXCELMAKE-FIVE LAYERS SHADOW
# -1 FACE IT-RADIANCE MAKEUP BASE
# -1 FAIRY TALES-ROSEMARY HAIR SPRAY
# -1 FAISIES-MAYBELINE VOLUME EXPRESS
# -1 FERRARI-SCUDERIA BLACK EAU DE TOILETTE SPRAY
# -1 FERRARI-UOMO PERFUME
# -1 FIRST AID BEAUTY-ULTRA REPAIR CREAM
# -1 FIRSTLAB-PROBIOTIC REVERSE CREAM
# -1 FIXX-ALL DAY GLOW MAKEUP SETTING
# -1 FO ARUM-NATURAL BB CREAM
# -1 FRESH-SUGAR FACE POLISH
# -1 FROM NATURE-ALOEVERA PERFECT SUN BLOCK
# -1 FROM NATURE-COLLAGEN HYDRO HONEY ESSENCE
# -1 FRUIT OF THE EARTH-ALOE VERA 100_ GEL
# -1 FUERAIN-METEORITES TRAVEL TOUCH FACE POWDER
# -1 F_CO-BANILA CO PRIME PRIMER BB CREAM
# -1 GD3.4-HAIR ENHANCER AMPOULE
# -1 GINGER-LAURA MERCIER
# -1 GIORGIO ARMANI-ACQUA DI GIO POUR HOMME
# -1 GIORGIO ARMANI-LASTING SILK UV FOUNDATION
# -1 GIORGIO ARMANI-LIP MAGNET
# 0 GOODAL-DOUBLE BRIGHT DDAY AMPOULE
# 1 GOODAL-DOUBLE BRIGHT WHITENING C AMPOULE
# -1 GOODAL-GREEN TANGERINE VITA C DART SPOT SERUM
# -1 GOODAL-GREEN TAUGERINE VITA C CREAM
# -1 GOODAL-PREMIUM SNAIL TONE UP CREAM
# -1 GOONGBE-FRESS SUN LOTION
# -1 GREEN FINGER-AFTER SUN CLEANSING
# -1 GREEN FINGER-INTENSIVE SUN BALM
# 0 GREEN FINGER-KIDS FACIAL LOTION
# 1 GREEN FINGER-MY KIDS KIDS LOTION
# 1 GREEN FINGER-야외놀이 선로션 SPF PA 45
# 0 GREEN FINGER-야외놀이 선크림
# -1 GREENFINGER-ULTRA LOTION
# -1 HADALABO-GOKU JYUN PERFECT GEL
# -1 HADALABO-ROHTO HADALABO GOKUJUN HYALURONIC LOTION MIST
# -1 HADALABO-SHIRO JYUN CREAM
# 0 HADALABO-SHIRO JYUN Lotion
# 1 HADALABO-SHIRO JYUN MILK
# -1 HADALABO-기와미츠 유무워터 하또무기_비타
# -1 HAIR PLUS-OH FRESH DEEP HERBAL SCALP CLEANSING SHAMPOO
# -1 HAIR PLUS-VELVET PROTEIN BOND NUTRI INJECTION AMPOULE
# -1 HANGYEOL-SUN PROTECTOR WITH BLISS
# -1 HANSKIN-Caviar Gold BB Cream
# -1 HANYUL-PURE ARTEMISIA WATERY CALMING CREAM
# -1 HAPPY BATH-AQUA MOISTURE SUN LOTION
# -1 HAPPY BATH-Deep Cleansing Form
# -1 HAPPY BATH-FACIAL YOGURT FOAM
# -1 HAPPY BATH-PERFECT SUN CREAM
# -1 HAZZYS MEN-RULE420 WHITENING SUN ALL IN ONE
# -1 HEALTH REVOLUTION_S-HERBAL FACE FOOD
# -1 HENVX-INSTANT HARI PLUS POWDER
# -1 HERA-AGE AWAY VITALIZING NIGHT MASK
# 0 HERA-AGE REVERSE CUSHION C13
# 0 HERA-BLACK CUSHION 21
# 0 HERA-BLACK CUSHION_1
# 0 HERA-BLACK CUSHION_2
# 1 HERA-BLACK CUSHION_3
# -1 HERA-BLACK FOUNDATION WEIGHTLESS COVER FIT FOUNDATION
# 1 HERA-BLINDNESS BLACK CUSHION
# -1 HERA-HD PERFECT FOUNDATION
# -1 HERA-MAGIC STARTER
# 0 HERA-MAKE UP FIXER
# 1 HERA-MAKE UP FIXER ALL DAY FITTING
# -1 HERA-SHADOW HOLIC 4D
# -1 HERA-SIGNIA CREAM
# 0 HERA-SUN MATE EXCELLENCE
# 1 HERA-SUN MATE PROTECTOR
# -1 HERA-UV MIST CUSHION COVER
# -1 HEROINE MAKE-SMOOTH LIQUID EYELINER
# -1 HIMALAYA HERBALS-REVITALIZING NIGHT CREAM
# -1 HIMALAYA-LIP BALM
# -1 HIMALAYA-NOURISHING SKIN CREAM
# -1 HOLIKA HOLIKA-GOOD CERA SUPER CERAMIDE MIST
# -1 HOLIKA HOLIKA-PEACE MATCHING SHADOW
# -1 HUGO-Element eau de toilette
# -1 IDIUOMO-SKIN TYPE TESTATO
# -1 ILDONG-Probiotic Cream
# -1 ILLI-TOTAL AGING CARE BODY LOTION
# -1 ILLIYOON-CERAMIDE ATO CONCENTRATE CREAM
# -1 ILLIYOON-PROBIOTICS SKIN BARRIER ESSENCE DROP
# -1 IMFROM-MUGWORT ESSENCE
# -1 INNESFREE-MY EYE SHADOW
# -1 INNISFREE-ALOE REVITAL SOOTHING GEL
# 1 INNISFREE-APPLE SEED LIB _ EYE MAKE UP REMOVER
# 0 INNISFREE-APPLE SEED LIP AND EYE MAKEUP REMOVER
# -1 INNISFREE-BIJA TROUBLE LOTION
# -1 INNISFREE-BLUEBERRY REBALANCING SKIN
# -1 INNISFREE-DERMA FORMULA PEELING CREAM
# -1 INNISFREE-eco nail remover
# -1 INNISFREE-EXTREME UV PROTECTION CREAM
# -1 INNISFREE-FOREST FOR MEN FRESH CLEANSING FOAM
# -1 INNISFREE-forest for men fresh skin Jeju phytoncide complex
# -1 INNISFREE-FOREST FOR MEN PORE CARE ALL IN ONE ESSENCE
# -1 INNISFREE-green barley Peeting Toner
# 0 INNISFREE-green tea lotion for men
# -1 INNISFREE-GREEN TEA SEED ESSENC IN LOTION
# -1 INNISFREE-green tea seed serum
# 1 INNISFREE-Green tea Skin for Men
# -1 INNISFREE-INTENSIVE LONG LASTIN SUNSCREEN
# -1 INNISFREE-JEJU CHERRY BLOSSOM SKIN
# -1 INNISFREE-JEJU ORCHID SKIN
# -1 INNISFREE-JEJU SPARKLING MOISTURE
# -1 INNISFREE-MOISTURIZING OIL SERUM
# -1 INNISFREE-MY DROP WATER MOISTURE
# -1 INNISFREE-NAIL REMOVER
# -1 INNISFREE-OLIVE REAL CLEANSING FOAM
# -1 INNISFREE-olive real essential oil Ex
# 0 INNISFREE-PERFECT 9 REPAIR CREAM EX
# 1 INNISFREE-PERFECT 9 REPAIR EYE CREAM
# 0 INNISFREE-perfect uv protection cream
# 1 INNISFREE-PERFECT UV PROTECTION CREAM(1)
# -1 INNISFREE-PERFECT9 REPAIR LOTION
# -1 INNISFREE-SOYBEAN ENERGY NECK CREAM
# -1 INNISFREE-SOYBEAN ENERGY OIL
# -1 INNISFREE-TRUECARE NON_NANO SUNSCREEN
# -1 INNISFREE-마이 블러셔 햇살 가득 장미
# -1 INNISFREE-비비드 후르츠 틴트 물 먹은 체리
# -1 INNODERM-INNODERM CREAM
# -1 IOPE-AIR CUSHION MOISTURE RESTING
# -1 IOPE-BIO ESSENCE INTENSIVE CONDITIONING
# -1 IOPE-BIO NIGHT MASK INTENSIVE RECHARGING
# -1 IOPE-CC
# -1 IOPE-DERMA REPAIR CICA CREAM
# -1 IOPE-DERMA REPAIR CLEAN SUN STICK
# -1 IOPE-EYEBROW AUTO PENCIL EX
# -1 IOPE-LIP STICK
# -1 IOPE-LIVE LIFT EMULSION
# -1 IOPE-LIVE LIFT SOFTENER
# -1 IOPE-MOIST CLEANSING OIL
# -1 IOPE-PERFECT SKIN BASE
# -1 IOPE-UV SHIELD
# -1 IPKN MAN-TOWER ACTIVE(LITE) ALL IN ONE PRO
# -1 ISA KNOX-365 SUN CREAM
# -1 ISA KNOX-Heating Drop Cream
# -1 ISA KNOX-HOMME SKIN CARE AFTERSHAVE
# -1 ISA KNOX-HYDRO LIFTING TREATMENT REPAIR SERUM
# -1 ISA KNOX-IDEAL RINGER MEDIHYALON DROP
# -1 ISA KNOX-MX_II PLATINUM ULTRA MOISTURE EMULSION
# -1 ISA KNOX-NOX LAB EYE CREAM RETINOL _ MOISTURE LIPOSOME
# -1 ISA KNOX-Powdery Cotton Sun Stick
# -1 ISA KNOX-Tervina LX Homme Regenerating Torner
# 0 ISA KNOX-THE PRESTIGE RE ACTIVE CONCENTRATING CREAM
# 1 ISA KNOX-THE PRESTIGE RE ACTIVE CONCENTRATING SERUM
# 0 ISA KNOX-THE PRESTIGE RE ACTIVE HYDRATING EMULSION
# -1 ISA KNOX-UV SUN PRO BEAUTY SUN
# -1 ISA KNOX-X2D2 PORE CORRECTOR SERUM
# -1 ISA NOX-POWDERY COTTON SUN STICK
# -1 ISOI-BR MOISTURIZIP
# -1 ISOI-PORE TIGHTENING FRESH GEL CREAM
# -1 IT_S SKIN-COLLAGEN NUTRITION EMULSION
# -1 IT_S SKIN-IT_S TOP BY ITALY SATIN LIP PENCIL
# -1 IT_S SKIN-POWER 10 FORMULA WR FACE _ BODY OIL MIST
# -1 I_M MEME-I_M SHADING PALETTE
# -1 J.ESTINA-PEARL FECTION FLOW FIXER
# -1 JAMINKYUNG-CARACOL ALL IN ONE CREAM
# -1 JIMMY CHOO-BODY LOTION
# 0 JIMMY CHOO-EAU DE TOILETTE
# 1 JIMMY CHOO-오드트휠렛
# -1 JJHO DERMA-D MOISTURE CREAM
# 0 JO MALONE-BLACKBERRY AND BAY COLOGNE
# 0 JO MALONE-BLOSSOM AND HONEY COLOGNE
# 0 JO MALONE-ENGLISH PEAR _ FREESIA
# 0 JO MALONE-LACKBERRY_BAY COLOGNE
# 0 JO MALONE-OSMANTHUS BLOSSOM COLOGNE
# 1 JO MALONE-WOOP SAGE _ SEA SALT COLOGNE
# 0 JOHN VARVATOS-ARTISAN
# 1 JOHN VARVATOS-ARTISAN_1
# -1 JUNGSAEMMOOL-ARTIST CONCEALER PALETTE
# -1 J_COCEU-PEPTIDE VOLUME ESSENCE
# 0 KAMILL-HAND _ NAGELCREME
# 1 Kamill-Hand _ Nail Cream
# 0 KAMILL-HAND_NAGELCREME CLASSIC
# 0 KAMILL-HAND_NAIL CREAM_1
# 0 KAMILL-HAND_NAIL CREAM_2
# 0 KAMILLE-HANDCREME
# -1 KARADIUM-DEEP PORE CLEAN CLEANSING WATER
# 0 KATE-BROWN SHADE EYES_1
# 1 KATE-BROWN SHADE EYES_2
# -1 KATE-DESIGNING EYE BROW
# -1 KATE-POWDERIESS LIQUID FOR COVER
# -1 KENNETH COLE-BLACK
# -1 KENZO-LEAU KENZO POUR HOMME
# -1 Kerastate-Nutritive Nectar Thermique
# -1 KIEHL_S-CALENDUAL HERBAL EXTRACT ALCOHOL FREE TONER
# -1 KIEHL_S-CALENDULA DEEP CLEANSING FOAMING FACE WASH
# -1 KIEHL_S-CLEARLY CORRECTIVE DARK SPOT SOLUTION
# 0 KIEHL_S-FACIAL FUEL ENERGIZING TONIC FOR MAN
# 1 KIEHL_S-FACIAL FUEL ENERGIZING TONIC FOR MEN
# -1 KIEHL_S-LIP BALM CRANBERRY
# -1 KIEHL_S-MID NIGHT RECOVERY CONCENTRATE
# 0 KIEHL_S-POWERFUL STRENGTH LINE REDUCING CONCENTRATE
# 1 KIEHL_S-PRECISION LIFTING _ PORE TIGHTENING CONCENTRATE
# -1 KIEHL_S-TURMERID _ CRANBERRY SEED ENERGIZING RADIANCE MASQUE
# 0 KIEHL_S-ULTRA FACIAL CREAM
# 0 KIEHL_S-ULTRA FACIAL CREAM_1
# 0 KIEHL_S-ULTRA FACIAL CREAM_2
# 1 KIEHL_S-ULTRA FACIAL CREAM_3
# -1 KIEHL_S-ULTRA FACIAL TONER
# -1 KIEHL_S-ULTRA LIGHT DAILY UV DEFENSE
# -1 KISS ME-EYELINER BLACK
# 0 KISS ME-HEAVY ROTATION COLORING EYEBROW
# -1 KISS ME-HEROINE MAKE MASCARA
# 0 KISS ME-HEROINE MAKE SMOOTH LIQUID EYELINER
# 1 KISSME-HEAVY ROTATION COLORING EYRBROW
# 0 KISSME-HEROINE MAKE SMOOTH LIQUID EYE LINER
# 0 KISSME-HEROINE MAKE SMOOTH LIQUID EYELINER
# 1 KISSME-HEROINE MAKEUP SMOOTHING EYELINER
# -1 LA RECHE POSAY-LIPIKAR LOTION
# 0 LA ROCHE POSAY-EFFACLAR DUO
# 0 LA ROCHE POSAY-EFFACLAR K
# -1 LA ROCHE POSAY-EFFACLAR LOTION ASTRINGENTE
# 1 LA ROCHE POSAY-EFFACLAR MAT
# 0 LA ROCHE POSAY-LIPIAR LAIT LOTION
# 1 LA ROCHE POSAY-TOLERIANE CRME MOUSSANCTE PURIFLANTE
# -1 LA ROCHE POSAY-TOLERIANE DERMO CLEANSER
# 1 LAB SERIES FOR MEN-Rescue Water Lotion
# -1 LAB SERIES-AGE RESCUE FACE LOTION
# 0 LAB SERIES-RESCUE WATER LOTION
# -1 LAB SERIES-SOLID WATER ESSENCE
# -1 LABEL YOUNG-EFFECT RECIPRE SPOT TONING VER PREMIUM
# -1 LABEL YOUNG-SHOCKING FOOT PEELING CREAM
# -1 LABEL YOUNG-SHOCKING SCALP PACK
# -1 LABIOTTE-Collagen water soothing gel
# -1 LACVERT-CATHY CAT COLOR TALK EYES
# -1 LACVERT-HELLO HYALURON TONER
# 0 LACVERT-HOMEE RECHARGE MILD SET EMULSION 35ML
# 0 LACVERT-HOMME RE CHARGE MILD SET AFTERSHAVE
# 0 LACVERT-HOMME RECHARGE MILD SET AFTERSHAVE 160ML
# 1 LACVERT-HOMME RECHARGE MILD SET AFTERSHAVE 35ML
# -1 LACVERT-MINT TONE UP SUN CREAM
# -1 LACVERT-PURE DEEP CLEANSING OIL
# -1 LAFEMME-PLACENTA CREAM MOISTURISER WITH COENZME
# -1 LAHEIN-SALON LONG LASTING
# -1 LANCOME-BALLERINE NEW SPRINT 2014 NAIL
# -1 LANCOME-GRANDIOSE MASCARA
# -1 LANCOME-MIRACLE PERFUME
# -1 LANCOME-UV EXPERT MILKEY BRIGHT
# -1 LANCOME-UV EXPERT YOUTH SHIELD BB COMPLETE
# -1 LANEIGE-BB CUSHION PORE CONTROL
# 0 LANEIGE-CREAM SKIN
# 1 LANEIGE-CREAM SKIN REFINER
# -1 LANEIGE-HOMME ACTIVE WATER BANACING EMULSION
# -1 LANEIGE-HOMME ACTIVE WATER CLEANSER
# -1 LANEIGE-HOMME ACTIVE WATER TONER
# -1 LARINS-MANUKA FACIAL MUD MASK
# 0 LAROCHE POSAY-CICA PLAST BAUME B5 SOOTHING REPAIRING BALM
# 0 LAROCHE POSAY-DERMO SOOTHING HYDRATING LOTION
# 1 LAROCHE POSAY-TOLERIANE FLUIDE
# 0 LAROCHE POSAY-TOLERIANE ULTRA CONTOUR YEUX
# 1 LAROCHE POSAY-TOLERIANE ULTRA LIGHT INTENSE SOOTHING FLUID FACE AND EYES
# -1 LAURA MERCIER-INVISIBLE LOOSE SETTING POWDER
# 0 LAURA MERCIER-MATTE EYE COLOUR
# 1 LAURA MERCIER-MATTE EYE COLOUR_2
# -1 LAVIDA-COLLAGEN SOLUTION SERUM
# -1 LE BLANC REAL-DROP H ESSENCE
# -1 LEADERS-TRIPLE CURE SUN STICK
# -1 LEZE-TREATMENT MOISTURING SERUM
# -1 LG LIFE_HEALTH-ART DE PEAU HAIR GEL
# 0 LG-praL
# 1 LG-praL2
# -1 LILYBYRED-MOOD LIAR VELVET TINT
# -1 LIP MAGNET-MATTE LIP GLOSS
# -1 LIRIKOS-KAKAO FOUDER
# -1 LOCCITANE-BRUME PERFECTRICE PERFECTING MIST
# -1 LOCCITANE-CEAME MAINS HAND CREAM
# -1 LOCCITANE-LAVANDE LAIT CORPS BODY LOTION
# -1 LOCCITANE-MINI PURE SHEA BUTTER
# -1 LOREAL-COLLAGEN MOISTURE FILLER
# -1 LOREAL-HYDRAFRESH ULTRA HYDRATING GEL CREAM
# -1 LOREAL-LIP STICK
# -1 LOTREE-ROSA DAVURICA POWDER PACT
# -1 LOVEYDOVEY-FRAGRANCE BODY MIST
# -1 LOWELL-DONO CURE CREMA HAIR STYLING TREATMENT
# -1 LUK-THE HAIR CUSHION
# -1 LUNA-LONG LASTING TIP CONCEALER
# -1 LUNA-SOFT FACE FOUDER
# 0 LUNASOL-EYE SHADOW
# 1 LUNASOL-Sking Modeling Eyes 01
# -1 LUSH-CATASTOPHE COSMETIC FRESH FACE MASK
# -1 M.T.E-MINERAL TONING ESSENCE
# -1 MAC-LIGHT SCAPADE MINERALIZE SKIN FINISH
# 0 MAC-LIP STICK
# 0 MAC-LIP STICK2
# 1 MAC-LUSTRE LIP STICK
# 0 MAC-MAKE UP POWDER MEDIUM DARK
# 0 MAC-POUDER KISS LIP STICK
# -1 MAC-PRE+PRIME FIX+
# -1 MAC-PRO LONGWEAR MOURISHING WATER PRO FOUNDATION
# -1 MAC-STUDIO CAREBLEND PRESSED
# -1 MAC-STUDIO FIX FLUID SPF BROAD SPECTRUM
# 0 MAC-Vegas Volt
# 0 MAC-VEGAS VOLT AMPLIFIED LIP STICK_1
# 0 MAC-VEGAS VOLT AMPLIFIED LIP STICK_2
# -1 MAC-VERSICOLOUR STAIN
# -1 MACQUEEN-TONE ON TONE SHADOW PALETTE
# -1 MAD HIPPIE-VITAMIN C SERUM
# -1 MADECA21-TECASOL TONER
# -1 MAIIM-RAHEL NATURAL LOTION
# -1 MAKE UP FOR EVER-Aqua XL Ink Eye Liner
# -1 MAKEUP HELPER-ORIGINAL PRO FINISH
# -1 MAKOLICA-SHADOW BE286
# -1 MAMONDE MEN-MOISTURE CONTROL LOTION
# -1 MAMONDE MEN-Recharging Lotion
# -1 MAMONDE-CHAMOMILE PURE TONER
# -1 MAMONDE-CREAMY TINT COLOR BALM LIGHT NO
# -1 MAMONDE-EVERYDAY SUN CREAM
# -1 MAMONDE-MOISTURE CERAMIDE
# -1 MAMONDE-MOISTURE CREAM EMULSION
# -1 MAMONDE-PANG PANG HAIR SHADOW 01 BABYFACE HAIRLINE
# 0 MAMONDE-ROSE WATER TONER
# 1 MAMONDE-ROSE WATER TONER_2
# 0 MANOLOGY-AQUA BOUNCING WATER LOTION
# 1 MANOLOGY-MOISTURIZER AQUA BOMB
# -1 MANYO FACTORY-GALAC FOR MEN DAILY SUN MOISTURIZING LOTION
# -1 Marc Jacobs-Daisy Dream
# -1 MARC JACOBS-RAIN PERFUME
# -1 MARY KAY-satin hands cream
# -1 MATSU KRYO-ACNE CLEANSING FOAM
# -1 MATT-TOUCH LIPSTIC BATONE A LEVRES
# -1 MAVIS VIVAUDOU-DUAL LOOSE CUBE
# -1 MAXCLINIC-TONE UP BB CUSHION
# -1 MAY NEWYORK-SUPER CLEAR SUN STICK
# -1 MAY NEWYORK-SUPER SUN STICK
# -1 MAYBELLIN-THE FALSIES
# -1 MAYBELLINE-FASHION BROW
# -1 MAYBELLINE-PORELESS AND MATTE FIT ME CONCEALER
# -1 MAYBELLINE-ROCKET VOLUME EXPRESS
# -1 MDOC-SEBUM STRIKE SERUM 100ml
# -1 MDOC-SEBUM STRIKE TONER
# -1 MDOC-SKIN PORE PRIMER
# -1 MDOC-WHITENING TONE UP CREAM
# -1 MEDICUBE-ZERO PORE PAD
# -1 MEDITIME-BOTALINUM CONCENTRATE CARE CREAM
# -1 MEDI_PEEL-Bor_Tox
# -1 MEGA-FIRST C SERUM PURE VITAMIN C
# -1 MENTHLATUM-DEEP MOIST LIP BAM
# -1 MIBA-ION CALCIUM MINERAL BB CREAM
# -1 MIGUHARA-ANTI WRINKLE PERFECT AMPLE
# -1 MIGUHARA-Ultra Whitening  Ample
# -1 MIRACLE30-YOUTH AMPOULE
# -1 MISEENSCENE-ALL AT ONCE ESSENCE
# -1 MISEENSCENE-CURLING ESSENCE 2X
# -1 MISEENSCENE-LIMITED PERFECT SERUM ROSE PETAL EDITION
# 0 MISEENSCENE-PERFECT SERUM
# 1 MISEENSCENE-PERFECT SERUM STYLING
# 0 MISEENSCENE-PERFECT SERUM_1
# 0 MISEENSCENE-PERFECT SERUM_2
# -1 MISS DIOR-BLOOMING BOUQUET
# -1 MISSHA-ALL AROUND SAFE BLOCK SEBUM ZERO SUN
# -1 MISSHA-LAYER BLURRING PRIMER SHIMMER
# 0 MISSHA-M PERFECT COVER BB CREAM
# 1 MISSHA-PERFECT COVER BB CREAM
# -1 MISSHA-Perfumed Show Cologne Heaven Blue
# -1 MISSHA-SAFE BLOCK ESSENCE SUN 45
# -1 MISSHA-SIGNATURE DEWY ROUGE
# -1 MISSHA-SIGNATURE FLAWLESS COVER STICK CONCEALER
# -1 MISSHA-STROBEAM
# -1 MISSHA-TIME REVOLUTION NIGHT REPAIR BORABIT AMPOULE
# 1 MISSHA-TIME REVOLUTION THE FIRST INTENSIVE MOISUTE
# 0 MISSHA-TIME REVOLUTION THE FIRST TREATMENT ESSENCE
# -1 MISSHA-TRIPLE SHADOW
# -1 MISSHA-VITAMIN B12 DOUBLE HYDROP AMPOULER
# -1 MOLTON BROWN-COCO_SANDALWOOD NOURISHING BODY LOTION
# -1 MOREMO-HIGH PROTEIN AMPOULE CREAM
# 0 MOROCCANOIL-MOROCCANOIL TREATMENT
# 1 MOROCCANOIL-Treatment
# -1 N7-PROTECT_PERFECT INTENSE EYE CREAM
# -1 NARS-AQUA GLOW CUSION
# -1 NARS-FOUNDATION
# -1 NARS-GINA BLUSH
# -1 NARS-LIP STICK
# 1 NARS-LIQUID BLUSH SEXAPEAL
# -1 NARS-NAMSAN AQYA GLOW CUSHION FOUNDATION
# -1 NARS-RADIANT CREAMY CONCEALER
# 1 NARS-SEX APPEAL
# 0 NARS-SEX APPEAL MAKE UP
# 0 NARS-SHAKE WELL BIEN AGITER FOUNDATION
# -1 NARS-VELVET LIP GLID PLAY PEN
# -1 NARS-VELVET MATTE LIP PENCIL
# -1 NARURE REPUBLIC-SUPER AQUA MAX
# -1 NATURE REPUBLIC-BUY FLOWER BLUSHER
# -1 NATURE REPUBLIC-COLLAGEN BB CREAM
# -1 NATURE REPUBLIC-PROVANECE AIR SKIN FIT
# -1 NATURE REPUBLIC-SHEA BUTTER ULTRA STREAM CREAM
# -1 NATURE REPUBLIC-바이플라워 트리플 무스 틴트 레드 무스
# -1 NEUTROGENA-BEACH DEFENSE SUNSCREEN LOTION
# 1 NEUTROGENA-FOOT CREAM
# 0 NEUTROGENA-HAND CREAM
# -1 NO BRAND-BABT COMFORT LOTION
# -1 NO BRAND-BE ACTIVE PURE SUNSTICK
# -1 NOODLE_BOO-BOUNCING BABY BUBBLES
# -1 NOW SOLUTION-SHEA BUTTER MOISTURE
# -1 NU SKIN-NACPA MOISTURE MIST
# -1 NUSKIN-pure cleansing gel
# -1 NUSKIN-SUNRIGHT for Face _ Body
# -1 NUXE-HUILE PRODIGIEUSE
# -1 NUXE-REVE DE MIEL HAND AND NAIL CREAM
# -1 O HUI-DAY SHIELD
# 0 O HUI-MIRACLE MOISTURE CLEANSING FOAM
# -1 O HUI-MIRACLE MOISTURE CREAM
# -1 O HUI-MIRACLE MOISTURE EMULSION
# -1 O HUI-MIRACLE MOISTURE SKIN SOFTNER
# -1 OBSIDIEN-CURLING START 2 SWING
# -1 ODYSSEY-ROMANTIC EMULSION
# -1 ODYSSEY-SKIN REFINER
# -1 OGANACELL-PEPTIDE RECOVERY CREAM
# -1 OHUI-AGE RECOVERY EYE CREAM FOR ALL
# -1 OHUI-AGE RECOVERY SKIN SOFTERNER
# -1 OHUI-ANTI WRINKLE AGE RECOVERY CREAM
# -1 OHUI-ANTI WRINKLE AGE RECOVERY EMULSION
# 1 OHUI-MIRACLE MOISTURE CLEANSING FOAM
# -1 OHUI-PERFECT SUN POWDER
# -1 OHUI-PERFECT SUN WATER CLEANSER
# -1 OHUI-PHYTO VITAMIN PRIME ADVANCER EMULSION
# -1 OHUI-PRIME ADVANCER SKIN SOFTNER
# -1 OHUI-SECOND SKIN FOUNDATION
# -1 OLAY-ACTIVE HYDRATING HYDRATATION ORIGINAL CREAM
# -1 ON THE BODY-FACE_BODY PERFECT SUN LOTION
# -1 ON THE BODY-ONE SHOT SUN KILL
# -1 ON THE BODY-THE NATURAL COCONUT OIL BODY LOTION
# -1 ONTHEBODY-NATURAL NO SEBUM SUN PACT
# -1 ONTHEBODY-SPA NATUAL THERAPY GINGERLEMON REVITAL BODY OIL
# -1 ORGAPLUS-ULTRA PURE SUN STICK
# -1 ORIENTAL-GOLD BB CREAM
# -1 PALMER_S-COCONUT OIL BODY LOTION
# -1 PAULA_S CHOICE-hydralight moisture_infusing lotion
# 0 PAULA_S CHOICE-PORE REDUCING TONER
# 1 PAULA_S CHOICE-Pore_Reducing Toner
# -1 PAULA_S CHOICE-RESIST SUPER LIGHT DAILY WRINKLE DEFENSE
# 1 PAULA_S CHOICE-SKIN BALANCING INVISIBLE FINISH MOISUTRE GEL
# -1 PAULA_S CHOICE-SKIN BALANCING PORE REDUCING TONER
# 0 PAULA_S CHOICE-Skin Balancing Ultra Sheer Daily Defense
# 0 PAULA_S CHOICE-Skin Perfecting 8_ AHA GEL
# 1 PAULA_S CHOICE-SKIN PERFECTING AHA GEL EXFOLIANT
# 0 PAULA_S CHOICE-SKIN PERFECTING BHA LIQUID
# -1 PAULA_S CHOICE-Super light Daily Wrinkle Defense
# -1 PAULA_SCHOICE-PORE CLARIFYING CHARCOAL GEL MASK
# 0 PEPTIDE-Volume Essence
# 1 PEPTIDE-Volume Essence_2
# -1 PERIPERA-INK AIRY VEVET 02
# -1 PERIPERA-INK BLACK CARE VOLUME CURLING
# -1 PERIPERA-VELVET CHEEK
# -1 PETERTHOMASROTH-MEGA RICH CODITIONER
# -1 PHYSIOGEL-CALMING RELEF SERUM
# -1 PHYSIOGEL-CODZIENNE NAWILZANIE
# 0 PHYSIOGEL-DAILY MOISTURE THERAPY
# 0 PHYSIOGEL-DAILY MOISTURE THERAPY FACIAL CREAM
# 0 PHYSIOGEL-Daily Moisture Therapy Facial Lotion
# 1 PHYSIOGEL-DAILY MOISTURE THERAPY FAICAL CREAM
# -1 PHYSIOGEL-DAILY MOISTURE THERAPY FOR DRY AND SENSITIVE SKIN
# 1 PHYSIOGEL-DAILY MOISTURE THERAPY(1)
# 0 PHYSIOGEL-FACIAL LOTION
# 0 PHYSIOGEL-HYPOALLERGENIC BODY LOTION
# -1 PHYSIOGEL-LAGODZENIE I ULGA
# -1 PHYTO VITAL-DEEP MOISTURIZING MASK
# -1 POLO SPORT-RALPH LAUREN
# -1 POLO-BLACK BY RALPH LAUREN FOR MEN
# 0 PONDS-BB MAGIC POWDER
# 0 POND_s-BB Magic Power
# -1 POND_S-CLEAR FACE SPA LIP_EYE REMOVER
# 1 POND_S-MAGIC POWDER BB CREAM
# -1 POWDER4ROOM-FULL COVER SKIN FIXING CREAM
# -1 POWER4ROOM-MAKE UP POWER FIXX
# -1 PREM-PROTECT YOUR SKIN FROM THE SUN
# -1 PRETTY AS A PEACH-SUPER SMOOTH BODY LOTION
# -1 PRIMERA-CURE EYE CREAM ORGANIENCE
# -1 PRIMERA-EMULSION ORGANIENCE
# -1 PRIMERA-OIL FREE GEL CREAM
# -1 PROFESSIONAL STRENGTH-5_ GLYCOLIC ACID CREME
# -1 RAUSCH-ANTI DANDRUFF SHAMPOO
# -1 REAL BARRIER-AQUA SOOTHING GEL CREAM
# -1 REAL BARRIER-EXTREAM CREAM
# -1 RENEW-INTENSIVE SKIN THERAPY
# -1 RENK-EYE SHADOW
# -1 RENK-Real White Gel Cream
# -1 RENK-TRIPLE RAGIANCE COLOR CREAM
# -1 RICH SKIN-MOIST UP FACE MIST GREEN TEA
# -1 RIRE-BUBLE BUBLE LIP MASK
# 0 RMK-FOUNDATION_1
# 1 RMK-FOUNDATION_2
# -1 RMK-INGENLOUS POWDER CHEEKS
# -1 RMK-Liquid Foundation
# -1 RMK-UV FACE PROTECTOR
# -1 ROKKISS-TEA TREE MOISTURINZING CREAM
# 0 ROUND LAB-독도 토너
# 1 ROUNDLAB-1025 DOCKDO TONER
# -1 ROVECTIN-TREATMENT LOTION
# -1 RYUSPA-FACIAL CREAM
# -1 S2ND-PINK TOUCH ALL IN ONE TONE UP CREAM
# -1 SABON-BODY SCRUB PATCHOULI VAVENDER VANILLA
# -1 SABON-Lip Balm Vanilla Coconut
# -1 SAINT LAURENT-LIP STICK
# 1 SAINT LAURENT-LIP TINT
# -1 SANTA MARIA NOVELLA-ACQUA DI ROSE WATER
# -1 SCINIC-CICANOID AMPOULE
# -1 SCINIC-ENJOY ALL ROUND AIRY SUN STICK
# -1 SCINIC-FIRST TREATMENT ESSENCE
# -1 SCINIC-MASTER PLUS
# -1 SCUDERIA FERRARI-BLACK SIGNATURE
# -1 SEBAMED-EXTREME DRY SKIN RELEF FACE CREAM
# -1 SENKA-HADA LABO GOKU_JYUN PERFECT GEL
# 0 SENKA-PERFECT WHIP
# -1 SENKA-PERFECT WHIP COLLAGEN IN
# 1 SENKA-PERFECT WHIP_2
# -1 SERENDIBEAYTY-NATURAL MOURISING FACE OIL
# -1 SHU UEMURA-PETAL SKIN FUID FOUNDATION
# 0 SHU UEMURA-UNLIMITED BREATHABLE LASTING FOUNDATION
# 1 SHU UEMURA-unlimited foundation
# -1 SHU UEMURE-POWDER
# -1 SIDMOOL-ATMEAL WATERFULL CREAM
# -1 SIDMOOL-ATO LOTION WITH NATURAL INGREDIENTS
# -1 SIDMOOL-GREEN TEA SKIN
# -1 SIDMOOL-ROYAL HONEY PEPTIDE DEEP MOISTURE PACK
# -1 SIDMOOL-SUBUN GADEUK SUN SPRAY
# -1 SIDMOOL-ULTRA FACIAL MOISTURIZING LOTION
# -1 SIDMOOL-다당류 리얼 수분 에센스
# -1 SIDMOOL-살구씨 딥 클렌징 오일
# -1 SIDMOOL-카카두 아미노 클렌져
# -1 SISLEY-FLORAL TUONING LOTION
# -1 SK II-MEN FACIAL TREATMENT ESSENCE
# 1 SK II-RNA POWER EYE CREAM RADICAL NEW AGE
# 0 SK II-RNA POWER RADICAL NEW AGE
# -1 SK II-STEMPWER EYE CREAM
# -1 SKIN FOOD-ALL OVER MUFFIN CAKE FINISH
# -1 SKIN FOOD-GOLD CAVIAR EMULSION
# -1 SKIN FOOD-PEACH COTTON MULTI FINISH POWDER
# -1 SKIN FOOD-석류 립 시크
# -1 SKIN HD-COLAGENIC CHEEK
# -1 SKIN ORGANICS-MOISTURE RESTORING NIGHT CREAM
# -1 SKINEYE-AC PURE SOOTHER SLEEPING PACK
# -1 SKINFOOD-MINERAL SUGAR TRIPLE SHADOW
# -1 SKINFOOD-WHITE GRAPE
# -1 SKIN_LAB-BARRIERDERM INTENSIVE CREAM
# -1 SO NATURAL-ALL DAY TIGHT MAKE UP SETTING FIXER
# -1 SOHAIR-MOROCOCO ARGAN OIL
# -1 SOMEBYMI-AHABHAPHA 30DAYS MIRACLE TONER
# -1 SONATURAL-CENTELLA MAGIC POWER
# -1 SONREVE-DAILY SUN PROTECTION
# -1 SONREVE-FACE_NECK SLEEPING MASK
# -1 SONREVE-TRI BIO TREATMENT ESSENCE
# -1 SOORYEHAN-BCHAEK TRUE EYE CREAM
# -1 SOORYEHAN-BICHAEK TRYE REJUVENATING EMULSION
# -1 SOORYEHAN-BIO GINSENG FIRST ESSENCE
# -1 SOORYEHAN-CHEAYUL ESSENCE
# -1 SOORYEHAN-REPAIR ESSENCE
# -1 SOORYEHAN-진생진액
# -1 SOORYEHAN-효 구효진 보울 오일
# -1 STAGE PERFORMER GLOW CREATOR-BASE _ TOP GLOW BOOSTING CREAM
# -1 STILA-MATTE N METAL EYE SHADOW PALETTE
# -1 STRIDEX MAXIMUM-ACNE MEDICATION PADS
# -1 STRIDEX-SINGLE STEP CLEANSING
# -1 STYLENANDA-3ce red recipe matte lip color
# -1 SULHWASOO-SNOWISE WHITENING ESSENCE
# -1 SULHWASOO-수올미스트
# 1 SULHWASOO-여윤팩
# 0 SULWHASOO-CLEAR MASK
# 1 SULWHASOO-ESSENTIAL BALANCING EMULSION EX
# 0 SULWHASOO-ESSENTIAL BALANCING WATER EX
# -1 SULWHASOO-ESSENTIAL FIRMING CREAM EX
# -1 SULWHASOO-ESSENTIAL REJUVENATING EYE CREAM 25ML
# -1 SULWHASOO-FIRST CARE ACTIVATING SERUM
# -1 SULWHASOO-RENODIGM DUAL CARE CREAM
# -1 SULWHASOO-SNOWISE BRIGHTENING SERUM
# -1 SULWHASOO-립스틱 4호
# -1 SULWHASOO-순행클랜징폼
# 0 SULWHASOO-옥용팩
# -1 SULWHASOO-자음유액
# -1 SUM-SECRET EYE CREAM
# -1 SUM-TIME ENERGY SKIN RESETTING MOIST FIRMING CREAM
# -1 SUM-WHITE AWARD
# -1 SUM37-SECRET ESSENCE MIST
# -1 SUNSILK-DAMAGE RESTORE
# -1 TAF-ESSENTIAL 7 SKIN
# -1 TEGEL-HAND AND BODY LOTION
# -1 THE BODY SHOP-MORINGA SHOWER GEL
# -1 THE BODY SHOP-WHITE MUSK EAU DE TOILETTE
# -1 THE FACE SHOP-STYLIST SUPER HARD WAX
# -1 THE FACESHOP-ANTI DARKENING CUSHION
# -1 THE FACESHOP-HIGHLIGHTER BEAM BASE ILLUMINATRICE
# -1 THE FACESHOP-INK LIPQUID RED SING
# 0 THE FACESHOP-JEJU ALOE
# 1 THE FACESHOP-JEJU ALOE FRESH SOOTHING GEL
# -1 THE FACESHOP-LA MARCHE THERAPHY FIST SERUM
# -1 THE FACESHOP-NATURAL SUN BODY _ FAMILY MILD SUN MILK
# -1 THE FACESHOP-NATURAL SUN INORGANIC SUN SCREEN STICK
# -1 THE FACESHOP-OIL CLEAR SMOOTH AND BRIGHT POWDER
# -1 THE FACESHOP-POWER LONG LASTING SUN CREAM
# -1 THE FACESHOP-POWER PERFECTION BB CREAM
# 1 THE FACESHOP-PRISM CUBE BRUSH BY ITALY FRENCH ROSE
# 0 THE FACESHOP-SINGLE BLUSH FARD A JOUES MULTI USAGE
# -1 THE FACESHOP-The Fresh for men Hydrating Emulsion
# -1 THE FACESHOP-THE SIGNARUE SKIN CONDITIONING SERUM
# -1 THE FACESHOP-TINT STICK TEINTE EN BATON
# -1 THE FACESHOP-Trendy Nails Nail Remover Rose
# -1 THE FACESHOP-더시그니처 모공 숨숨 크림
# -1 THE SAEM-HEALING TEA GARDEN GREEN TEA CLEANSING WATER
# -1 THE THERAPY-HYDRATING FORMULA EMULSION
# -1 THEBODYSHOP-MORINGA BOBY YOGURT
# -1 THEFACESHOP-INK LASTING FOUNDATION SLIM FIT
# -1 THIERRY MUGLER-ANGEL EAU PARFUM NATURAL SPRAY
# -1 THINK NATURE-BODY LOTION MOISTURE
# -1 TN-AC CONTROL RECIPE TROUBLE SKIN MOITURE LOTION
# -1 TONICO ANALCOLICO-ANTICA FARMACIA DEI MONACI CAMALDOLESI
# -1 TONY LAB-AC Control Toner
# -1 TONYMOLY-DELIGHT TONY TINT
# -1 TONYMOLY-EASY TOUCH
# -1 TONYMOLY-Floria Nutra Energy 100 Hours Cream
# 1 TONYMOLY-LUMINOUS GODDESS AURA BB CREAM
# 0 TONYMOLY-LUMINOUS GOODESS AURA BB CREAM
# -1 TONYMOLY-MOISTURE MIST
# -1 TONYMOLY-My Sunny vital sun Stick
# -1 TONYMOLY-The Chok Chok GREEN TEA Foam Cleanser
# -1 TONYMORY-THE BLACK TEA LONDON CLASSIC OIL
# -1 TONYPOLY-백젤 아이라이너 BLACK
# 0 TOO COOL FOR SCHOOL-ART CLASS BY RODIN
# 0 TOO COOL FOR SCHOOL-ART CLASS BY RODIN SHADING
# 1 TOO COOL FOR SCHOOL-ART CLASS BY RODIN SHADING CONTOUR
# -1 TOPPIK-HAIR BUILDING FIBERS
# 0 ULOS-COSMEDIC SKIN LOTION FOR FACE AND BODY
# 1 ULOS-COSMEDICS SKIN LOTION FOR FACE _ BODY
# 0 ULOS-SKIN MILK FOR FACE _ BODY
# -1 ULTRA HD-MAKE UP FOR EVER FOUNDATION
# -1 ULTRA V-FOCUS ENRICHED CREAM WHITENING NAD WRINKLE CARE
# -1 ULTRA V-HYAL 100 ANTI WRINKLE _ WHITENING
# -1 ULTRA V-IDEBENONE AGE RETURNING EYE CREAM
# -1 ULTRA V-IDEBENONE SUN BLOCK
# -1 ULTRA V-NIO BF CREAM SKIN BRIGHTENING ANTI WRINKLE
# -1 UNKNOWN-ORGAN EXTRA VIRGIN COCONUT OIL
# -1 URBAN BOUTIQUE-ROSY CHEEKS_ONLY ONE
# -1 URIAGE-THERMAL MICELLAR WATER
# -1 URIAGE-XEMOSE CLEANSING SOOTHING OIL
# -1 URIAGE-XEMOSE TONIQUE HYDRATANT
# -1 VANITAS Versace-eau de toilette
# -1 VANT36.5-AHA 10_ CREAM
# -1 VANT36.5-ALL IN ONE ESSENCE
# -1 VASELINE-INTENSIVE CARE
# -1 VASELINE-PURE PETROLEUM JELLY ORIGINAL
# -1 VDIVOV-SILK WEAR MAKEUP BASE
# -1 VDL-COLOR CORRECTING PRIMER
# -1 VDL-EXPERT COLOR FOR EYES
# -1 VDL-EXPERT COLOR PRIMER FOR EYES
# -1 VDL-EXPERT RADIANCE FIX MIST
# -1 VDL-NAKED STRONG CLEASING OIL
# -1 VDL-PERFECTING LAST FOUNDATION
# -1 VELY VELY-ARTEMISIA BALANCE ESSENCE
# -1 VELY VELY-AURA PEARL BASE
# -1 Vely Vely-Water Glow Balm
# -1 VER22-BOUNCE UP PACT PRIME
# -1 VERITE-ALL IN ONE CREAM
# 0 VERITE-AURORA COVER CUSHION
# -1 VERITE-CREAMY COLOR LIP BALM
# -1 VERITE-LIGHT TOUCH FOUNDATION
# 1 VERITE-오로라 커버 쿠션 21호 커버 바닐라
# -1 VERITE-울트라 모이스트 스킨
# 0 VERITE-크리스탈 커버 쿠션 21호 커버 바닐라 1
# 0 VERITE-크리스탈 커버 쿠션 21호 커버 바닐라 2
# -1 VERNIS A LEVRES-LIP TINT STICK
# -1 VERSACE-BRIGHT CRYSTAL PERFUME
# 0 VICHY V-EAU THERMALE MINERALISANTE
# 1 Vichy-EAU THERMALE MINERALISANTE
# -1 VICTORIA_S SECRET-LOVE ADDICT BODY MIST
# 0 VICTORIA_S SECRET-LOVE SPELL
# 1 VICTORIA_S SECRET-LOVE SPELL FRAGRANCE LOTION
# -1 VITRESS-CUTICLE COAT CLASSIC FOR EXTRA SHINY_SILLY SMOOTH HAIR
# -1 VIVIENNE WESTWOOD-NAUGHTY ALICE
# -1 VOLTE FACE-Fill Nutrition Serum
# -1 VONIN-PURE SUN
# 0 VONIN-THE CHARACTER BLACK
# 1 VONIN-THE CHARACTER BLACK TONER
# -1 VT-CICA REDNESS COVER CUSHION
# -1 VT-CICA REPAIR CREAM
# -1 VT-Double Cover Cushion 21호
# -1 VT-WATER CC CUSION MINI
# 0 W-ESSENCE WAX_1
# 1 W-ESSENCE WAX_2
# -1 WAKE MAKE-LIP COSTER ROSE SWING
# -1 WET N WILD-COLORICON ROSE IN THE AIR
# -1 WHOO-THE HISTORY OF WHOO LUXURY BB CREAM
# -1 WHOO-공진향 미 궁중 블러셔
# -1 WHOO-궁중립밤
# -1 WHOO-럭셔리 립스틱 부케 핑크
# -1 WHYDRO-WHITE REVOLTION CREAM
# -1 WONDER-CERAMIDE MOCCHI TONER
# -1 YOUR NAIL-BASIC
# -1 YSL-Endanger Me Red
# 0 YSL-GLOSSY STAIN
# 1 YSL-GLOSSY STAIN LIP COLOR_1
# 0 YSL-LIP STICK
# -1 YSL-LIP STICK_2
# 0 YSL-RED LIP STICK
# 0 YSL-TATOUAGE COUTURE LIQUID MATTE LIP STAIN_1
# 0 YSL-TATOUAGE COUTURE LIQUID MATTE LIP STAIN_2
# 0 YSL-VERNIS À LÈVRES VINYL CREAM LIQUID LIPSTICK
# -1 YURICA-FACE SHIELD
# -1 YURIPIBU-BIFIDA REPAIR AMPOULE
# -1 YURIPIBU-SPECIAL SPOT ESSENCE
# 1 ZIAJA-KOZIE MLEKO KREM2
# 0 ZIALA-goat_s milk Night Cream
# -1 과일나라-PURE ALOE VERA
# -1 과일나라-ULTRA MOISTURE HAND CARE ARGAN HAND CREAM
# -1 식물나라-OXYGEN WATER FITTING SUN CREAM
# -1 식물나라-제주 탄산수 딥 클렌징 워터
# -1 식물나라-프로폴리스 페이스 오일
# -1 웰빙헬스-고운발
