# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import os, shutil
import time, copy

# %%
# Data augmentation and normalization for training
# Just normalization for validation
data_transforms = {
    'train': transforms.Compose([
#         transforms.CenterCrop(160),
#         transforms.Resize([224,224]),
#         transforms.RandomCrop(160, padding=None, pad_if_needed=True, fill=0, padding_mode='constant'),
        transforms.Resize([224,224]),
        transforms.RandomHorizontalFlip(),
        transforms.RandomVerticalFlip(),
        transforms.RandomAffine([-45,45], translate=[0.2,0.2], scale=[0.7,1], shear=15, resample=False, fillcolor=0),
#         transforms.RandomRotation([-90,90], resample=False, expand=False, center=None),
        transforms.ToTensor(),
        transforms.ColorJitter(brightness=0, contrast=0, saturation=0, hue=0),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
        transforms.RandomErasing(p=1, scale=(0.02, 0.05), ratio=(0.3, 3.3), value=0, inplace=False),
        transforms.RandomErasing(p=1, scale=(0.02, 0.05), ratio=(0.3, 3.3), value=0, inplace=False)        
    ]),
    'val': transforms.Compose([
        transforms.Resize([224,224]),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

data_dir = 'LG-orignal-video/images_seperated_full'
# data_dir = 'img_hand'
image_datasets = {'train': datasets.ImageFolder(os.path.join(data_dir, 'train'), data_transforms['train']), 
                  'val': datasets.ImageFolder(os.path.join(data_dir, 'val'), data_transforms['val'])}

dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=32,
                                             shuffle=True, num_workers=4)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
class_names = image_datasets['train'].classes

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(dataset_sizes, len(class_names))
# Out:
# {'train': 10521, 'val': 598} 100

# %%
len(image_datasets['train'].classes), len(image_datasets['val'].classes)
# Out:
# (100, 100)

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for idx, (inputs, labels) in enumerate(dataloaders[phase]):
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs, _featuremaps = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
                
                # mini batch statistics
                if idx%50==0 and phase=='train':
                    print('[batch loss] {} Loss: {:.4f}'.format(phase, loss.item()))
                
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
import torch
import torch.nn as nn
from torchvision import datasets, models, transforms
import torchvision
from sklearn.preprocessing import MinMaxScaler
import numpy as np
from tqdm import tqdm_notebook as tqdm

class Flatten(torch.nn.Module):
    """
    torch.nn.Sequential에서 사용가능한 flatten 모듈
    """
    def forward(self, x):
        batch_size = x.shape[0]
        return x.view(batch_size, -1)

class DynamicGNoise(nn.Module):
    def __init__(self, shape, std=0.2):
        super().__init__()
        self.noise = torch.zeros(shape,shape).cuda()
        self.std   = std
        
    def forward(self, x):
        if not self.training: return x
        self.noise.data.normal_(0, std=self.std)
        return x + self.noise
    
class CAM(nn.Module):
    def __init__(self, n_classes):
        """Load the pretrained ResNet-50 and replace top fc layer."""
        super(CAM, self).__init__()
        self.scaler = MinMaxScaler()
        self.upsampler =  nn.UpsamplingBilinear2d([224,224])
        self.trans_normal = transforms.Compose([
            transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
        ])

#         ****torch pretrained net****
#         net = models.resnet50(pretrained=True)
#         modules = list(net.children())[:-2]      # delete all untill Conv_5 layer. - 2048
        avg_pool = nn.AdaptiveAvgPool2d(output_size=(1, 1)) # GAP
        flatten = Flatten()
#         self.backbone = nn.Sequential(*modules) #2048
        self.backbone = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), bias=False),
            nn.BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), bias=False),
            nn.BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), bias=False),
            nn.BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
            nn.ReLU(),   
            nn.MaxPool2d(2, 2),
            nn.Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), bias=False),
            nn.BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
            nn.ReLU()          
        )
        
        self.class_len = n_classes
        self.classifier = nn.Linear(self.class_len, self.class_len, bias=False) #final linear classifier
        self.noise = DynamicGNoise(224, std=0.05)
        # Freeze resnet
#         for param in self.backbone.parameters():
#             param.requires_grad = False
        
        # 1x1 conv 
        self.conv_final = nn.Sequential(
            nn.Conv2d(256, self.class_len, kernel_size=(1, 1), stride=(1, 1), bias=False),
            nn.BatchNorm2d(self.class_len, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
        )
        # fc layer
        self.fc = nn.Sequential(
            avg_pool,
            flatten,
            self.classifier
        )
        
        self.device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
        
    def forward(self, images):
        """Extract feature vectors from input images."""
        # CNN backbone
        _images = self.noise(images)
        _conv = self.backbone(_images)
        featuremaps = self.conv_final(_conv)
        # fc layer
        logits = self.fc(featuremaps) 
        return logits, featuremaps
    
        
    def getCAM(self, images_normal):
        """
        get class activation map
        @param images_normal - (N x C x H x W) 
        @return cams_scaled - (N x 224 x 224) [0,1] weight matrix
        @return masks_np - (N x 224 x 224 x C) numpy [0,1] weight matrix
        """
        # forward to model
        logits, featuremaps = self(images_normal) # featuremaps (N x C x H x W)
        preds, indices = logits.softmax(dim=1).sort(dim=1, descending=True) # cam_weight (N x C)
        cam_weights = self.classifier.weight[:,indices[:,0]].transpose(1,0)

        # get class activation map
        cams = []
        for _featuremap, _cam_weight in zip(featuremaps, cam_weights):
            _cam = []
            for c,w in zip(_featuremap, _cam_weight): 
                _cam.append((c*w).data)
            _cam = torch.stack(_cam)
            cams.append(_cam)
        cams = torch.stack(cams)
            
        cams_updsampled = self.upsampler(cams).sum(dim=1) # batchx224x224
        # scale to [0,1] for recalibrartion weight
        cams_scaled = []
        for _cam_upsampled in cams_updsampled:
            _cam_scaled = self.scaler.fit_transform(_cam_upsampled.cpu().numpy())  
            cams_scaled.append(_cam_scaled)
        cams_scaled = torch.tensor(cams_scaled).data
        masks_np = np.stack([cams_scaled, cams_scaled, cams_scaled], axis=3)
        return cams_scaled, masks_np

# %%
from torchsummary import summary
model = CAM(len(image_datasets['train'].classes))
model.to(model.device)

summary(model, (3, 224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#      DynamicGNoise-1          [-1, 3, 224, 224]               0
#             Conv2d-2         [-1, 32, 222, 222]             864
#        BatchNorm2d-3         [-1, 32, 222, 222]              64
#               ReLU-4         [-1, 32, 222, 222]               0
#          MaxPool2d-5         [-1, 32, 111, 111]               0
#             Conv2d-6         [-1, 64, 109, 109]          18,432
#        BatchNorm2d-7         [-1, 64, 109, 109]             128
#               ReLU-8         [-1, 64, 109, 109]               0
#          MaxPool2d-9           [-1, 64, 54, 54]               0
#            Conv2d-10          [-1, 128, 52, 52]          73,728
#       BatchNorm2d-11          [-1, 128, 52, 52]             256
#              ReLU-12          [-1, 128, 52, 52]               0
#         MaxPool2d-13          [-1, 128, 26, 26]               0
#            Conv2d-14          [-1, 256, 24, 24]         294,912
#       BatchNorm2d-15          [-1, 256, 24, 24]             512
#              ReLU-16          [-1, 256, 24, 24]               0
#            Conv2d-17          [-1, 100, 24, 24]          25,600
#       BatchNorm2d-18          [-1, 100, 24, 24]             200
# AdaptiveAvgPool2d-19            [-1, 100, 1, 1]               0
#           Flatten-20                  [-1, 100]               0
#            Linear-21                  [-1, 100]          10,000
#            Linear-22                  [-1, 100]          10,000
# ================================================================
# Total params: 434,696
# Trainable params: 434,696
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 71.92
# Params size (MB): 1.66
# Estimated Total Size (MB): 74.15
# ----------------------------------------------------------------

# %%
# model.load_state_dict(torch.load('torch_models/cam-myconv.pth'))

# %%
classes = image_datasets['train'].classes
criterion = nn.CrossEntropyLoss()

# Observe that only parameters of final layer are being optimized as
# opposed to before.
params = list(model.fc.parameters()) + list(model.conv_final.parameters()) + list(model.backbone.parameters())
# optimizer = optim.SGD(params, lr=0.001, momentum=0.9)
optimizer = torch.optim.Adam(params, lr=0.001)

# Decay LR by a factor of 0.1 every 3 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=3, gamma=0.5)
# exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.5)

# %%
model = train_model(model, criterion, optimizer, exp_lr_scheduler, num_epochs=20)
# Out:
# Epoch 0/19
# ----------
# [batch loss] train Loss: 4.6349
# [batch loss] train Loss: 4.6284
# [batch loss] train Loss: 4.6028
# [batch loss] train Loss: 4.6066
# [batch loss] train Loss: 4.6147
# [batch loss] train Loss: 4.6665
# [batch loss] train Loss: 4.6200
# train Loss: 4.6269 Acc: 0.0077
# val Loss: 4.6200 Acc: 0.0117
#
# Epoch 1/19
# ----------
# [batch loss] train Loss: 4.6140
# [batch loss] train Loss: 4.6196
# [batch loss] train Loss: 4.6279
# [batch loss] train Loss: 4.6481
# [batch loss] train Loss: 4.5989
# [batch loss] train Loss: 4.6390
# [batch loss] train Loss: 4.6366
# train Loss: 4.6259 Acc: 0.0057
# val Loss: 4.6213 Acc: 0.0117
#
# Epoch 2/19
# ----------
# [batch loss] train Loss: 4.6191
# [batch loss] train Loss: 4.6534
# [batch loss] train Loss: 4.6472
# [batch loss] train Loss: 4.6173
# [batch loss] train Loss: 4.6484
# [batch loss] train Loss: 4.6370
# [batch loss] train Loss: 4.6417
# train Loss: 4.6270 Acc: 0.0074
# val Loss: 4.6191 Acc: 0.0117
#
# Epoch 3/19
# ----------
# [batch loss] train Loss: 4.6055
# [batch loss] train Loss: 4.6406
# [batch loss] train Loss: 4.6225
# [batch loss] train Loss: 4.6148
# [batch loss] train Loss: 4.5950
# [batch loss] train Loss: 4.6552
# [batch loss] train Loss: 4.6550
# train Loss: 4.6263 Acc: 0.0072
# val Loss: 4.6213 Acc: 0.0100
#
# Epoch 4/19
# ----------
# [batch loss] train Loss: 4.6297
# [batch loss] train Loss: 4.6616
# [batch loss] train Loss: 4.6258
# [batch loss] train Loss: 4.6689
# [batch loss] train Loss: 4.5903
# [batch loss] train Loss: 4.6285
# [batch loss] train Loss: 4.6257
# train Loss: 4.6262 Acc: 0.0068
# val Loss: 4.6179 Acc: 0.0117
#
# Epoch 5/19
# ----------
# [batch loss] train Loss: 4.6403
# [batch loss] train Loss: 4.6258
# [batch loss] train Loss: 4.6379
# [batch loss] train Loss: 4.6280
# [batch loss] train Loss: 4.6368
# [batch loss] train Loss: 4.6323
# [batch loss] train Loss: 4.5873
# train Loss: 4.6290 Acc: 0.0082
# val Loss: 4.6206 Acc: 0.0117
#
# Epoch 6/19
# ----------
# [batch loss] train Loss: 4.6364
# [batch loss] train Loss: 4.6068
# [batch loss] train Loss: 4.5876
# [batch loss] train Loss: 4.6007
# [batch loss] train Loss: 4.6223
# [batch loss] train Loss: 4.6128
# [batch loss] train Loss: 4.6686
# train Loss: 4.6266 Acc: 0.0071
# val Loss: 4.6195 Acc: 0.0100
#
# Epoch 7/19
# ----------
# [batch loss] train Loss: 4.6393
# [batch loss] train Loss: 4.6346
# [batch loss] train Loss: 4.6438
# [batch loss] train Loss: 4.6170
# [batch loss] train Loss: 4.6086
# [batch loss] train Loss: 4.6368
# [batch loss] train Loss: 4.5951
# train Loss: 4.6255 Acc: 0.0069
# val Loss: 4.6182 Acc: 0.0117
#
# Epoch 8/19
# ----------
# [batch loss] train Loss: 4.6779
# [batch loss] train Loss: 4.6110
# [batch loss] train Loss: 4.6436
# [batch loss] train Loss: 4.5942
# [batch loss] train Loss: 4.6003
# [batch loss] train Loss: 4.6248
# [batch loss] train Loss: 4.6264
# train Loss: 4.6264 Acc: 0.0067
# val Loss: 4.6204 Acc: 0.0117
#
# Epoch 9/19
# ----------
# [batch loss] train Loss: 4.6441
# [batch loss] train Loss: 4.6510
# [batch loss] train Loss: 4.6402
# [batch loss] train Loss: 4.6010
# [batch loss] train Loss: 4.6700
# [batch loss] train Loss: 4.6408
# [batch loss] train Loss: 4.6626
# train Loss: 4.6274 Acc: 0.0063
# val Loss: 4.6219 Acc: 0.0117
#
# Epoch 10/19
# ----------
# [batch loss] train Loss: 4.6351
# [batch loss] train Loss: 4.6366
# [batch loss] train Loss: 4.6554
# [batch loss] train Loss: 4.6552
# [batch loss] train Loss: 4.6205
# [batch loss] train Loss: 4.6297
# [batch loss] train Loss: 4.6397
# train Loss: 4.6269 Acc: 0.0069
# val Loss: 4.6222 Acc: 0.0100
#
# Epoch 11/19
# ----------
# [batch loss] train Loss: 4.6140
# [batch loss] train Loss: 4.6603
# [batch loss] train Loss: 4.6362
# [batch loss] train Loss: 4.6398
# [batch loss] train Loss: 4.6237
# [batch loss] train Loss: 4.5912
# [batch loss] train Loss: 4.6492
# train Loss: 4.6270 Acc: 0.0071
# val Loss: 4.6223 Acc: 0.0100
#
# Epoch 12/19
# ----------
# [batch loss] train Loss: 4.6080
# [batch loss] train Loss: 4.6027
# [batch loss] train Loss: 4.6199
# [batch loss] train Loss: 4.5796
# [batch loss] train Loss: 4.6162
# [batch loss] train Loss: 4.6139
# [batch loss] train Loss: 4.6242
# train Loss: 4.6259 Acc: 0.0077
# val Loss: 4.6201 Acc: 0.0100
#
# Epoch 13/19
# ----------
# [batch loss] train Loss: 4.6382
# [batch loss] train Loss: 4.6167
# [batch loss] train Loss: 4.6116
# [batch loss] train Loss: 4.6148
# [batch loss] train Loss: 4.6743
# [batch loss] train Loss: 4.6323
# [batch loss] train Loss: 4.5836
# train Loss: 4.6287 Acc: 0.0065
# val Loss: 4.6202 Acc: 0.0100
#
# Epoch 14/19
# ----------
# [batch loss] train Loss: 4.6428
# [batch loss] train Loss: 4.6128
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-90-70cd1c1d3009> in <module>()
# ----> 1 model = train_model(model, criterion, optimizer, exp_lr_scheduler, num_epochs=20)
#
# <ipython-input-87-5a872f378fea> in train_model(model, criterion, optimizer, scheduler, num_epochs)
#      20
#      21             # Iterate over data.
# ---> 22             for idx, (inputs, labels) in enumerate(dataloaders[phase]):
#      23                 inputs = inputs.to(device)
#      24                 labels = labels.to(device)
#
# ~\AppData\Roaming\Python\Python36\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     802
#     803             assert not self._shutdown and self._tasks_outstanding > 0
# --> 804             idx, data = self._get_data()
#     805             self._tasks_outstanding -= 1
#     806
#
# ~\AppData\Roaming\Python\Python36\site-packages\torch\utils\data\dataloader.py in _get_data(self)
#     769         else:
#     770             while True:
# --> 771                 success, data = self._try_get_data()
#     772                 if success:
#     773                     return data
#
# ~\AppData\Roaming\Python\Python36\site-packages\torch\utils\data\dataloader.py in _try_get_data(self, timeout)
#     722         #   (bool: whether successfully get data, any: data if successful else None)
#     723         try:
# --> 724             data = self._data_queue.get(timeout=timeout)
#     725             return (True, data)
#     726         except Exception as e:
#
# C:\ProgramData\Anaconda3\lib\multiprocessing\queues.py in get(self, block, timeout)
#     102                 if block:
#     103                     timeout = deadline - time.time()
# --> 104                     if timeout < 0 or not self._poll(timeout):
#     105                         raise Empty
#     106                 elif not self._poll():
#
# C:\ProgramData\Anaconda3\lib\multiprocessing\connection.py in poll(self, timeout)
#     255         self._check_closed()
#     256         self._check_readable()
# --> 257         return self._poll(timeout)
#     258
#     259     def __enter__(self):
#
# C:\ProgramData\Anaconda3\lib\multiprocessing\connection.py in _poll(self, timeout)
#     328                         _winapi.PeekNamedPipe(self._handle)[0] != 0):
#     329                 return True
# --> 330             return bool(wait([self], timeout))
#     331
#     332         def _get_more_data(self, ov, maxsize):
#
# C:\ProgramData\Anaconda3\lib\multiprocessing\connection.py in wait(object_list, timeout)
#     857                         timeout = 0
#     858
# --> 859             ready_handles = _exhaustive_wait(waithandle_to_obj.keys(), timeout)
#     860         finally:
#     861             # request that overlapped reads stop
#
# C:\ProgramData\Anaconda3\lib\multiprocessing\connection.py in _exhaustive_wait(handles, timeout)
#     789         ready = []
#     790         while L:
# --> 791             res = _winapi.WaitForMultipleObjects(L, False, timeout)
#     792             if res == WAIT_TIMEOUT:
#     793                 break
#
# KeyboardInterrupt:

# %%
# class_correct = list(0. for i in range(len(classes)))
# class_total = list(0. for i in range(len(classes)))
# model.eval()
# for data in dataloaders['val']:
#     images, labels = data[0].to(device), data[1].to(device)
#     outputs, _featuremaps = model(images)
#     _, predicted = torch.max(outputs, 1)
#     c = (predicted == labels).squeeze()
#     for i in range(len(labels)):
#         label = labels[i]
#         class_correct[label] += c[i].item()
#         class_total[label] += 1


# for i in range(len(classes)):
#     print('Accuracy of %5s : %2d %%' % (
#         classes[i], 100 * class_correct[i] / class_total[i]))

# %%
torch.save(model.state_dict(), 'torch_models/cam-myconv.pth')

# %% [markdown]
# ___
# # VISUALIZE

# %%
cam_dataset = torchvision.datasets.ImageFolder(
    root='new-cosmetic-frontview/images_ext',
#     root='LG-orignal-video/images_seperated_full/train',
#     root='server/vu-visor/static/images_ext_bak',
#     root='img_real/server',
    transform=transforms.Compose([
        transforms.Resize([224,224]),
        transforms.ToTensor(),
#         transforms.RandomErasing(p=1, scale=(0.02, 0.33), ratio=(0.3, 3.3), value=0, inplace=False),
#         transforms.RandomErasing(p=1, scale=(0.02, 0.1), ratio=(0.3, 3.3), value=0, inplace=False)
#         transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])
)
trans_normal = transforms.Compose([
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])

# cam_dataset = image_datasets['train']
cam_loader = torch.utils.data.DataLoader(cam_dataset, batch_size=3,
                                          shuffle=True, num_workers=4)

def show_img(imgPath):
    frame = cv2.imread(os.path.join(imgPath), cv2.IMREAD_COLOR)
    # opencv frme input // H*W*C(BGR)
    # 0-255 3 channel
    inputs = torch.Tensor(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))/255 # 여기 Tensor 소문자로 바꾸면 안됨... 차이 알아보기
    plt.imshow(inputs)
    plt.show()

def show_tensor(t):
    plt.imshow(t.numpy().transpose([1,2,0]))
    plt.show()

# %%
model.eval()
cam_iter = iter(cam_loader)

# %%
def getCAM(images_normal):
    """
    get class activation map
    @param images_normal - (N x C x H x W) 
    @return cams_scaled - (N x 224 x 224) [0,1] weight matrix
    @return masks_np - (N x 224 x 224 x C) numpy [0,1] weight matrix
    """
    # forward to model
    logits, featuremaps = model(images_normal) # featuremaps (N x C x H x W)
    preds, indices = logits.softmax(dim=1).sort(dim=1, descending=True) # cam_weight (N x C)
#     cam_weights = model.classifier.weight[:,[29]*len(indices)].transpose(1,0)
    cam_weights = model.classifier.weight[:,indices[:,0]].transpose(1,0)
    print(indices[:,0], len(indices))

    # get class activation map
    cams = []
    for _featuremap, _cam_weight in zip(featuremaps, cam_weights):
        _cam = []
        for c,w in zip(_featuremap, _cam_weight): 
            _cam.append((c*w).data)
        _cam = torch.stack(_cam)
        cams.append(_cam)
    cams = torch.stack(cams)

    cams_updsampled = model.upsampler(cams).sum(dim=1) # batchx224x224
    # scale to [0,1] for recalibrartion weight
    cams_scaled = []
    for _cam_upsampled in cams_updsampled:
        _cam_scaled = model.scaler.fit_transform(_cam_upsampled.cpu().numpy())  
        cams_scaled.append(_cam_scaled)
    cams_scaled = torch.tensor(cams_scaled).data
    masks_np = np.stack([cams_scaled, cams_scaled, cams_scaled], axis=3)
    return cams_scaled, masks_np

# %%
images, labels = next(cam_iter)
images = images.data.to(model.device)
images_normal = []
for image in images:
    images_normal.append(trans_normal(image))
images_normal = torch.stack(images_normal)

# get class activation map
# %time cams_scaled, masks_np = getCAM(images_normal)

for image, cam_scaled, mask in zip(images, cams_scaled, masks_np):
    # plot
    im_np = image.cpu().numpy().transpose([1,2,0]).clip(0,1)
    plt.figure(figsize=(10,5))
    plt.subplot(121)
    plt.imshow(im_np)
    # plt.imshow(cam_scaled.clip(0, .2), cmap='jet', alpha=0.4)
    plt.imshow(cam_scaled, cmap='jet', alpha=0.4)
    plt.colorbar(ticks=[0.1,0.3,0.5,0.7,0.9], orientation ='vertical')

    # img masked
    im_masked = im_np*mask
    plt.subplot(122)
    plt.imshow(im_masked.clip(0,1))
    plt.show()
# Out:
# tensor([79,  0,  0], device='cuda:0') 3
# Wall time: 48 ms

# %% [markdown]
# ---
# # bak

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
cam_dataset = torchvision.datasets.ImageFolder(
#     root='new-cosmetic-frontview/images_ext',
    root='LG-orignal-video/images_seperated_full/train',
#     root='server/vu-visor/static/images_ext_bak',
#     root='img_real/server',
    transform=transforms.Compose([
        transforms.Resize([224,224]),
        transforms.ToTensor(),
#         transforms.RandomErasing(p=1, scale=(0.02, 0.33), ratio=(0.3, 3.3), value=0, inplace=False),
#         transforms.RandomErasing(p=1, scale=(0.02, 0.1), ratio=(0.3, 3.3), value=0, inplace=False)
#         transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])
)
trans_normal = transforms.Compose([
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])

# cam_dataset = image_datasets['train']
cam_loader = torch.utils.data.DataLoader(cam_dataset, batch_size=1,
                                          shuffle=True, num_workers=4)

def show_img(imgPath):
    frame = cv2.imread(os.path.join(imgPath), cv2.IMREAD_COLOR)
    # opencv frme input // H*W*C(BGR)
    # 0-255 3 channel
    inputs = torch.Tensor(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))/255 # 여기 Tensor 소문자로 바꾸면 안됨... 차이 알아보기
    plt.imshow(inputs)
    plt.show()

def show_tensor(t):
    plt.imshow(t.numpy().transpose([1,2,0]))
    plt.show()
    
def getCAM(featuremap, cam_weight):
    """
    get class activation map
    @param featuremap - (C x H x W)
    @param cam_weight - (C)
    @return (H x W) [0,1] weight matrix
    """
    global scaler
    # get class activation map
    cam = []
    for c,w in zip(featuremap, cam_weight): 
        cam.append((c*w).data)
    cam = torch.stack(cam)
    upsampler = nn.UpsamplingBilinear2d([224,224])
    cam_updsampled = upsampler(cam.unsqueeze(0)).squeeze().sum(dim=0) # upsample [224,224]
    # scale to [0,1] for recalibrartion weight
    cam_scaled = scaler.fit_transform(cam_updsampled.cpu().numpy())    
    return cam_scaled
    # return cam_updsampled.cpu().numpy()

# %%
images, labels = next(cam_iter)
images = images.data.to(model.device)
images_normal = trans_normal(images[0]).unsqueeze(0)
# images_normal = images
# %time logit, features = model(images_normal)    
label = int(labels.item())
#     if label != 12: continue
print(cam_loader.dataset.classes[label])
pred, idx = logit.softmax(dim=1).sort(dim=1, descending=True)
# print(pred[:,0].item(), ',', cam_loader.dataset.classes[idx[:,0].item()])


# get class activation map
#     cam_weight = model.classifier.weight[:,12]
cam_weight = model.classifier.weight[:,idx[:,0].item()]
cam_scaled = getCAM(features[0], cam_weight)

# plot
im_np = images[0].cpu().numpy().transpose([1,2,0])
plt.figure(figsize=(10,5))
plt.subplot(121)
plt.imshow(im_np.clip(0,1))
# plt.imshow(cam_scaled.clip(0, .2), cmap='jet', alpha=0.4)
plt.imshow(cam_scaled, cmap='jet', alpha=0.4)
plt.colorbar(ticks=[0.1,0.3,0.5,0.7,0.9], orientation ='vertical')

# img masked
mask = np.stack([cam_scaled, cam_scaled, cam_scaled], axis=2) #>0.4
im_masked = im_np.clip(0,1)*mask
plt.subplot(122)
plt.imshow(im_masked)
plt.show()
# Out:
# Wall time: 3 ms
# MAC-LIP STICK
# torch.Size([24, 24]) tensor(-0.1382, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(0.1274, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(-0.2162, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(0.1943, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(-0.5963, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(-0.4396, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(0.2058, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(-0.4559, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(0.1131, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(-0.3466, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(-0.2502, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(0.0312, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(-0.0307, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(0.1129, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(-0.2786, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(0.3105, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(0.1751, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(0.3784, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(0.0391, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(-0.0113, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(0.1607, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(0.2276, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(-0.0493, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(0.0277, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(0.2454, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(-0.1194, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(0.1673, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(-0.0064, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(-0.1560, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(0.3332, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(-0.4248, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(0.2319, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(0.2357, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(0.0480, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(-0.2511, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(-0.1090, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(0.1017, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(-0.2063, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(0.3103, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(0.2230, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(0.3257, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(0.2271, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(-0.0327, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(0.0871, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(0.4393, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(-0.1206, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(0.0429, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(-0.3598, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(0.2526, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(0.4436, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(0.0040, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(0.1338, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(0.5510, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(-0.3848, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(0.0156, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(-0.1086, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(0.3691, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(-0.1734, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(-0.0282, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(-0.1234, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(-0.4323, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(0.5345, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(-0.2415, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(-0.3568, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(0.1795, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(-0.1090, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(0.1771, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(0.3005, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(-0.1858, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(-0.4069, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(-0.0613, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(-0.1083, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(0.1119, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(-0.1267, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(-0.4026, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(0.0793, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(-0.0439, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(0.4128, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(-0.0587, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(0.1698, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(-0.1119, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(0.1692, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(-0.0646, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(-0.2987, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(-0.0626, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(0.1190, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(0.0657, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(0.1697, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(-0.0324, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(0.1653, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(-0.4215, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(0.0452, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(-0.3659, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(0.2437, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(0.2968, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(-0.1487, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(-0.3528, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(-0.1011, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(-0.1247, device='cuda:0', grad_fn=<SelectBackward>)
# torch.Size([24, 24]) tensor(-0.3767, device='cuda:0', grad_fn=<SelectBackward>)
